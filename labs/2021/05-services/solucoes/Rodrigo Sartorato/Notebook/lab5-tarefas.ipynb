# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %%
import io
import requests
import json

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
url_drum = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_drum = requests.get(url_drum)
json_drum = data_drum.json()

print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de tendas dos Milagres: " + grass)
# Out:
# Autor de tendas dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()

print(json.dumps(json_mi, indent=3))
uri_mesh = json_mi[0]["resource"]

print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])

url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Statue of Liberty"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
statue_ref = data.json()
print(json.dumps(statue_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 315739031,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 32965412,
#       "boundingbox": [
#          "40.6888049",
#          "40.6896741",
#          "-74.0451069",
#          "-74.0439637"
#       ],
#       "lat": "40.689253199999996",
#       "lon": "-74.04454817144321",
#       "display_name": "Statue of Liberty, Flagpole Plaza, Manhattan Community Board 1, Manhattan, New York County, New York, 10004, United States",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.8714324085707771,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 33622182,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 2837177940,
#       "boundingbox": [
#          "41.3438445",
#          "41.3439445",
#          "-86.3112295",
#          "-86.3111295"
#       ],
#       "lat": "41.3438945",
#       "lon": "-86.3111795",
#       "display_name": "Statue of Liberty, North Center Street, Plymouth, Marshall County, Indiana, 46563, United States",
#       "class": "tourism",
#       "type": "artwork",
#       "importance": 0.6398058423953755,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_art_gallery2.p.20.png"
#    },
#    {
#       "place_id": 72530020,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 6522071353,
#       "boundingbox": [
#          "59.352823",
#          "59.352923",
#          "5.2191716",
#          "5.2192716"
#       ],
#       "lat": "59.352873",
#       "lon": "5.2192216",
#       "display_name": "Statue of Liberty, Visnesvegen, Visnes, Karm\u00f8y, Rogaland, 4264, Norge",
#       "class": "historic",
#       "type": "monument",
#       "importance": 0.5075345213990273,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_monument.p.20.png"
#    },
#    {
#       "place_id": 2598417,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 355219404,
#       "boundingbox": [
#          "52.6257341",
#          "52.6258341",
#          "-1.1436719",
#          "-1.1435719"
#       ],
#       "lat": "52.6257841",
#       "lon": "-1.1436219",
#       "display_name": "Statue Of Liberty, Upperton Road, Bede Island, Leicester, City of Leicester, East Midlands, England, LE2 7AU, United Kingdom",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 75794313,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 7045384476,
#       "boundingbox": [
#          "43.0853367",
#          "43.0854367",
#          "-75.2472915",
#          "-75.2471915"
#       ],
#       "lat": "43.0853867",
#       "lon": "-75.2472415",
#       "display_name": "Statue of Liberty, Pleasant Street, City of Utica, Oneida County, New York, 13501, United States",
#       "class": "tourism",
#       "type": "artwork",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_art_gallery2.p.20.png"
#    },
#    {
#       "place_id": 6840256,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 738952460,
#       "boundingbox": [
#          "13.4812514",
#          "13.4813514",
#          "144.7532551",
#          "144.7533551"
#       ],
#       "lat": "13.4813014",
#       "lon": "144.7533051",
#       "display_name": "Statue of Liberty, Aspinall Avenue, Hag\u00e5t\u00f1a, Hag\u00e5t\u00f1a Municipality, Guam, 96910, United States",
#       "class": "historic",
#       "type": "monument",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_monument.p.20.png"
#    },
#    {
#       "place_id": 26332202,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 2625445239,
#       "boundingbox": [
#          "37.9783308",
#          "37.9784308",
#          "-103.5433845",
#          "-103.5432845"
#       ],
#       "lat": "37.9783808",
#       "lon": "-103.5433345",
#       "display_name": "Statue of Liberty, Colorado Avenue, La Junta, Otero County, Colorado, 81050, United States",
#       "class": "historic",
#       "type": "monument",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_monument.p.20.png"
#    },
#    {
#       "place_id": 56140566,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 4926244200,
#       "boundingbox": [
#          "40.7405985",
#          "40.7406985",
#          "-93.7467783",
#          "-93.7466783"
#       ],
#       "lat": "40.7406485",
#       "lon": "-93.7467283",
#       "display_name": "Statue of Liberty, North Main Street, Leon, Decatur County, Iowa, 50144, United States",
#       "class": "historic",
#       "type": "monument",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_monument.p.20.png"
#    },
#    {
#       "place_id": 211642581,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 579896826,
#       "boundingbox": [
#          "44.1862081",
#          "44.1862887",
#          "-88.4616518",
#          "-88.4615216"
#       ],
#       "lat": "44.1862436",
#       "lon": "-88.4615865186054",
#       "display_name": "Statue of Liberty, South Commercial Street, Neenah, Winnebago County, Wisconsin, 54956, United States",
#       "class": "historic",
#       "type": "memorial",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_monument.p.20.png"
#    },
#    {
#       "place_id": 74195947,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 6862922602,
#       "boundingbox": [
#          "39.3357744",
#          "39.3358744",
#          "-84.527324",
#          "-84.527224"
#       ],
#       "lat": "39.3358244",
#       "lon": "-84.527274",
#       "display_name": "Statue of Liberty, Dixie Highway, Fairfield, Butler County, Ohio, 45014, United States",
#       "class": "tourism",
#       "type": "artwork",
#       "importance": 0.30100000000000005,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_art_gallery2.p.20.png"
#    }
# ]

# %%
print(statue_ref[0]["osm_id"])
# Out:
# 32965412

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(statue_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
statue_way = data.json()
print(json.dumps(statue_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1251759 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 32965412,
#          "timestamp": "2021-05-03T17:39:34Z",
#          "version": 69,
#          "changeset": 104072794,
#          "user": "Harvesterify",
#          "uid": 6060820,
#          "nodes": [
#             371241042,
#             371241043,
#             371241044,
#             8262932587,
#             1276628073,
#             371241045,
#             371241547,
#             3274271627,
#             1276628057,
#             371241048,
#             8262932463,
#             1276628259,
#             371241049,
#             371241050,
#             8262932596,
#             8262932444,
#             371241051,
#             371241052,
#             371241053,
#             371241054,
#             371241055,
#             371241056,
#             1276628191,
#             371241057,
#             5037716992,
#             1276628067,
#             371241058,
#             371241059,
#             371241060,
#             371241061,
#             371241062,
#             371241063,
#             371241064,
#             371241042
#          ],
#          "tags": {
#             "addr:postcode": "10004",
#             "alt_name": "Lady Liberty;Liberty Enlightening the World",
#             "artist_name": "Auguste Bartholdi",
#             "artwork_type": "statue",
#             "boundary": "national_park",
#             "building": "yes",
#             "building:colour": "#C1BA9D",
#             "building:material": "stone",
#             "building:part": "yes",
#             "ele": "2",
#             "fee": "no",
#             "height": "10",
#             "historic": "monument",
#             "image": "https://commons.wikimedia.org/wiki/File:Statue_of_Liberty_7.jpg",
#             "importance": "international",
#             "inscription": "Give me your tired, your poor, Your huddled masses yearning to breathe free, The wretched refuse of your teeming shore. Send these, the homeless, tempest-tost, to me, I lift my lamp beside the golden door !",
#             "landmark": "statue",
#             "material": "copper",
#             "monument": "statue",
#             "name": "Statue of Liberty",
#             "name:af": "Vryheidstandbeeld",
#             "name:ba": "\u0410\u0437\u0430\u0442\u043b\u044b\u04a1 \u0441\u0442\u0430\u0442\u0443\u044f\u04bb\u044b",
#             "name:be": "\u0421\u0442\u0430\u0442\u0443\u044f \u0421\u0432\u0430\u0431\u043e\u0434\u044b",
#             "name:cs": "Socha Svobody",
#             "name:da": "Frihedsgudinden",
#             "name:de": "Freiheitsstatue",
#             "name:el": "\u0386\u03b3\u03b1\u03bb\u03bc\u03b1 \u03c4\u03b7\u03c2 \u0395\u03bb\u03b5\u03c5\u03b8\u03b5\u03c1\u03af\u03b1\u03c2",
#             "name:en": "Statue of Liberty",
#             "name:es": "Estatua de la Libertad",
#             "name:et": "Vabadussammas",
#             "name:fi": "Vapaudenpatsas",
#             "name:fr": "Statue de la Libert\u00e9",
#             "name:he": "\u05e4\u05e1\u05dc \u05d4\u05d7\u05d9\u05e8\u05d5\u05ea",
#             "name:hi": "\u0938\u094d\u091f\u0948\u091a\u0942 \u0911\u092b \u0932\u093f\u092c\u0930\u094d\u091f\u0940",
#             "name:hu": "Szabads\u00e1g-szobor",
#             "name:it": "Statua della Libert\u00e0",
#             "name:ja": "\u81ea\u7531\u306e\u5973\u795e\u50cf",
#             "name:ko": "\uc790\uc720\uc758 \uc5ec\uc2e0\uc0c1",
#             "name:nl": "Vrijheidsbeeld",
#             "name:pl": "Statua Wolno\u015bci",
#             "name:pt": "Est\u00e1tua da Liberdade",
#             "name:ro": "Statuia Libert\u0103\u021bii",
#             "name:ru": "\u0421\u0442\u0430\u0442\u0443\u044f \u0421\u0432\u043e\u0431\u043e\u0434\u044b",
#             "name:sk": "Socha slobody",
#             "name:sl": "Kip svobode",
#             "name:sv": "Frihetsgudinnan",
#             "name:tt": "\u0410\u0437\u0430\u0442\u043b\u044b\u043a \u0441\u044b\u043d\u044b",
#             "name:uk": "\u0421\u0442\u0430\u0442\u0443\u044f \u0421\u0432\u043e\u0431\u043e\u0434\u0438",
#             "name:zh": "\u81ea\u7531\u5973\u795e\u50cf",
#             "official_name": "Liberty Enlightening the World",
#             "official_name:en": "Liberty Enlightening the World",
#             "roof:colour": "#BEBA9F",
#             "roof:material": "stone",
#             "roof:shape": "flat",
#             "seamark:landmark:category": "monument",
#             "start_date": "1886-10-28",
#             "tourism": "attraction",
#             "wheelchair": "limited",
#             "wikidata": "Q9202",
#             "wikipedia": "en:Statue of Liberty"
#          }
#       }
#    ]
# }

# %%
print(statue_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:Statue of Liberty

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = statue_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
statue_dbpedia = data.json()
print(json.dumps(statue_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Statue_of_Liberty"
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:World_Heritage_Sites_in_the_United_States"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Dead_Kennedys"
#                }
#             },
#             "http://dbpedia.org/property/locmapin": "New York City#New York",
#             "http://dbpedia.org/property/designation1Free1name": "State Party",
#             "http://dbpedia.org/property/title": "Statue of Liberty, Liberty Island, Manhattan, New York, New York County, NY",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Statue de la Libert\u00e9",
#             "http://dbpedia.org/ontology/abstract": "\u062a\u0645\u062b\u0627\u0644 \u0627\u0644\u062d\u0631\u064a\u0629 (\u0628\u0627\u0644\u0625\u0646\u062c\u0644\u064a\u0632\u064a\u0629: Statue of Liberty)\u060c \u0648\u0627\u0633\u0645\u0647 \u0627\u0644\u0643\u0627\u0645\u0644 \u0627\u0644\u062d\u0631\u064a\u0629 \u062a\u0646\u064a\u0631 \u0627\u0644\u0639\u0627\u0644\u0645 (\u0628\u0627\u0644\u0625\u0646\u062c\u0644\u064a\u0632\u064a\u0629: Liberty Enlightening the World\u060c \u0628\u0627\u0644\u0641\u0631\u0646\u0633\u064a\u0629: La Libert\u00e9 \u00e9clairant le monde)\u060c \u0647\u0648 \u0639\u0645\u0644 \u0641\u0646\u064a \u0646\u062d\u062a\u064a \u0642\u0627\u0645\u062a \u0641\u0631\u0646\u0633\u0627 \u0628\u0625\u0647\u062f\u0627\u0626\u0647 \u0625\u0644\u0649 \u0627\u0644\u0648\u0644\u0627\u064a\u0627\u062a \u0627\u0644\u0645\u062a\u062d\u062f\u0629 \u0627\u0644\u0623\u0645\u0631\u064a\u0643\u064a\u0629 \u0641\u064a 28 \u0623\u0643\u062a\u0648\u0628\u0631 \u0639\u0627\u0645 1886 \u0643\u0647\u062f\u064a\u0629 \u062a\u0630\u0643\u0627\u0631\u064a\u0629\u060c \u0628\u0647\u062f\u0641 \u062a\u0648\u062b\u064a\u0642 \u0639\u0631\u0649 \u0627\u0644\u0635\u062f\u0627\u0642\u0629 \u0628\u064a\u0646 \u0627\u0644\u0628\u0644\u062f\u064a\u0646 \u0628\u0645\u0646\u0627\u0633\u0628\u0629 \u0627\u0644\u0630\u0643\u0631\u0649 \u0627\u0644\u0645\u0626\u0648\u064a\u0629 \u0644\u0644\u062b\u0648\u0631\u0629 \u0627\u0644\u0623\u0645\u0631\u064a\u0643\u064a\u0629 (1775-1783). \u0648\u0645\u0646\u0630 \u0630\u0644\u0643 \u0627\u0644\u062d\u064a\u0646 \u0627\u0633\u062a\u0642\u0631 \u0627\u0644\u062a\u0645\u062b\u0627\u0644 \u0628\u0645\u0648\u0642\u0639\u0647 \u0627\u0644\u0645\u0637\u0644 \u0639\u0644\u0649 \u062e\u0644\u064a\u062c \u0646\u064a\u0648\u064a\u0648\u0631\u0643 \u0628\u0648\u0644\u0627\u064a\u0629 \u0646\u064a\u0648\u064a\u0648\u0631\u0643 \u0627\u0644\u0623\u0645\u0631\u064a\u0643\u064a\u0629 \u0644\u064a\u0643\u0648\u0646 \u0641\u064a \u0627\u0633\u062a\u0642\u0628\u0627\u0644 \u0643\u0644 \u0632\u0627\u0626\u0631\u064a \u0627\u0644\u0628\u0644\u0627\u062f \u0633\u0648\u0627\u0621 \u0643\u0627\u0646\u0648\u0627 \u0633\u0627\u0626\u062d\u064a\u0646 \u0623\u0648 \u0645\u0647\u0627\u062c\u0631\u064a\u0646. \u0642\u0627\u0645 \u0628\u062a\u0635\u0645\u064a\u0645\u0647 \u0641\u0631\u064a\u062f\u0631\u064a\u0643 \u0628\u0627\u0631\u062a\u0648\u0644\u062f\u064a \u0628\u064a\u0646\u0645\u0627 \u0635\u0645\u0645 \u0647\u064a\u0643\u0644\u0647 \u0627\u0644\u0625\u0646\u0634\u0627\u0626\u064a \u063a\u0648\u0633\u062a\u0627\u0641 \u0625\u064a\u0641\u0644.",
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://ga.dbpedia.org/resource/Dealbh_na_Saoirse"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/Artwork"
#                }
#             },
#             "http://dbpedia.org/property/designation1Free2value": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/List_of_World_Heritage_Sites_in_North_America"
#                }
#             },
#             "http://dbpedia.org/property/designation2Free1name": "Designated by",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Quote"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://archive.org/details/insearchoflibert00bell"
#                }
#             },
#             "http://dbpedia.org/property/photos": "404",
#             "http://dbpedia.org/property/id": "ny2026",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-74.04444122314453",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1025418457",
#             "http://dbpedia.org/property/dwgs": "41",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Manhattan"
#                }
#             },
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Statue_of_Liberty_-_4621961395.jpg?width=300"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "\uc790\uc720\uc758 \uc5ec\uc2e0\uc0c1(\u81ea\u7531\uc758 \u5973\u795e\u50cf, \uc601\uc5b4: Statue of Liberty \uc2a4\ud0dc\ucd94 \uc624\ube0c \ub9ac\ubc84\ud2f0 \uad6d\ub9bd\uae30\ub150\ubb3c[*], \ud504\ub791\uc2a4\uc5b4: Statue de la Libert\u00e9 \uc2a4\ud0c0\ud280 \ub4dc \ub77c \ub9ac\ubca0\ub974\ud14c[*])\uc740 \ubbf8\uad6d \ub274\uc695 \ub9ac\ubc84\ud2f0\uc12c\uc5d0 \uc788\ub294 \uac74\ucd95\ubb3c\ub85c, \ub274\uc695\uc744 \uc0c1\uc9d5\ud558\ub294 \ub300\ud45c\uc801\uc778 \uac74\ucd95\ubb3c\uc774\uba70, \uc138\uacc4\ub97c \ubc1d\ud788\ub294 \uc790\uc720(\uc601\uc5b4: Liberty Enlightening the World \ub9ac\ubc84\ud2f0 \uc778\ub77c\uc774\ud2b8\ub2dd \ub354 \uc6d4\ub4dc[*], \ud504\ub791\uc2a4\uc5b4: La libert\u00e9 \u00e9clairant le monde \ub77c \ub9ac\ubca0\ub974\ud14c \uc5d0\ud074\ub808\ub791 \ub974 \ubabd\ub4dc[*])\ub77c\ub294 \uc774\ub984\uc73c\ub85c, \ud504\ub791\uc2a4\uac00 19\uc138\uae30 \ub9d0\uc5d0 \ubbf8\uad6d\uc758 \ub3c5\ub9bd 100\uc8fc\ub144\uc744 \ucd95\ud558\ud558\uae30 \uc704\ud574 \uc81c\uc791\ud55c \ub3d9\uc0c1\uc774\ub2e4.",
#             "http://dbpedia.org/property/height": "",
#             "http://dbpedia.org/property/cap": "33",
#             "http://www.georss.org/georss/point": "40.689166666666665 -74.04444444444445",
#             "http://dbpedia.org/property/designation1Type": "Cultural",
#             "http://dbpedia.org/property/survey": "NY-138",
#             "http://dbpedia.org/property/designation5Number": "931",
#             "http://dbpedia.org/property/designation1Number": "307",
#             "http://dbpedia.org/property/designation": "NRHP",
#             "http://www.w3.org/2004/02/skos/core#exactMatch": {
#                "__deferred": {
#                   "uri": "http://globalwordnet.org/ili/i59504"
#                }
#             },
#             "http://dbpedia.org/property/governingBody": "U.S. National Park Service",
#             "http://dbpedia.org/property/designation1Free2name": "Region",
#             "http://xmlns.com/foaf/0.1/name": "Statue of Liberty",
#             "http://dbpedia.org/ontology/wikiPageLength": "113637",
#             "http://dbpedia.org/property/designation4Number": "1535",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "40.68916702270508",
#             "http://dbpedia.org/property/visitationNum": "3200000",
#             "http://dbpedia.org/property/designation3Number": "100000829",
#             "http://dbpedia.org/property/link": "no",
#             "http://dbpedia.org/property/website": {
#                "__deferred": {
#                   "uri": "https://www.nps.gov/stli"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#seeAlso": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Replicas_of_the_Statue_of_Liberty"
#                }
#             },
#             "http://dbpedia.org/property/designation3Date": "2017-09-14",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Sculpture"
#                }
#             },
#             "http://dbpedia.org/property/location": "New York, U.S.",
#             "http://dbpedia.org/property/designation5Date": "1976-09-14",
#             "http://dbpedia.org/property/name": "",
#             "http://dbpedia.org/property/designation1Free1value": "United States",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Statue_of_Liberty_-_4621961395.jpg"
#                }
#             },
#             "http://dbpedia.org/property/designation2Free1value": "President Calvin Coolidge",
#             "http://dbpedia.org/property/designation2Date": "1924-10-15",
#             "http://dbpedia.org/ontology/wikiPageID": "28617",
#             "http://dbpedia.org/property/restored": "19381984",
#             "http://dbpedia.org/property/beginningLabel": "Dedicated",
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "https://www.nps.gov/stli"
#                }
#             },
#             "http://dbpedia.org/property/designation3Offname": "The Statue of Liberty Enlightening the World",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-74.044441223145 40.689167022705)",
#             "http://dbpedia.org/property/colwidth": "20",
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-monument-noun-2"
#                }
#             },
#             "http://dbpedia.org/property/designation1Date": "1984",
#             "http://dbpedia.org/property/beginningDate": "1886-10-28",
#             "http://dbpedia.org/property/designation4Date": "1971-05-27",
#             "http://dbpedia.org/property/sculptor": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Fr\u00e9d\u00e9ric_Auguste_Bartholdi"
#                }
#             },
#             "http://dbpedia.org/property/visitationYear": "2009",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Statue_of_Liberty?oldid=1025418457&ns=0"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Statue_of_Liberty"
#                }
#             },
#             "http://dbpedia.org/property/mapCaption": "Location within New York City##Location within New York",
#             "http://dbpedia.org/property/designation5Type": "Individual",
#             "http://dbpedia.org/property/data": "10",
#             "http://dbpedia.org/property/designation1Criteria": "i, vi",
#             "http://dbpedia.org/property/designation4Offname": "Statue of Liberty National Monument, Ellis Island and Liberty Island",
#             "http://dbpedia.org/property/color": "59"
#          }
#       ],
#       "__count": "1"
#    }
# }
