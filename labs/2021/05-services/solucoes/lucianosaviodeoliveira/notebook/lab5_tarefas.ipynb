# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_drum = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_drum = requests.get(url_drum)
json_drum = data_drum.json()

print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
amado = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tenda dos milagres: " + amado)
# Out:
# Autor de Tenda dos milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Basilique Notre-Dame de Montréal"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 84262999,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 4320792,
#       "boundingbox": [
#          "45.504064",
#          "45.5048156",
#          "-73.5567165",
#          "-73.5552911"
#       ],
#       "lat": "45.50443735",
#       "lon": "-73.55599519109501",
#       "display_name": "Basilique Notre-Dame, Rue Saint-Sulpice, Vieux-Montr\u00e9al, Ville-Marie, Montr\u00e9al, Agglom\u00e9ration de Montr\u00e9al, Montr\u00e9al (06), Qu\u00e9bec, H2Y 2V8, Canada",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.9259422436998734,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    }
# ]

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 4320792

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1567623 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 4320792,
#          "timestamp": "2020-04-13T08:39:47Z",
#          "version": 14,
#          "changeset": 83461750,
#          "user": "snodnipper",
#          "uid": 99999,
#          "nodes": [
#             26235149,
#             1401388730,
#             1401388627,
#             1401388699,
#             1401388701,
#             1401388727,
#             26235150,
#             3470867556,
#             26235151,
#             26235148,
#             1401388674,
#             1401388724,
#             1401388653,
#             1401388684,
#             1401388700,
#             1401388649,
#             1401388677,
#             1401388650,
#             1401388723,
#             1401388703,
#             1401388728,
#             1401388725,
#             26235149
#          ],
#          "tags": {
#             "alt_name": "Notre-Dame Basilica",
#             "amenity": "place_of_worship",
#             "building": "church",
#             "denomination": "catholic",
#             "name": "Basilique Notre-Dame",
#             "name:en": "Notre-Dame Basilica",
#             "name:ko": "\ub178\ud2b8\ub974\ub2f4\ub300\uc131\ub2f9",
#             "religion": "christian",
#             "tourism": "attraction",
#             "wheelchair": "yes",
#             "wikidata": "Q887686",
#             "wikipedia": "en:Notre-Dame Basilica (Montreal)"
#          }
#       }
#    ]
# }

# %%
print(museum_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:Notre-Dame Basilica (Montreal)

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Notre-Dame_Basilica_(Montreal)"
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://hy.dbpedia.org/resource/\u0544\u0578\u0576\u0580\u0565\u0561\u056c\u056b_\u0531\u057d\u057f\u057e\u0561\u056e\u0561\u0574\u0578\u0580_\u057f\u0561\u0573\u0561\u0580"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "http://www.basiliquenddm.org/"
#                }
#             },
#             "http://dbpedia.org/property/imagesize": "280",
#             "http://www.w3.org/2000/01/rdf-schema#comment": "\u0643\u0646\u064a\u0633\u0629 \u0646\u0648\u062a\u0631\u062f\u0627\u0645 (\u0628\u0627\u0644\u0641\u0631\u0646\u0633\u064a\u0629: Basilique Notre-Dame de Montr\u00e9al)\u200f \u0647\u064a \u0628\u0627\u0632\u064a\u0644\u064a\u0643\u0627 \u062a\u0642\u0639 \u0641\u064a \u0645\u0646\u0637\u0642\u0629 \u0627\u0644\u062a\u0627\u0631\u064a\u062e\u064a\u0629 \u0641\u064a \u0645\u0648\u0646\u062a\u0631\u064a\u0627\u0644\u060c \u0643\u064a\u0628\u064a\u0643\u060c \u0643\u0646\u062f\u0627. \u062a\u0642\u0639 \u0627\u0644\u0643\u0646\u064a\u0633\u0629 \u0641\u064a 110 \u060c \u0639\u0646\u062f \u0632\u0627\u0648\u064a\u0629 \u0634\u0627\u0631\u0639 \u0633\u0627\u0646\u062a \u0633\u0648\u0644\u0628\u064a\u0633.\u0628\u0646\u064a\u062a \u0647\u0630\u0647 \u0627\u0644\u0643\u0646\u064a\u0633\u0629 \u0639\u0644\u0649 \u0646\u0645\u0637 \u0627\u0644\u0639\u0645\u0627\u0631\u0629 \u0627\u0644\u0642\u0648\u0637\u064a\u0629 \u0627\u0644\u062d\u062f\u064a\u062b\u0629\u060c \u0648\u0647\u064a \u0645\u0632\u062e\u0631\u0641\u0629 \u0628\u0643\u062b\u0627\u0641\u0629. \u0627\u0644\u062e\u0632\u0627\u0626\u0646 \u0645\u0644\u0648\u0646\u0629 \u0628\u0627\u0644\u0644\u0648\u0646 \u0627\u0644\u0623\u0632\u0631\u0642 \u0648\u0645\u0632\u064a\u0646\u0629 \u0628\u0646\u062c\u0648\u0645 \u0630\u0647\u0628\u064a\u0629\u060c \u0648\u0628\u0642\u064a\u0629 \u0627\u0644\u0647\u064a\u0643\u0644 \u0645\u0632\u064a\u0646\u0629 \u0628\u062f\u0631\u062c\u0627\u062a \u0627\u0644\u0644\u0648\u0646 \u0627\u0644\u0623\u0632\u0631\u0642 \u0648\u0627\u0644\u0623\u0632\u0648\u0631 \u0648\u0627\u0644\u0623\u062d\u0645\u0631 \u0648\u0627\u0644\u0623\u0631\u062c\u0648\u0627\u0646\u064a \u0648\u0627\u0644\u0641\u0636\u064a \u0648\u0627\u0644\u0630\u0647\u0628\u064a. \u0648\u0647\u064a \u0645\u0644\u064a\u0626\u0629 \u0628\u0645\u0626\u0627\u062a \u0627\u0644\u0645\u0646\u062d\u0648\u062a\u0627\u062a \u0627\u0644\u062e\u0634\u0628\u064a\u0629 \u0648\u0627\u0644\u0639\u062f\u064a\u062f \u0645\u0646 \u0627\u0644\u062a\u0645\u0627\u062b\u064a\u0644 \u0627\u0644\u062f\u064a\u0646\u064a\u0629. \u0632\u062c\u0627\u062c \u0627\u0644\u0646\u0648\u0627\u0641\u062f \u0647\u0648 \u0632\u062c\u0627\u062c \u0645\u0639\u0634\u0642 \u0648\u0647\u0648 \u063a\u064a\u0631 \u0627\u0639\u062a\u064a\u0627\u062f\u064a \u0641\u064a \u0627\u0644\u0643\u0646\u0627\u0626\u0633 \u0648\u062c\u062f\u0631\u0627\u0646 \u0627\u0644\u0647\u064a\u0643\u0626\u0644 \u0644\u0627 \u062a\u0635\u0648\u0631 \u0645\u0646\u0627\u0638\u0631 \u0645\u0646 \u0627\u0644\u0643\u062a\u0627\u0628 \u0627\u0644\u0645\u0642\u062f\u0633\u060c \u0644\u0643\u0646\u0647\u0627 \u062a\u0635\u0648\u0631 \u0645\u0634\u0627\u0647\u062f \u0645\u0646 \u0627\u0644\u062a\u0627\u0631\u064a\u062e \u0627\u0644\u062f\u064a\u0646\u064a \u0641\u064a \u0645\u0648\u0646\u062a\u0631\u064a\u0627\u0644. \u0643\u0645\u0627 \u064a\u0648\u062c\u062f \u0641\u064a \u0627\u0644\u0628\u0627\u0632\u064a\u0644\u064a\u0643\u0627 \u0623\u0631\u063a\u0648\u0646 \u0630\u0648 \u0623\u0646\u0627\u0628\u064a\u0628 \u064a\u0639\u0648\u062f \u062a\u0627\u0631\u064a\u062e\u0647 \u0644\u0639\u0627\u0645 1891\u060c \u0648\u064a\u062a\u0643\u0648\u0646 \u0645\u0646 \u0623\u0631\u0628\u0639 \u0644\u0648\u062d\u0627\u062a \u0645\u0641\u0627\u062a\u064a\u062d \u06487000 \u0623\u0646\u0628\u0648\u0628\u0627\u064b \u0641\u0631\u062f\u064a\u0627\u064b \u0648\u0644\u0648\u062d\u0629 \u062f\u0648\u0627\u0633\u0629.",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Gothic_Revival_church_buildings_in_Canada"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jean_Girard"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Basilique_Notre-Dame_de_Montreal_07.JPG"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "\u5723\u6bcd\u5723\u6bbf \uff08\u6cd5\u8a9e\uff1aBasilique Notre-Dame de Montr\u00e9al\uff0c\u82f1\u8a9e\uff1aNotre-Dame Basilica\uff09\u662f\u4e00\u5ea7\u7f57\u9a6c\u5929\u4e3b\u6559\u7684\u5b97\u5ea7\u5723\u6bbf\uff0c\u4f4d\u4e8e\u52a0\u62ff\u5927\u8499\u7279\u5229\u5c14\u8001\u57ce\u533a\u7684\u5723\u6bcd\u897f\u8857110\u53f7\uff0c\u4e0e\u5723\u53d9\u5c14\u76ae\u65af\u8857\u8f6c\u89d2\uff0c\u6bd7\u90bb\u5723\u53d9\u5c14\u76ae\u65af\u795e\u5b66\u9662\uff0c\u9762\u5bf9\u5175\u5668\u5e7f\u573a\uff08Place d&#39;Armes\uff09\u3002 \u5723\u6bcd\u5723\u6bbf\u4e3a\u54e5\u7279\u590d\u5174\u5f0f\u5efa\u7b51\uff0c\u5185\u90e8\u5b8f\u4f1f\uff0c\u8272\u5f69\u7eda\u4e3d\uff0c\u5929\u82b1\u677f\u4e3a\u6df1\u84dd\u8272\uff0c\u88c5\u9970\u91d1\u8272\u7684\u661f\u661f\uff0c\u5176\u4f59\u5730\u65b9\u84dd\u8272\uff0c\u7ea2\u8272\uff0c\u7d2b\u8272\uff0c\u94f6\u8272\u548c\u91d1\u8272\u3002\u5185\u90e8\u6709\u6570\u767e\u6728\u96d5\u3002\u4e0d\u5bfb\u5e38\u7684\u662f\uff0c\u82b1\u7a97\u73bb\u7483\u6ca1\u6709\u63cf\u7ed8\u5723\u7ecf\u7684\u573a\u666f\uff0c\u800c\u662f\u63cf\u7ed8\u8499\u7279\u5229\u5c14\u5b97\u6559\u5386\u53f2\u7684\u573a\u666f\u3002\u8fd8\u6709\u4e00\u53f0Casavant Fr\u00e8res\u7ba1\u98ce\u7434\u3002",
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Building102913152"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Infobox_church"
#                }
#             },
#             "http://dbpedia.org/ontology/architect": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/James_O'Donnell_(architect)"
#                }
#             },
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Notre-Dame_Street"
#                }
#             },
#             "http://dbpedia.org/property/constructionCost": "47446.0",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Notre-Dame van Montreal",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-73.556114196777 45.504444122314)",
#             "http://www.georss.org/georss/point": "45.504444444444445 -73.55611111111111",
#             "http://dbpedia.org/ontology/architecturalStyle": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Gothic_Revival_architecture"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1016160805",
#             "http://dbpedia.org/property/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Quebec"
#                }
#             },
#             "http://dbpedia.org/property/archdiocese": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Roman_Catholic_Archdiocese_of_Montreal"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Notre-Dame_Basilica_(Montreal)?oldid=1016160805&ns=0"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-73.55611419677734",
#             "http://dbpedia.org/property/pushpinMap": "Montreal",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/267047932"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "45.50444412231445",
#             "http://dbpedia.org/property/materials": "Stone, which came from the Tanneries quarry in Griffintown",
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://www.basiliquenddm.org/"
#                }
#             },
#             "http://dbpedia.org/property/caption": "The church building&#39;s exterior, 2012",
#             "http://dbpedia.org/property/denomination": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Catholic_Church"
#                }
#             },
#             "http://dbpedia.org/property/dedicatedDate": "1829-07-01",
#             "http://dbpedia.org/property/functionalStatus": "Active",
#             "http://dbpedia.org/property/status": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Basilicas_in_the_Catholic_Church"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "18452",
#             "http://dbpedia.org/property/name": "Notre-Dame Basilica",
#             "http://xmlns.com/foaf/0.1/page": {
#                "__deferred": {
#                   "uri": "http://www.basiliquenddm.org/"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Notre-Dame Basilica",
#             "http://dbpedia.org/property/groundbreaking": "1823",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Basilique_Notre-Dame_de_Montreal_07.JPG?width=300"
#                }
#             },
#             "http://dbpedia.org/property/style": "Gothic Revival, English Gothic",
#             "http://dbpedia.org/ontology/wikiPageID": "19185352",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Notre-Dame_Basilica_(Montreal)"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#differentFrom": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Notre-Dame_Church_(Montreal)"
#                }
#             },
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Basilica"
#                }
#             },
#             "http://dbpedia.org/property/nativeName": "Basilique Notre-Dame de Montr\u00e9al",
#             "http://dbpedia.org/property/website": {
#                "__deferred": {
#                   "uri": "http://www.basiliquenddm.org/"
#                }
#             },
#             "http://dbpedia.org/property/architect": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/James_O'Donnell_(architect)"
#                }
#             },
#             "http://dbpedia.org/property/dedication": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Mary,_mother_of_Jesus"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
