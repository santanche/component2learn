# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles (novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
tent_of_miracles_json = data.json()
print(json.dumps(tent_of_miracles_json, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
author = tent_of_miracles_json["d"]["results"][0]["http://dbpedia.org/property/author"]["__deferred"]["uri"]
print("Autor de Tenda dos Milagres: " + author)
# Out:
# Autor de Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Estádio Arena das Dunas"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
arena_das_dunas_ref = data.json()
print(json.dumps(arena_das_dunas_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 258548143,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 3821148,
#       "boundingbox": [
#          "-5.8285405",
#          "-5.8246811",
#          "-35.2143691",
#          "-35.2109123"
#       ],
#       "lat": "-5.8265949500000005",
#       "lon": "-35.21262831075757",
#       "display_name": "Arena das Dunas, 5121, Avenida Prudente de Morais, Lagoa Nova, Regi\u00e3o Sul, Natal, Regi\u00e3o Geogr\u00e1fica Imediata de Natal, Regi\u00e3o Geogr\u00e1fica Intermedi\u00e1ria de Natal, Rio Grande do Norte, Regi\u00e3o Nordeste, 59064-625, Brasil",
#       "class": "leisure",
#       "type": "stadium",
#       "importance": 0.744556447945316
#    }
# ]

# %%
print(arena_das_dunas_ref[0]["osm_id"])
# Out:
# 3821148

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "relation" # types: node, way, or relation
id = str(arena_das_dunas_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
arena_das_dunas_relation = data.json()
print(json.dumps(arena_das_dunas_relation, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1247579 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "relation",
#          "id": 3821148,
#          "timestamp": "2020-02-18T11:12:10Z",
#          "version": 8,
#          "changeset": 81166600,
#          "user": "annakulikowa",
#          "uid": 8987605,
#          "members": [
#             {
#                "type": "way",
#                "ref": 288083067,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 288083063,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 288083068,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 288083071,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 288083069,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 288083064,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 288083065,
#                "role": "outer"
#             }
#          ],
#          "tags": {
#             "addr:city": "Natal",
#             "addr:housenumber": "5121",
#             "addr:postcode": "59064-625",
#             "addr:street": "Avenida Prudente de Morais",
#             "addr:suburb": "Lagoa Nova",
#             "capacity": "45.000",
#             "leisure": "stadium",
#             "name": "Arena das Dunas",
#             "sport": "soccer",
#             "type": "multipolygon",
#             "website": "https://arenadunas.com.br/",
#             "wikidata": "Q1343986",
#             "wikipedia": "pt:Arena das Dunas"
#          }
#       }
#    ]
# }

# %%
print(arena_das_dunas_relation["elements"][0]["tags"]["wikipedia"])
# Out:
# pt:Arena das Dunas

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = arena_das_dunas_relation["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("pt:", "")
format = "json"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
arena_das_dunas_dbpedia = data.json()
print(json.dumps(arena_das_dunas_dbpedia, indent=3))
# Out:
# {
#    "http://dbpedia.org/resource/List_of_international_goals_scored_by_Marta": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Greece_national_football_team_results_(2000\u20132019)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/List_of_international_goals_scored_by_Christine_Sinclair": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Brazil_national_football_team_results_(2010\u20132019)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2017_Copa_do_Brasil_First_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2019_Copa_do_Brasil_First_Stage": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2019_Copa_do_Brasil_Second_Stage": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Andr\u00e9_Ayew": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Nichelle_Prince": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Am\u00e9rica_Futebol_Clube_(RN)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/ground": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/ground": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2016_Clube_do_Remo_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2021_Copa_do_Brasil_second_round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_in_American_soccer": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Jos\u00e9_Juan_V\u00e1zquez": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/List_of_international_goals_scored_by_Neymar": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Ghana_national_football_team_results_(2010\u20132019)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Greece_at_the_FIFA_World_Cup": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Natal,_Rio_Grande_do_Norte": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Katie_Johnson_(footballer)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Marco_Antonio_Rodr\u00edguez": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Oribe_Peralta": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Cameroon_at_the_FIFA_World_Cup": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Santa_Cruz_Futebol_Clube_(RN)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/ground": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/ground": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Filipe_Lu\u00eds": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/M\u00f4nica_Hickmann_Alves": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/List_of_international_goals_scored_by_Clint_Dempsey": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup_Group_G": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Estrela": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://en.wikipedia.org/wiki/Arena_das_Dunas": {
#       "http://xmlns.com/foaf/0.1/primaryTopic": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Japan_national_football_team_results_(2010\u20132019)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Japan_national_football_team": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_in_Japanese_football": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup_bids": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Allianz_Parque": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Diego_God\u00edn": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/List_of_FIFA_World_Cup_stadiums": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Ghana_at_the_FIFA_World_Cup": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/List_of_stadiums_by_capacity": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/John_Brooks_(soccer,_born_1993)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/United_States_men's_national_soccer_team_results_(2010\u20132019)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Mexico_national_football_team_schedule_and_results": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Kyle_Beckerman": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Italy_national_football_team_results_(2010\u2013present)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Best_Moment_ESPY_Award": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Space_frame": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Janine_Beckie": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Gabriel_Jesus": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Arena_das_Dunas": {
#       "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Scene108645963"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Region108630985"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/YagoGeoEntity"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/YagoLegalActorGeo"
#          },
#          {
#             "type": "uri",
#             "value": "http://www.w3.org/2002/07/owl#Thing"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Area108497294"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Whole100003553"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Stadium104295881"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/ontology/Place"
#          },
#          {
#             "type": "uri",
#             "value": "http://schema.org/Place"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/ontology/Stadium"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/ontology/Venue"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/ontology/Location"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/WikicatSportsVenuesInRioGrandeDoNorte"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Structure104341686"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Artifact100021939"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/ontology/ArchitecturalStructure"
#          },
#          {
#             "type": "uri",
#             "value": "http://www.w3.org/2003/01/geo/wgs84_pos#SpatialThing"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/ontology/Building"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Wikicat2014FIFAWorldCupStadiums"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Venue108677628"
#          },
#          {
#             "type": "uri",
#             "value": "http://www.wikidata.org/entity/Q41176"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/WikicatFootballVenuesInBrazil"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Location100027167"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/Object100002684"
#          },
#          {
#             "type": "uri",
#             "value": "http://umbel.org/umbel/rc/Stadium"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/WikicatStadiumsUnderConstruction"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/class/yago/PhysicalEntity100001930"
#          }
#       ],
#       "http://www.w3.org/2000/01/rdf-schema#label": [
#          {
#             "type": "literal",
#             "value": "\u6c99\u4e18\u7af6\u6280\u5834",
#             "lang": "zh"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "sv"
#          },
#          {
#             "type": "literal",
#             "value": "\u0391\u03c1\u03ad\u03bd\u03b1 \u03bd\u03c4\u03b1\u03c2 \u039d\u03c4\u03bf\u03cd\u03bd\u03b1\u03c2",
#             "lang": "el"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "ga"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "it"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "in"
#          },
#          {
#             "type": "literal",
#             "value": "\u0410\u0440\u0435\u043d\u0430 \u0434\u0430\u0441 \u0414\u0443\u043d\u0430\u0441",
#             "lang": "ru"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "cs"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "fr"
#          },
#          {
#             "type": "literal",
#             "value": "\u0410\u0440\u0435\u043d\u0430 \u0434\u0430\u0441 \u0414\u0443\u043d\u0430\u0441",
#             "lang": "uk"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "es"
#          },
#          {
#             "type": "literal",
#             "value": "\u30a2\u30ec\u30fc\u30ca\u30fb\u30c0\u30b9\u30fb\u30c9\u30a5\u30fc\u30ca\u30b9",
#             "lang": "ja"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "ca"
#          },
#          {
#             "type": "literal",
#             "value": "\u0645\u0644\u0639\u0628 \u0622\u0631\u064a\u0646\u0627 \u062f\u0627\u0633 \u062f\u0648\u0646\u0627\u0633",
#             "lang": "ar"
#          },
#          {
#             "type": "literal",
#             "value": "\uc544\ub808\ub098 \ub2e4\uc2a4 \ub450\ub098\uc2a4",
#             "lang": "ko"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "pl"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "nl"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "pt"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "en"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "de"
#          }
#       ],
#       "http://www.w3.org/2000/01/rdf-schema#comment": [
#          {
#             "type": "literal",
#             "value": "\u0645\u0644\u0639\u0628 \u0622\u0631\u064a\u0646\u0627 \u062f\u0627\u0633 \u062f\u0648\u0646\u0627\u0633 \u0647\u0648 \u0645\u0644\u0639\u0628 \u0644\u0643\u0631\u0629 \u0627\u0644\u0642\u062f\u0645 \u0627\u0644\u062a\u064a \u0635\u0645\u0645\u0647\u0627 \u0634\u0631\u0643\u0629 \u0628\u0648\u0628\u0648\u0644\u0648\u0633(\u0633\u0627\u0628\u0642\u0627 \u0647\u0648\u0643 \u0633\u0628\u0648\u0631\u062a \u0627\u0644\u0645\u0644\u0639\u0628 \u0627\u0644\u062d\u062f\u062b) \u0648\u0627\u0644\u0630\u064a \u0633\u064a\u062a\u0645 \u0628\u0646\u0627\u0626\u0647 \u0641\u064a \u064a\u0646\u0627\u064a\u0631 2011 \u0644\u0625\u0633\u062a\u0636\u0627\u0641\u0629 \u0645\u0628\u0627\u0631\u064a\u0627\u062a \u0628\u0637\u0648\u0644\u0629 \u0643\u0623\u0633 \u0627\u0644\u0639\u0627\u0644\u0645 \u0644\u0643\u0631\u0629 \u0627\u0644\u0642\u062f\u0645 2014 \u0628\u0627\u0644\u0628\u0631\u0627\u0632\u064a\u0644. \n* \u0648\u064a\u062c\u0631\u064a \u0628\u0646\u0627\u0624\u0647 \u0641\u064a \u0645\u062f\u064a\u0646\u0629 \u0646\u0627\u062a\u0627\u0644 \u0641\u064a \u0648\u0644\u0627\u064a\u0629 \u0631\u064a\u0648 \u063a\u0631\u0627\u0646\u062f\u064a \u062f\u0648 \u0646\u0648\u0631\u062a\u064a. \u0627\u0644\u0645\u0644\u0639\u0628 \u0648\u0645\u0646 \u0627\u0644\u0645\u0642\u0631\u0631 \u0623\u0646 \u064a\u062a\u0645 \u0628\u0646\u0627\u0624\u0647 \u0641\u064a \u0645\u0643\u0627\u0646 \u0627\u0644\u0645\u0644\u0639\u0628 \u0645\u0634\u0627\u062f\u0627\u0648\u0648\u060c \u0648\u0627\u0644\u062a\u064a \u0633\u064a\u062a\u0645 \u0647\u062f\u0645 \u0627\u0644\u0645\u0628\u0627\u0646\u064a \u0641\u064a\u0647 \u0639\u0627\u0645 2011. \n* \u0647\u0630\u0627 \u0627\u0644\u0645\u0634\u0631\u0648\u0639 \u064a\u062d\u0644 \u0645\u062d\u0644 \u0627\u0644\u0645\u0634\u0631\u0648\u0639 \u0627\u0644\u0642\u062f\u064a\u0645 \u0627\u0644\u0630\u064a \u064a\u0633\u0645\u0649 \"\u0645\u0644\u0639\u0628 \u0625\u0633\u062a\u0631\u064a\u0644\u0627 \u062f\u0648\u0633 \u0631\u064a\u064a\u0633 \u0645\u0627\u062c\u0648\u0633\"\u0648 \u0627\u0644\u062a\u064a \u0645\u0646 \u0634\u0623\u0646\u0647\u0627 \u0623\u0646 \u062a\u0643\u0648\u0646 \u0645\u0648\u062c\u0648\u062f\u0629 \u0641\u064a \u0628\u0644\u062f\u064a\u0629 \u0627\u0644\u0645\u062c\u0627\u0648\u0631\u0629 \u0628\u0627\u0631\u0646\u0627\u0645\u064a\u0631\u064a\u0645\u060c \u0648\u0641\u064a \u0647\u0630\u0627 \u0627\u0644\u0645\u0634\u0631\u0648\u0639 \u0627\u0644\u062c\u062f\u064a\u062f\u060c \u0633\u0648\u0641 \u062a\u0635\u0628\u062d \u0642\u062f\u0631\u0629 \u0627\u0644\u0645\u0644\u0639\u0628 \u0627\u0644\u062c\u062f\u064a\u062f 45.000 \u0645\u062a\u0641\u0631\u062c. \u0648\u0633\u064a\u062a\u0645 \u0628\u0646\u0627\u0621 \u0645\u0628\u0627\u0646\u064a \u062a\u062c\u0627\u0631\u064a\u0629 \u0648\u0645\u0631\u0627\u0643\u0632 \u062a\u0633\u0648\u0642 \u0648\u0633\u064a\u062a\u0645 \u0628\u0646\u0627\u0621 \u0641\u0646\u0627\u062f\u0642 \u0630\u0627 \u0627\u0644\u0639\u0644\u0627\u0645\u0629 \u0627\u0644\u062f\u0648\u0644\u064a\u0629\u060c \u0648\u0628\u062d\u064a\u0631\u0629 \u0627\u0635\u0637\u0646\u0627\u0639\u064a\u0629 \u0641\u064a \u0623\u0631\u062c\u0627\u0621 \u0627\u0644\u0645\u0644\u0639\u0628.",
#             "lang": "ar"
#          },
#          {
#             "type": "literal",
#             "value": "Die Arena das Dunas ist ein Fu\u00dfballstadion in der brasilianischen Stadt Natal. Es wurde f\u00fcr die Fu\u00dfball-Weltmeisterschaft 2014 gebaut und wird heute haupts\u00e4chlich vom Fu\u00dfballverein Am\u00e9rica FC genutzt. Die Arena steht ca. 3 km s\u00fcdlich der Innenstadt im Ortsteil direkt an der Bundesstra\u00dfe BR-101 und bietet Pl\u00e4tze f\u00fcr rund 35.000 Zuschauer.",
#             "lang": "de"
#          },
#          {
#             "type": "literal",
#             "value": "\u00ab\u0410\u0440\u0435\u043d\u0430 \u0434\u0430\u0441 \u0414\u0443\u043d\u0430\u0441\u00bb (\u043f\u043e\u0440\u0442. Arena das Dunas) \u0430\u0431\u043e \u00ab\u0414\u0443\u043d\u0430\u0441 \u0410\u0440\u0435\u043d\u0430\u00bb \u2014 \u0444\u0443\u0442\u0431\u043e\u043b\u044c\u043d\u0438\u0439 \u0441\u0442\u0430\u0434\u0456\u043e\u043d \u0443 \u041d\u0430\u0442\u0430\u043b\u0456, \u0420\u0456\u0443-\u0413\u0440\u0430\u043d\u0434\u0456-\u0434\u0443-\u041d\u043e\u0440\u0442\u0456, \u0411\u0440\u0430\u0437\u0438\u043b\u0456\u044f. \u0422\u0443\u0442 \u043f\u0440\u043e\u0445\u043e\u0434\u0438\u043b\u0438 \u043c\u0430\u0442\u0447\u0456 \u0427\u0435\u043c\u043f\u0456\u043e\u043d\u0430\u0442\u0443 \u0441\u0432\u0456\u0442\u0443 \u0437 \u0444\u0443\u0442\u0431\u043e\u043b\u0443 2014.",
#             "lang": "uk"
#          },
#          {
#             "type": "literal",
#             "value": "The Arena das Dunas (\"Dunes Arena\") is a football stadium in Natal, Brazil. The arena can shelter 31,375 spectators, and was designed by sports architect Christopher Lee of Populous. The stadium hosted football matches for the 2014 FIFA World Cup held in Brazil. During the tournament, it had a seating capacity of 42,000. It was built in place of the Machad\u00e3o, which was demolished in 2011.",
#             "lang": "en"
#          },
#          {
#             "type": "literal",
#             "value": "\uc544\ub808\ub098 \ub2e4\uc2a4 \ub450\ub098\uc2a4(\ud3ec\ub974\ud22c\uac08\uc5b4: Arena das Dunas)\ub294 \ube0c\ub77c\uc9c8 \ud788\uc6b0\uadf8\ub780\uc9c0\ub450\ub178\ub974\uce58\uc8fc \ub098\ud0c0\uc6b0\uc5d0 \uc704\uce58\ud55c \uacbd\uae30\uc7a5\uc73c\ub85c, \uc544\uba54\ub9ac\uce74 FC\uc758 \ud648 \uad6c\uc7a5\uc73c\ub85c \uc0ac\uc6a9\ub418\uace0 \uc788\ub2e4. 2014\ub144 FIFA \uc6d4\ub4dc\ucef5 \uacbd\uae30\uac00 \uc5f4\ub9b4 \uacbd\uae30\uc7a5\uc73c\ub85c \uc120\uc815\ub418\uc5c8\uc73c\uba70 2014\ub144 1\uc6d4 26\uc77c\uc5d0 \uac1c\uc7a5\ud558\uc600\ub2e4.",
#             "lang": "ko"
#          },
#          {
#             "type": "literal",
#             "value": "De Arena das Dunas of Dunas Arena is een voetbalstadion in Braziliaanse stad Natal, de hoofdstad van Rio Grande do Norte. Het stadion werd speciaal gebouwd voor het wereldkampioenschap voetbal 2014. De werken begonnen in 2011. Het stadion werd gebouwd op de plaats waar het voormalige Machad\u00e3o stond, dat begin 2011 werd gesloopt. Arena das Dunas biedt plaats aan 45.000 toeschouwers en werd gebruikt voor vier duels in de groepsfase van het WK 2014. De wedstrijd tussen de Verenigde Staten en Ghana (2\u20131) werd uiteindelijk het best bezocht.",
#             "lang": "nl"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas (svenska: Sanddynsarenan) \u00e4r en fotbollsarena i Natal, Brasilien. Arenan \u00e4r en av v\u00e4rdarenorna f\u00f6r v\u00e4rldsm\u00e4sterskapet i fotboll 2014. Den b\u00f6rjade byggas i januari 2011 och blev f\u00e4rdigst\u00e4lld samma m\u00e5nad 2014.",
#             "lang": "sv"
#          },
#          {
#             "type": "literal",
#             "value": "La Arena das Dunas es un estadio multiusos localizado en la ciudad de Natal, capital del estado de Rio Grande do Norte, Brasil. Su construcci\u00f3n se inici\u00f3 15 de agosto de 2011 y se termin\u00f3 el 19 de enero de 2014, con el fin de acoger algunos partidos de la Copa Mundial de F\u00fatbol de 2014 que se llev\u00f3 a cabo en Brasil.\u200b Actualmente juega all\u00ed el club Am\u00e9rica de Natal. El Am\u00e9rica de Natal juega de local en el estadio desde enero de 2014. El ABC tambi\u00e9n jug\u00f3 all\u00ed en la temporada 2014. Por su parte, el club carioca Flamengo jug\u00f3 all\u00ed un partido de local en el Brasileir\u00e3o 2015 y uno en 2016.",
#             "lang": "es"
#          },
#          {
#             "type": "literal",
#             "value": "\u03a4\u03bf \u0391\u03c1\u03ad\u03bd\u03b1 \u03bd\u03c4\u03b1\u03c2 \u039d\u03c4\u03bf\u03cd\u03bd\u03b1\u03c2 (\u03c0\u03bf\u03c1\u03c4\u03bf\u03b3\u03b1\u03bb\u03b9\u03ba\u03ac: Arena das Dunas) \u03b5\u03af\u03bd\u03b1\u03b9 \u03ad\u03bd\u03b1 \u03c0\u03bf\u03b4\u03bf\u03c3\u03c6\u03b1\u03b9\u03c1\u03b9\u03ba\u03cc \u03b3\u03ae\u03c0\u03b5\u03b4\u03bf \u03c3\u03c4\u03bf \u039d\u03b1\u03c4\u03ac\u03bb \u03c4\u03b7\u03c2 \u0392\u03c1\u03b1\u03b6\u03b9\u03bb\u03af\u03b1\u03c2. \u0391\u03bd\u03b1\u03ba\u03b1\u03c4\u03b1\u03c3\u03ba\u03b5\u03c5\u03ac\u03c3\u03c4\u03b7\u03ba\u03b5 \u03b3\u03b9\u03b1 \u03bd\u03b1 \u03c6\u03b9\u03bb\u03bf\u03be\u03b5\u03bd\u03ae\u03c3\u03b5\u03b9 \u03b1\u03b3\u03ce\u03bd\u03b5\u03c2 \u03c4\u03bf\u03c5 \u03a0\u03b1\u03b3\u03ba\u03cc\u03c3\u03bc\u03b9\u03bf\u03c5 \u039a\u03c5\u03c0\u03ad\u03bb\u03bb\u03bf\u03c5 \u03a0\u03bf\u03b4\u03bf\u03c3\u03c6\u03b1\u03af\u03c1\u03bf\u03c5 2014 \u03ba\u03b1\u03b9 \u03b7 \u03b1\u03bd\u03b1\u03ba\u03b1\u03c4\u03b1\u03c3\u03ba\u03b5\u03c5\u03ae \u03c4\u03bf\u03c5 \u03ba\u03cc\u03c3\u03c4\u03b9\u03c3\u03b5 423.000.000 \u03a1\u03b5\u03ac\u03bb \u0392\u03c1\u03b1\u03b6\u03b9\u03bb\u03af\u03b1\u03c2. \u0395\u03c0\u03af\u03c3\u03b7\u03c2 \u03b5\u03af\u03bd\u03b1\u03b9 \u03b7 \u03ad\u03b4\u03c1\u03b1 \u03c4\u03c9\u03bd \u03ba\u03b1\u03b9 .",
#             "lang": "el"
#          },
#          {
#             "type": "literal",
#             "value": "\u30a2\u30ec\u30fc\u30ca\u30fb\u30c0\u30b9\u30fb\u30c9\u30a5\u30fc\u30ca\u30b9\uff08Arena das Dunas\uff09\u306f\u30d6\u30e9\u30b8\u30eb\u30fb\u30ea\u30aa\u30b0\u30e9\u30f3\u30c7\u30fb\u30c9\u30fb\u30ce\u30eb\u30c6\u5dde\u306e\u30ca\u30bf\u30fc\u30eb\u306b\u3042\u308b\u30b9\u30bf\u30b8\u30a2\u30e0\u30022014 FIFA\u30ef\u30fc\u30eb\u30c9\u30ab\u30c3\u30d7\u306e\u8a66\u5408\u4f1a\u5834\u3068\u3057\u3066\u4f7f\u7528\u3055\u308c\u305f\u3002\u5730\u5143\u30a2\u30e1\u30ea\u30abFC\u306e\u30db\u30fc\u30e0\u30b9\u30bf\u30b8\u30a2\u30e0\u3068\u3057\u3066\u3082\u4f7f\u308f\u308c\u308b\u4e88\u5b9a\u3002",
#             "lang": "ja"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas je v\u00edce\u00fa\u010delov\u00fd stadion v brazilsk\u00e9m m\u011bst\u011b Natal. V sou\u010dasnosti je nejv\u00edce vyu\u017e\u00edv\u00e1n pro fotbal. Byl otev\u0159en v roce 2014 a jeho kapacita je 42 000 div\u00e1k\u016f. Byl vystav\u011bn pro Mistrovstv\u00ed sv\u011bta 2014, v jeho\u017e r\u00e1mci se na n\u011bm hr\u00e1ly \u010dty\u0159i z\u00e1pasy z\u00e1kladn\u00edch skupin.",
#             "lang": "cs"
#          },
#          {
#             "type": "literal",
#             "value": "Staidiam sp\u00f3irt i Natal, an Bhrasa\u00edl is ea Arena das Dunas . T\u00e1 s\u00e9 suite i Natal. Toilleann an staidiam 45,000 duine.",
#             "lang": "ga"
#          },
#          {
#             "type": "literal",
#             "value": "\u6c99\u4e18\u7af6\u6280\u5834\uff08\u8461\u8404\u7259\u8a9e\uff1aArena das Dunas\uff09\uff0c\u4f4d\u65bc\u5df4\u897f\u7d0d\u5854\u723e\u3001\u70ba\u8209\u8fa62014\u5e74\u4e16\u754c\u676f\u800c\u5efa\u7684\u8db3\u7403\u5834\u3002\u8a72\u7403\u5834\u65bc2011\u5e741\u6708\u52d5\u5de5\uff0c\u4e26\u80fd\u5bb9\u7d0d42,086\u4eba\uff0c\u5728\u4e16\u754c\u676f\u671f\u9593\uff0c\u8a72\u7403\u5834\u6703\u627f\u8fa64\u5834\u7684\u5206\u7d44\u8cfd\u3002",
#             "lang": "zh"
#          },
#          {
#             "type": "literal",
#             "value": "L'Arena das Dunas \u00e9s un estadi de futbol que es va comen\u00e7ar el gener de 2011 per acollir partits de la Copa del M\u00f3n de Futbol de 2014 que es duran a terme al Brasil.L'estadi va ser dissenyat per l'empresa Populous. Va ser constru\u00eft a trav\u00e9s d'una col\u00b7laboraci\u00f3 p\u00fablico privada al lloc de l'anterior que va ser demolit per donar pas a aquest complex.Es va construir a Natal, capital de l'estat de Rio Grande do Norte, Brasil.",
#             "lang": "ca"
#          },
#          {
#             "type": "literal",
#             "value": "L'Arena das Dunas o Dunas Arena \u00e8 uno stadio di calcio situato nella citt\u00e0 di Natal in Brasile. Lo stadio \u00e8 stato disegnato dal team di architetti Populous e la sua costruzione \u00e8 iniziata a gennaio 2011. Lo stadio sorge dove un tempo si ergevano lo Stadio Machad\u00e3o e la palestra Machadinho che sono stati demoliti nel 2011 proprio per fare posto al nuovo edificio. Questo progetto \u00e8 stato inoltre uno dei pi\u00f9 lodati dagli ispettori FIFA. Dalla fine del mondiale lo stadio versa in uno stato di totale disuso tanto da essere stato messo in vendita dalla societ\u00e0 che lo ha in gestione, la OAS.",
#             "lang": "it"
#          },
#          {
#             "type": "literal",
#             "value": "L'Arena das Dunas est un stade construit sp\u00e9cialement pour la coupe du monde de football de 2014, situ\u00e9 dans la ville de Natal dans le Rio Grande do Norte au Br\u00e9sil.",
#             "lang": "fr"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas \u2013 stadion pi\u0142karski w Natal, Rio Grande do Norte, w Brazylii, na kt\u00f3rym swoje mecze rozgrywaj\u0105 kluby Alecrim Natal i Am\u00e9rica Natal. Obiekt jest jedn\u0105 z aren pi\u0142karskich Mistrzostw \u015awiata 2014. Stadion powsta\u0142 w miejscu by\u0142ego Est\u00e1dio Machad\u00e3o.",
#             "lang": "pl"
#          },
#          {
#             "type": "literal",
#             "value": "\u00ab\u0410\u0440\u0435\u043d\u0430 \u0434\u0430\u0441 \u0414\u0443\u043d\u0430\u0441\u00bb (\u043f\u043e\u0440\u0442. Arena das Dunas) \u0438\u043b\u0438 \u0414\u0443\u043d\u0430\u0441 \u0410\u0440\u0435\u043d\u0430 \u2014 \u0444\u0443\u0442\u0431\u043e\u043b\u044c\u043d\u044b\u0439 \u0441\u0442\u0430\u0434\u0438\u043e\u043d \u0432 \u0411\u0440\u0430\u0437\u0438\u043b\u0438\u0438, \u043f\u0440\u043e\u0435\u043a\u0442 \u043a\u043e\u0442\u043e\u0440\u043e\u0433\u043e \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0430\u043d \u043a\u043e\u043c\u043f\u0430\u043d\u0438\u0435\u0439 Populous. \u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u043e \u0441\u0442\u0430\u0434\u0438\u043e\u043d\u0430 \u043d\u0430\u0447\u0430\u043b\u043e\u0441\u044c \u0432 \u044f\u043d\u0432\u0430\u0440\u0435 2011 \u0433\u043e\u0434\u0430. \u0420\u0430\u0441\u043f\u043e\u043b\u043e\u0436\u0435\u043d \u0432 \u0433\u043e\u0440\u043e\u0434\u0435 \u041d\u0430\u0442\u0430\u043b, \u0441\u0442\u043e\u043b\u0438\u0446\u0435 \u0448\u0442\u0430\u0442\u0430 \u0420\u0438\u0443-\u0413\u0440\u0430\u043d\u0434\u0438-\u0434\u0443-\u041d\u043e\u0440\u0442\u0438. \u0421\u0442\u0430\u0434\u0438\u043e\u043d \u043f\u043e\u0441\u0442\u0440\u043e\u0435\u043d \u043d\u0430 \u043c\u0435\u0441\u0442\u0435 \u0441\u0442\u0430\u0434\u0438\u043e\u043d\u0430 \u00ab\u00bb \u0438 \u0442\u0440\u0435\u043d\u0430\u0436\u0435\u0440\u043d\u043e\u0433\u043e \u0437\u0430\u043b\u0430 \u00ab\u00bb. \u0421\u0442\u0430\u0434\u0438\u043e\u043d \u0440\u0430\u0441\u043f\u043e\u043b\u043e\u0436\u0435\u043d \u043d\u0430 \u0430\u0432\u0435\u043d\u0438\u0434\u0435 \u0421\u0435\u043d\u0430\u0434\u043e\u0440 \u0421\u0430\u043b\u0433\u0430\u0434\u043e \u0424\u0438\u043b\u0443 (\u0448\u043e\u0441\u0441\u0435 ). \u041f\u0440\u043e\u0435\u043a\u0442 \u043f\u043e\u043b\u0443\u0447\u0438\u043b \u043e\u0434\u043d\u0443 \u0438\u0437 \u043d\u0430\u0438\u0431\u043e\u043b\u0435\u0435 \u0432\u044b\u0441\u043e\u043a\u0438\u0445 \u043e\u0446\u0435\u043d\u043e\u043a \u043e\u0442 \u0438\u043d\u0441\u043f\u0435\u043a\u0442\u043e\u0440\u0430 \u0424\u0418\u0424\u0410.",
#             "lang": "ru"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas adalah stadion sepak bola dan kompleks serbaguna yang sedang dalam tahap pembangunan di kota Natal, di negara bagian Brasil, Rio Grande do Norte. Stadion ini terletak di distrik , antara BR-101 dan Avenida de Morais Prudente, dua jalan arteri utama kota.",
#             "lang": "in"
#          },
#          {
#             "type": "literal",
#             "value": "Arena das Dunas (ou Arena Marinho Chagas) \u00e9 um est\u00e1dio multiuso localizado na cidade de Natal, no estado brasileiro do Rio Grande do Norte. Al\u00e9m de partidas de futebol, o complexo tem a capacidade de abrigar eventos de grande porte, exposi\u00e7\u00f5es e lojas comerciais. A estrutura foi inaugurada em 22 de janeiro de 2014, depois de 29 meses de obras, no lugar do Est\u00e1dio Jo\u00e3o Machado. \u00c9 gerenciada pela OAS Arenas.",
#             "lang": "pt"
#          }
#       ],
#       "http://xmlns.com/foaf/0.1/name": [
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "en"
#          }
#       ],
#       "http://xmlns.com/foaf/0.1/homepage": [
#          {
#             "type": "uri",
#             "value": "http://www.arenadunas.com.br/"
#          }
#       ],
#       "http://www.w3.org/2003/01/geo/wgs84_pos#lat": [
#          {
#             "type": "literal",
#             "value": -5.826935768127441,
#             "datatype": "http://www.w3.org/2001/XMLSchema#float"
#          }
#       ],
#       "http://www.w3.org/2003/01/geo/wgs84_pos#long": [
#          {
#             "type": "literal",
#             "value": -35.21237182617188,
#             "datatype": "http://www.w3.org/2001/XMLSchema#float"
#          }
#       ],
#       "http://xmlns.com/foaf/0.1/depiction": [
#          {
#             "type": "uri",
#             "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Natal,_Brazil_-_Arena_das_Dunas.jpg"
#          }
#       ],
#       "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": [
#          {
#             "type": "uri",
#             "value": "http://en.wikipedia.org/wiki/Arena_das_Dunas"
#          }
#       ],
#       "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": [
#          {
#             "type": "literal",
#             "value": "POINT(-35.212371826172 -5.8269357681274)",
#             "datatype": "http://www.openlinksw.com/schemas/virtrdf#Geometry"
#          }
#       ],
#       "http://purl.org/dc/terms/subject": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Category:2014_establishments_in_Brazil"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Category:Sports_venues_completed_in_2014"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Category:Football_venues_in_Rio_Grande_do_Norte"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Category:Sports_venues_in_Rio_Grande_do_Norte"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Category:2014_FIFA_World_Cup_stadiums"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Category:Lagoa_Nova"
#          }
#       ],
#       "http://www.w3.org/2002/07/owl#sameAs": [
#          {
#             "type": "uri",
#             "value": "http://ja.dbpedia.org/resource/\u30a2\u30ec\u30fc\u30ca\u30fb\u30c0\u30b9\u30fb\u30c9\u30a5\u30fc\u30ca\u30b9"
#          },
#          {
#             "type": "uri",
#             "value": "http://sv.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://de.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://zh.dbpedia.org/resource/\u6c99\u4e18\u7af6\u6280\u5834"
#          },
#          {
#             "type": "uri",
#             "value": "https://global.dbpedia.org/id/MDRC"
#          },
#          {
#             "type": "uri",
#             "value": "http://pt.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://lt.dbpedia.org/resource/Das_Dunas_arena"
#          },
#          {
#             "type": "uri",
#             "value": "http://fr.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://ru.dbpedia.org/resource/\u0410\u0440\u0435\u043d\u0430_\u0434\u0430\u0441_\u0414\u0443\u043d\u0430\u0441"
#          },
#          {
#             "type": "uri",
#             "value": "http://fi.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://ms.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://rdf.freebase.com/ns/m.03cnvzp"
#          },
#          {
#             "type": "uri",
#             "value": "http://af.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://hi.dbpedia.org/resource/\u090f\u0930\u093f\u0928\u093e_\u0926\u093e\u0938_\u0926\u0942\u0928\u093e\u0938"
#          },
#          {
#             "type": "uri",
#             "value": "http://no.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://yago-knowledge.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://bs.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://el.dbpedia.org/resource/\u0391\u03c1\u03ad\u03bd\u03b1_\u03bd\u03c4\u03b1\u03c2_\u039d\u03c4\u03bf\u03cd\u03bd\u03b1\u03c2"
#          },
#          {
#             "type": "uri",
#             "value": "http://he.dbpedia.org/resource/\u05d0\u05e8\u05e0\u05d4_\u05d3\u05d0\u05e1_\u05d3\u05d5\u05e0\u05d0\u05e1"
#          },
#          {
#             "type": "uri",
#             "value": "http://hu.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://ga.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://hr.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://fa.dbpedia.org/resource/\u0648\u0631\u0632\u0634\u06af\u0627\u0647_\u0622\u0631\u0646\u0627_\u062f\u0627\u0633_\u062f\u0648\u0646\u0627\u0633"
#          },
#          {
#             "type": "uri",
#             "value": "http://da.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://ko.dbpedia.org/resource/\uc544\ub808\ub098_\ub2e4\uc2a4_\ub450\ub098\uc2a4"
#          },
#          {
#             "type": "uri",
#             "value": "http://bg.dbpedia.org/resource/\u0410\u0440\u0435\u043d\u0430_\u0434\u0430\u0441_\u0414\u0443\u043d\u0430\u0441"
#          },
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://nl.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://ca.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://gl.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://sr.dbpedia.org/resource/\u0410\u0440\u0435\u043d\u0430_\u0434\u0430\u0441_\u0414\u0443\u043d\u0430\u0441"
#          },
#          {
#             "type": "uri",
#             "value": "http://ar.dbpedia.org/resource/\u0645\u0644\u0639\u0628_\u0622\u0631\u064a\u0646\u0627_\u062f\u0627\u0633_\u062f\u0648\u0646\u0627\u0633"
#          },
#          {
#             "type": "uri",
#             "value": "http://es.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://pl.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://id.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://ro.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://cs.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://www.wikidata.org/entity/Q1343986"
#          },
#          {
#             "type": "uri",
#             "value": "http://ta.dbpedia.org/resource/\u0bae\u0ba3\u0bb1\u0bcd\u0b95\u0bc1\u0ba9\u0bcd\u0bb1\u0bc1_\u0b85\u0bb0\u0b99\u0bcd\u0b95\u0bae\u0bcd"
#          },
#          {
#             "type": "uri",
#             "value": "http://uk.dbpedia.org/resource/\u0410\u0440\u0435\u043d\u0430_\u0434\u0430\u0441_\u0414\u0443\u043d\u0430\u0441"
#          },
#          {
#             "type": "uri",
#             "value": "http://it.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://tr.dbpedia.org/resource/Arena_das_Dunas"
#          },
#          {
#             "type": "uri",
#             "value": "http://mr.dbpedia.org/resource/\u0905\u0930\u0947\u0928\u093e_\u0926\u093e\u0938_\u0926\u0941\u0928\u093e\u0938"
#          }
#       ],
#       "http://www.georss.org/georss/point": [
#          {
#             "type": "literal",
#             "value": "-5.826936 -35.212371"
#          }
#       ],
#       "http://www.w3.org/ns/prov#wasDerivedFrom": [
#          {
#             "type": "uri",
#             "value": "http://en.wikipedia.org/wiki/Arena_das_Dunas?oldid=1001984144&ns=0"
#          }
#       ],
#       "http://purl.org/linguistics/gold/hypernym": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Stadium"
#          }
#       ],
#       "http://dbpedia.org/ontology/openingDate": [
#          {
#             "type": "literal",
#             "value": "2014-01-26",
#             "datatype": "http://www.w3.org/2001/XMLSchema#date"
#          }
#       ],
#       "http://dbpedia.org/property/fullname": [
#          {
#             "type": "literal",
#             "value": "Arena das Dunas",
#             "lang": "en"
#          }
#       ],
# ...
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Offshoots_of_Operation_Car_Wash": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup_Group_A": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Bolivia_national_football_team_results_(2000\u20132019)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Associa\u00e7\u00e3o_Portuguesa_de_Desportos_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Cruzeiro_Esporte_Clube_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2018_FIFA_World_Cup_qualification_(CONMEBOL)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup_Group_C": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Populous_(company)": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Uruguay_at_the_FIFA_World_Cup": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2015_in_Brazilian_football": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/United_States_at_the_FIFA_World_Cup": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_CR_Vasco_da_Gama_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Campeonato_Brasileiro_S\u00e9rie_B": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Clube_de_Regatas_do_Flamengo_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Copa_do_Brasil_First_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Copa_do_Brasil_Second_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Copa_do_Brasil_Third_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_Copa_do_Brasil_knockout_stages": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup_officials": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2014_FIFA_World_Cup_venues": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2015_CR_Vasco_da_Gama_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2015_Campeonato_Brasileiro_S\u00e9rie_A": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2015_Clube_de_Regatas_do_Flamengo_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2015_Copa_do_Brasil_Second_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2015_Copa_do_Brasil_Third_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2016_Campeonato_Brasileiro_S\u00e9rie_A": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2016_Copa_do_Brasil_First_Round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2017_CR_Vasco_da_Gama_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2020_Copa_do_Brasil_third_round": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/2021_Cruzeiro_Esporte_Clube_season": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/property/stadium": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Estrela_dos_reis_magos": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Arena_das_dunas": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Dunas_Arena": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Dunas_Stadium": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Dunes_Arena": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Dunes_Stadium": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Estadio_das_Dunas": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Estrela_dos_Reis_Magos": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Est\u00e1dio_Estrela_dos_Reis_Magos": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    },
#    "http://dbpedia.org/resource/Est\u00e1dio_das_Dunas": {
#       "http://dbpedia.org/ontology/wikiPageWikiLink": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ],
#       "http://dbpedia.org/ontology/wikiPageRedirects": [
#          {
#             "type": "uri",
#             "value": "http://dbpedia.org/resource/Arena_das_Dunas"
#          }
#       ]
#    }
# }
