# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_drum = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"
data_drum = requests.get(url_drum)
json_drum = data_drum.json()
print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tenda dos Milagres: " + grass)
# Out:
# Autor de Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}"
concept = "Aspirin"
match = "exact"
concept = concept.replace(" ", "%20")
url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)
data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Nasa"
url = url_template.replace("{format}", format)\
                  .replace("{query}", query)
data = requests.get(url)
nasa_ref = data.json()
print(json.dumps(nasa_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 99133114,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 32541009,
#       "boundingbox": [
#          "29.5507993",
#          "29.5753063",
#          "-95.1085769",
#          "-95.0753597"
#       ],
#       "lat": "29.5645716",
#       "lon": "-95.09275295351505",
#       "display_name": "Lyndon B. Johnson Space Center, 2101, NASA Parkway, Houston, Harris County, Texas, 77058, United States",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.6180567423880722,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 258392256,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 2631184,
#       "boundingbox": [
#          "-14.4279746",
#          "-9.4932917",
#          "33.8883349",
#          "35.2959703"
#       ],
#       "lat": "-11.960646749999999",
#       "lon": "34.50156491324369",
#       "display_name": "Lake Malawi / Lago Niassa, Mo\u00e7ambique",
#       "class": "natural",
#       "type": "water",
#       "importance": 0.5138360394851793
#    },
#    {
#       "place_id": 47136686,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3860799304,
#       "boundingbox": [
#          "-2.4309961",
#          "-2.3909961",
#          "33.5419443",
#          "33.5819443"
#       ],
#       "lat": "-2.4109961",
#       "lon": "33.5619443",
#       "display_name": "Nasa, Busega, Simiyu, Lake Zone, Tanzania",
#       "class": "place",
#       "type": "village",
#       "importance": 0.385,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 4639953,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 571666784,
#       "boundingbox": [
#          "-15.669137",
#          "-15.629137",
#          "168.103615",
#          "168.143615"
#       ],
#       "lat": "-15.649137",
#       "lon": "168.123615",
#       "display_name": "Nasa, Penama, Vanuatu",
#       "class": "place",
#       "type": "village",
#       "importance": 0.385,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 42253110,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3179626227,
#       "boundingbox": [
#          "7.6850057",
#          "7.7250057",
#          "-72.1560069",
#          "-72.1160069"
#       ],
#       "lat": "7.7050057",
#       "lon": "-72.1360069",
#       "display_name": "La Nasa, Parroquia La Concordia, Distrito San Crist\u00f3bal, T\u00e1chira, Venezuela",
#       "class": "place",
#       "type": "village",
#       "importance": 0.375,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 256743401,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 861011447,
#       "boundingbox": [
#          "10.1728956",
#          "10.1883764",
#          "-68.4817851",
#          "-68.4644151"
#       ],
#       "lat": "10.1840199",
#       "lon": "-68.4686087",
#       "display_name": "La Nasa, Parroquia Salom, Municipio Nirgua, Yaracuy, Regi\u00f3n Centroccidental, Venezuela",
#       "class": "place",
#       "type": "village",
#       "importance": 0.375,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 81439039,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 7510984069,
#       "boundingbox": [
#          "40.4268803",
#          "40.4269803",
#          "49.8413426",
#          "49.8414426"
#       ],
#       "lat": "40.4269303",
#       "lon": "49.8413926",
#       "display_name": "Az\u0259rbaycan Milli Aerokosmik Agentliyi, S\u00fcleyman Sani Axundov k\u00fc\u00e7\u0259si, R\u0259sulzad\u0259, Bak\u0131, Bin\u0259q\u0259di rayonu, Bak\u0131 \u0130nzibati \u018frazisi, Bak\u0131, AZ 1115, Az\u0259rbaycan",
#       "class": "office",
#       "type": "government",
#       "importance": 0.3613896583874115
#    },
#    {
#       "place_id": 45601421,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3596734653,
#       "boundingbox": [
#          "-14.8573",
#          "-14.8173",
#          "-74.4114863",
#          "-74.3714863"
#       ],
#       "lat": "-14.8373",
#       "lon": "-74.3914863",
#       "display_name": "Nasa, Santa Luc\u00eda, Lucanas, Ayacucho, Per\u00fa",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.36,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 79309803,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 7490432074,
#       "boundingbox": [
#          "10.1175896",
#          "10.1575896",
#          "-2.3741663",
#          "-2.3341663"
#       ],
#       "lat": "10.1375896",
#       "lon": "-2.3541663",
#       "display_name": "Nasa, Wa East District, Upper West Region, Ghana",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.36,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 299691396,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 8303543061,
#       "boundingbox": [
#          "58.4216829",
#          "58.4217829",
#          "24.6921134",
#          "24.6922134"
#       ],
#       "lat": "58.4217329",
#       "lon": "24.6921634",
#       "display_name": "Nasa, Pulli k\u00fcla, Sindi, Tori vald, P\u00e4rnu maakond, 86807, Eesti",
#       "class": "place",
#       "type": "isolated_dwelling",
#       "importance": 0.30999999999999994
#    }
# ]

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"
element_type = "way"
id = str(nasa_ref[0]["osm_id"])
format = "json"
url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)
data = requests.get(url)
nasa_way = data.json()
print(json.dumps(nasa_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (610633 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 32541009,
#          "timestamp": "2021-04-20T17:14:02Z",
#          "version": 11,
#          "changeset": 103286030,
#          "user": "ti-lo",
#          "uid": 3437781,
#          "nodes": [
#             365951226,
#             3842075877,
#             3842075871,
#             365951227,
#             365951207,
#             365951210,
#             365951211,
#             365951213,
#             674226906,
#             365951215,
#             365951216,
#             674226907,
#             674226908,
#             674226909,
#             674226910,
#             365951217,
#             637536226,
#             637536207,
#             365951219,
#             365951220,
#             365950517,
#             365951222,
#             365951224,
#             365951226
#          ],
#          "tags": {
#             "addr:city": "Houston",
#             "addr:housenumber": "2101",
#             "addr:postcode": "77058",
#             "addr:state": "TX",
#             "addr:street": "NASA Parkway",
#             "aerospace:product": "robot",
#             "landuse": "commercial",
#             "name": "Lyndon B. Johnson Space Center",
#             "name:ko": "\ub9b0\ub4e0 B. \uc874\uc2a8 \uc6b0\uc8fc \uc13c\ud130",
#             "operator": "NASA",
#             "research": "aerospace",
#             "robot:type": "spaceflight",
#             "tourism": "attraction",
#             "website": "https://www.nasa.gov/centers/johnson/home/index.html",
#             "wikidata": "Q208371",
#             "wikipedia": "en:Johnson Space Center"
#          }
#       }
#    ]
# }

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = nasa_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"
url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
nasa_dbpedia = data.json()
print(json.dumps(nasa_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Johnson_Space_Center"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Johnson Space Center",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/White_Sands_Test_Facility"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "El Centre Espacial Lyndon B. Johnson (Lyndon B. Johnson Space Center en angl\u00e8s, abreujat JSC) \u00e9s la instal\u00b7laci\u00f3 de la NASA per a les activitats tripulades espacials situada al Houston sud-oriental, Texas. Va ser constru\u00efda en un terreny donat per la Universitat de Rice.",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Cite_news"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://www.wikidata.org/entity/Q24229398"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://ntrs.nasa.gov/archive/nasa/casi.ntrs.nasa.gov/19940020111_1994020111.pdf"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://es.dbpedia.org/resource/Centro_Espacial_Lyndon_B._Johnson"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Johnson_Space_Center"
#                }
#             },
#             "http://dbpedia.org/ontology/alternativeName": "Manned Spacecraft Center",
#             "http://dbpedia.org/ontology/abstract": "\u041a\u043e\u0441\u043c\u0456\u0447\u043d\u0438\u0439 \u0446\u0435\u043d\u0442\u0440 \u041b\u0456\u043d\u0434\u043e\u043d\u0430 \u0414\u0436\u043e\u043d\u0441\u043e\u043d\u0430 (\u0430\u043d\u0433\u043b. Lyndon B Johnson Space Center) \u2014 \u0432\u0435\u043b\u0438\u043a\u0438\u0439 \u043a\u043e\u0441\u043c\u0456\u0447\u043d\u0438\u0439 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0456\u0447\u043d\u0438\u0439 \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441 \u0443 \u0425&#39;\u044e\u0441\u0442\u043e\u043d\u0456 (\u0448\u0442\u0430\u0442 \u0422\u0435\u0445\u0430\u0441), \u044f\u043a\u0438\u0439 \u0454 \u0448\u0442\u0430\u0431-\u043a\u0432\u0430\u0440\u0442\u0438\u0440\u043e\u044e \u0430\u0441\u0442\u0440\u043e\u043d\u0430\u0432\u0442\u0456\u0432 \u041d\u0430\u0446\u0456\u043e\u043d\u0430\u043b\u044c\u043d\u043e\u0433\u043e \u0443\u043f\u0440\u0430\u0432\u043b\u0456\u043d\u043d\u044f \u0437 \u0430\u0435\u0440\u043e\u043d\u0430\u0432\u0442\u0438\u043a\u0438 \u0456 \u0434\u043e\u0441\u043b\u0456\u0434\u0436\u0435\u043d\u043d\u044f \u043a\u043e\u0441\u043c\u0456\u0447\u043d\u043e\u0433\u043e \u043f\u0440\u043e\u0441\u0442\u043e\u0440\u0443 \u0421\u0428\u0410 (NASA), \u0431\u0443\u0432 \u0437\u0430\u0441\u043d\u043e\u0432\u0430\u043d\u0438\u0439 \u0432 \u043b\u0438\u043f\u043d\u0456 1958 \u0440\u043e\u043a\u0443. \u0413\u0440\u0430\u0454 \u0440\u043e\u043b\u044c \u00ab\u0446\u0435\u043d\u0442\u0440\u0443 \u0443\u043f\u0440\u0430\u0432\u043b\u0456\u043d\u043d\u044f \u043f\u043e\u043b\u044c\u043e\u0442\u0430\u043c\u0438\u00bb, \u0432\u0456\u0434\u043f\u043e\u0432\u0456\u0434\u0430\u044e\u0447\u0438 \u0437\u0430 \u0434\u0456\u0457 \u043a\u043e\u0441\u043c\u0456\u0447\u043d\u0438\u0445 \u0448\u0430\u0442\u043b\u0456\u0432 \u043f\u0456\u0441\u043b\u044f \u0457\u0445 \u0437\u0430\u043f\u0443\u0441\u043a\u0443 \u0456 \u0430\u0436 \u0434\u043e \u043f\u0440\u0438\u0437\u0435\u043c\u043b\u0435\u043d\u043d\u044f. \u0422\u0443\u0442 \u0436\u0435 \u0440\u043e\u0437\u0442\u0430\u0448\u043e\u0432\u0430\u043d\u0456 \u043f\u0456\u0434\u0440\u043e\u0437\u0434\u0456\u043b\u0438 NASA, \u0432\u0456\u0434\u043f\u043e\u0432\u0456\u0434\u0430\u043b\u044c\u043d\u0456 \u0437\u0430 \u0440\u043e\u0437\u0440\u043e\u0431\u043a\u0443 \u0456 \u0435\u043a\u0441\u043f\u043b\u0443\u0430\u0442\u0430\u0446\u0456\u044e \u043a\u043e\u0441\u043c\u0456\u0447\u043d\u0438\u0445 \u0448\u0430\u0442\u043b\u0456\u0432, \u0430 \u0442\u0430\u043a\u043e\u0436 \u0437\u0430 \u041d\u0430\u0446\u0456\u043e\u043d\u0430\u043b\u044c\u043d\u0443 \u043a\u043e\u0441\u043c\u0456\u0447\u043d\u0443 \u0441\u0438\u0441\u0442\u0435\u043c\u0443 \u0442\u0440\u0430\u043d\u0441\u043f\u043e\u0440\u0442\u0443\u0432\u0430\u043d\u043d\u044f (\u0443 \u0440\u0430\u043c\u043a\u0430\u0445 \u044f\u043a\u043e\u0457 \u0432\u0435\u0434\u0443\u0442\u044c\u0441\u044f \u0440\u043e\u0431\u043e\u0442\u0438 \u0437 \u0432\u0456\u0434\u043d\u043e\u0432\u043b\u0435\u043d\u043d\u044f \u0456 \u043f\u043e\u0432\u0442\u043e\u0440\u043d\u043e\u0433\u043e \u0432\u0438\u043a\u043e\u0440\u0438\u0441\u0442\u0430\u043d\u043d\u044f \u0448\u0430\u0442\u0442\u043b\u0456\u0432). \u0423 \u0426\u0435\u043d\u0442\u0440\u0456 \u043f\u0440\u043e\u0432\u043e\u0434\u044f\u0442\u044c\u0441\u044f \u0440\u043e\u0431\u043e\u0442\u0438 \u043f\u043e \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u0430\u0445, \u043f\u043e\u0432&#39;\u044f\u0437\u0430\u043d\u0438\u0445 \u0456\u0437 \u0437\u0430\u0431\u0435\u0437\u043f\u0435\u0447\u0435\u043d\u043d\u044f\u043c \u043f\u0456\u043b\u043e\u0442\u043e\u0432\u0430\u043d\u0438\u0445 \u043f\u043e\u043b\u044c\u043e\u0442\u0456\u0432, \u043a\u043e\u0441\u043c\u0456\u0447\u043d\u043e\u044e \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u043e\u044e \u0456 \u0430\u0432\u0456\u0430\u0446\u0456\u0454\u044e. \u041a\u0440\u0456\u043c \u0442\u043e\u0433\u043e, \u0432\u0435\u0434\u0443\u0442\u044c\u0441\u044f \u0434\u043e\u0441\u043b\u0456\u0434\u0436\u0435\u043d\u043d ...
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Houston"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "35980",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-95.09100341796875",
#             "http://dbpedia.org/property/imageSize": "300",
#             "http://dbpedia.org/property/leaderTitle": "Director",
#             "http://www.w3.org/2004/02/skos/core#closeMatch": {
#                "__deferred": {
#                   "uri": "http://www.grid.ac/institutes/grid.419085.1"
#                }
#             },
#             "http://dbpedia.org/ontology/foundingDate": "1961-11-01",
#             "http://dbpedia.org/property/caption": "Top to bottom, left to right: Aerial view of JSC, Space Vehicle Mockup Facility, Christopher C. Kraft Jr. Mission Control Center, Neutral Buoyancy Laboratory, and the Space Center Houston Saturn V exhibit.",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Johnson_Space_Center"
#                }
#             },
#             "http://dbpedia.org/property/leaderName": "Mark Geyer",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/NASA_logo.svg"
#                }
#             },
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/155896317"
#                }
#             },
#             "http://dbpedia.org/ontology/leaderFunction": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Johnson_Space_Center__PersonFunction__1"
#                }
#             },
#             "http://dbpedia.org/ontology/numberOfStaff": "3200",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-95.091003417969 29.562999725342)",
#             "http://dbpedia.org/property/formerly": "Manned Spacecraft Center",
#             "http://dbpedia.org/ontology/abbreviation": "JSC",
#             "http://dbpedia.org/property/location": "Houston, Texas, US",
#             "http://dbpedia.org/ontology/predecessor": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Space_Task_Group"
#                }
#             },
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-location-noun-1"
#                }
#             },
#             "http://dbpedia.org/property/website": {
#                "__deferred": {
#                   "uri": "http://www.nasa.gov/centers/johnson/home/index.html"
#                }
#             },
#             "http://dbpedia.org/property/formation": "1961-11-01",
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "http://www.nasa.gov/centers/johnson/home/index.html"
#                }
#             },
#             "http://dbpedia.org/property/owner": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/NASA"
#                }
#             },
#             "http://dbpedia.org/property/staff": "3200",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/NASA_logo.svg?width=300"
#                }
#             },
#             "http://dbpedia.org/property/fullName": "Lyndon B. Johnson Space Center",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "29.5629997253418",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1017428551",
#             "http://dbpedia.org/property/predecessor": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Space_Task_Group"
#                }
#             },
#             "http://www.georss.org/georss/point": "29.563 -95.091",
#             "http://dbpedia.org/ontology/wikiPageID": "177571",
#             "http://dbpedia.org/property/abbreviation": "JSC",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Johnson_Space_Center?oldid=1017428551&ns=0"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
