# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

url = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data = requests.get(url)
json_data = data.json()

print(json.dumps(json_data, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
autor = json_data["d"]["results"][0]["http://dbpedia.org/property/author"]["__deferred"]["uri"]
print("Autor de Tenda dos Milagres: " + autor)
# Out:
# Autor de Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
code = json_mi[0]['resource'].split('/')[-1]
url_template = f"https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"
data = requests.get(url_template)
json_mid = data.json()
terms = json_mid["terms"]
print(json.dumps(terms, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003713",
#       "label": "Aspirin",
#       "preferred": true
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003714",
#       "label": "2-(Acetyloxy)benzoic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003712",
#       "label": "Acetylsalicylic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003721",
#       "label": "Acetysal",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003722",
#       "label": "Acylpyrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003711",
#       "label": "Aloxiprimum",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003723",
#       "label": "Colfarit",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003715",
#       "label": "Dispril",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003719",
#       "label": "Easprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003724",
#       "label": "Ecotrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003725",
#       "label": "Endosprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003726",
#       "label": "Magnecyl",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003727",
#       "label": "Micristin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003717",
#       "label": "Polopirin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003728",
#       "label": "Polopiryna",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003716",
#       "label": "Solprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003718",
#       "label": "Solupsan",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003720",
#       "label": "Zorprin",
#       "preferred": false
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "American Museum of Natural History"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 180335858,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 388436810,
#       "boundingbox": [
#          "40.7800328",
#          "40.782152",
#          "-73.9757936",
#          "-73.9726348"
#       ],
#       "lat": "40.7810974",
#       "lon": "-73.97424765735384",
#       "display_name": "American Museum of Natural History, 180, Central Park West, Upper West Side, Manhattan Community Board 7, Manhattan, New York County, New York, 10024, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 1.0424092820252828,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    }
# ]

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 388436810

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (829702 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 388436810,
#          "timestamp": "2021-07-01T23:03:56Z",
#          "version": 23,
#          "changeset": 107282200,
#          "user": "Natbu2384",
#          "uid": 13362183,
#          "nodes": [
#             3916369313,
#             3916376258,
#             3916376257,
#             3916369332,
#             6818442821,
#             6818442854,
#             3916376278,
#             6818442838,
#             3916369314,
#             6818442853,
#             6818442848,
#             3916369319,
#             6818442859,
#             6818442829,
#             6818442843,
#             3916369356,
#             6818442846,
#             3916369297,
#             6818442813,
#             6818442850,
#             3916369339,
#             6818442833,
#             6818442835,
#             3916369305,
#             6818442852,
#             6818442815,
#             3916369311,
#             6818442847,
#             6818442857,
#             6818442827,
#             3916369349,
#             6818442855,
#             6818442822,
#             6818442832,
#             3916369337,
#             3916369323,
#             3916369318,
#             3916376260,
#             3916369308,
#             3916369334,
#             3916369352,
#             3916369338,
#             3916369342,
#             3916369316,
#             3269834164,
#             3916376276,
#             3916369291,
#             3916369296,
#             3916369346,
#             3916369288,
#             3916369350,
#             3916369355,
#             3916376273,
#             3916369345,
#             3916369283,
#             3916376264,
#             6818442825,
#             3916369335,
#             6818442842,
#             3916369324,
#             6818442858,
#             3916376267,
#             6818442845,
#             6818442824,
#             3916376271,
#             6818442820,
#             6818442837,
#             6818442828,
#             3916369322,
#             6818442839,
#             3916369330,
#             6818442816,
#             3916376259,
#             6818442831,
#             3916369341,
#             6818442836,
#             6818442819,
#             6818442841,
#             3916376274,
#             3916369306,
#             3916376262,
#             3916369312,
#             3916369281,
#             3916376272,
#             3916369282,
#             3916369310,
#             3916369303,
#             3916376279,
#             3916376275,
#             3916369347,
#             3916369340,
#             3916369328,
#             3916369280,
#             3916369300,
#             3916369336,
#             3916376269,
#             3916369292,
#             3916369326,
#             3916369317,
#             3916369298,
#             3916369287,
#             3916369321,
#             3916376265,
#             3916369309,
#             3916376263,
#             3916369289,
#             3916369302,
#             3916369348,
#             3916369299,
#             3916376277,
#             3916369290,
#             3916376266,
#             3916369333,
#             3916369307,
#             3916369327,
#             3916369286,
#             3916376261,
#             3916369304,
#             3916369320,
#             3916369344,
#             3916369351,
#             3916369325,
#             3916369315,
#             3916376270,
#             3916369301,
#             3269834163,
#             3916369294,
#             3916369329,
#             3916376282,
#             3916369313
#          ],
#          "tags": {
#             "addr:city": "New York",
#             "addr:housenumber": "180",
#             "addr:state": "NY",
#             "addr:street": "Central Park West",
#             "alt_name:cs": "Americk\u00e9 p\u0159\u00edrodopisn\u00e9 muzeum",
#             "alt_name:es": "Museo Americano de Historia Natural",
#             "building": "museum",
#             "building:levels": "5",
#             "fee": "yes",
#             "gnis:feature_id": "942429",
#             "layer": "1",
#             "name": "American Museum of Natural History",
#             "name:cs": "Americk\u00e9 p\u0159\u00edrodov\u011bdn\u00e9 muzeum",
#             "name:es": "Museo Americano de Historia Natural",
#             "name:fr": "Mus\u00e9um am\u00e9ricain d'histoire naturelle",
#             "name:he": "\u05d4\u05de\u05d5\u05d6\u05d9\u05d0\u05d5\u05df \u05d4\u05d0\u05de\u05e8\u05d9\u05e7\u05d0\u05d9 \u05dc\u05ea\u05d5\u05dc\u05d3\u05d5\u05ea \u05d4\u05d8\u05d1\u05e2",
#             "name:ja": "\u30a2\u30e1\u30ea\u30ab\u81ea\u7136\u53f2\u535a\u7269\u9928",
#             "name:ko": "\ubbf8\uad6d \uc790\uc5f0\uc0ac \ubc15\ubb3c\uad00",
#             "name:pl": "Ameryka\u0144skie Muzeum Historii Naturalnej",
#             "name:pt": "Museu Americano de Hist\u00f3ria Natural",
#             "name:uk": "\u0410\u043c\u0435\u0440\u0438\u043a\u0430\u043d\u0441\u044c\u043a\u0438\u0439 \u043c\u0443\u0437\u0435\u0439 \u043f\u0440\u0438\u0440\u043e\u0434\u043e\u0437\u043d\u0430\u0432\u0441\u0442\u0432\u0430",
#             "name:zh": "\u81ea\u7136\u5386\u53f2\u535a\u7269\u9986",
#             "opening_hours": "Mo-Su 10:00-17:45",
#             "phone": "+1 212-769-5100",
#             "toilets:wheelchair": "yes",
#             "tourism": "museum",
#             "website": "https://www.amnh.org/",
#             "wheelchair": "yes",
#             "wikidata": "Q217717",
#             "wikipedia": "en:American Museum of Natural History"
#          }
#       }
#    ]
# }

# %%
print(museum_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:American Museum of Natural History

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/American_Museum_of_Natural_History"
#             },
#             "http://dbpedia.org/property/name": "American Museum of Natural History",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Emmett_Reid_Dunn"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://hu.dbpedia.org/resource/American_Museum_of_Natural_History"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "\u03a4\u03bf \u0391\u03bc\u03b5\u03c1\u03b9\u03ba\u03b1\u03bd\u03b9\u03ba\u03cc \u039c\u03bf\u03c5\u03c3\u03b5\u03af\u03bf \u03a6\u03c5\u03c3\u03b9\u03ba\u03ae\u03c2 \u0399\u03c3\u03c4\u03bf\u03c1\u03af\u03b1\u03c2 (American Museum of Natural History) \u03b5\u03af\u03bd\u03b1\u03b9 \u03ad\u03bd\u03b1 \u03b1\u03c0\u03cc \u03c4\u03b1 \u03bc\u03b5\u03b3\u03b1\u03bb\u03cd\u03c4\u03b5\u03c1\u03b1 \u03bc\u03bf\u03c5\u03c3\u03b5\u03af\u03b1 \u03c6\u03c5\u03c3\u03b9\u03ba\u03ae\u03c2 \u03b9\u03c3\u03c4\u03bf\u03c1\u03af\u03b1\u03c2 \u03c4\u03bf\u03c5 \u03ba\u03cc\u03c3\u03bc\u03bf\u03c5. \u0392\u03c1\u03af\u03c3\u03ba\u03b5\u03c4\u03b1\u03b9 \u03b1\u03c0\u03ad\u03bd\u03b1\u03bd\u03c4\u03b9 \u03b1\u03c0\u03cc \u03c4\u03bf \u03a3\u03ad\u03bd\u03c4\u03c1\u03b1\u03bb \u03a0\u03b1\u03c1\u03ba, \u03c3\u03c4\u03bf \u03c4\u03bf\u03c5 \u039c\u03b1\u03bd\u03c7\u03ac\u03c4\u03b1\u03bd, \u03c3\u03c4\u03b7 \u039d\u03ad\u03b1 \u03a5\u03cc\u03c1\u03ba\u03b7. \u03a4\u03bf \u03c3\u03c5\u03b3\u03ba\u03c1\u03cc\u03c4\u03b7\u03bc\u03b1 \u03c4\u03bf\u03c5 \u03bc\u03bf\u03c5\u03c3\u03b5\u03af\u03bf\u03c5 \u03b1\u03c0\u03bf\u03c4\u03b5\u03bb\u03b5\u03af\u03c4\u03b1\u03b9 \u03b1\u03c0\u03cc 28 \u03b5\u03bd\u03c9\u03bc\u03ad\u03bd\u03b1 \u03bc\u03b5\u03c4\u03b1\u03be\u03cd \u03c4\u03bf\u03c5\u03c2 \u03ba\u03c4\u
8\u6709\u5404\u79cd\u57f9\u517b\u4e2d\u5b66\u751f\u63a2\u7d22\u79d1\u5b66\u7684\u5174\u8da3\u7684\u6559\u80b2\u6d3b\u52a8\uff0c\u8fd8\u4f1a\u7ed9\u6559\u5e08\u4eec\u63d0\u4f9b\u57f9\u8bad\u3002\u7f8e\u56fd\u81ea\u7136\u53f2\u535a\u7269\u9986\u662f\u4e16\u754c\u4e0a\u6d4f\u89c8\u4eba\u6570\u6700\u591a\u7684\u535a\u7269\u9986\u4e4b\u4e00\uff0c2010\u5e74\u65f6\u6709\u8d85\u8fc7500\u4e07\u4eba\u53c2\u89c2\u8fc7\u8fd9\u4e2a\u535a\u7269\u9986\u3002",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Start_date_and_age"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-73.97472381591797",
#             "http://dbpedia.org/ontology/wikiPageLength": "120404",
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Natural_history"
#                }
#             },
#             "http://dbpedia.org/property/publictransit": "New York City Subway:",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Museu Americ\u00e0 d&#39;Hist\u00f2ria Natural",
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/WikicatFull-blockStructuresInNewYorkCity"
#                }
#             },
#             "http://dbpedia.org/property/visitors": "5000000",
#             "http://dbpedia.org/property/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Natural_history"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://www.thecityreview.com/uws/cpw/amerhist.html"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#seeAlso": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/List_of_castles"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "American Museum of Natural History",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/New_York_City"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "http://www.amnh.org/"
#                }
#             },
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/USA-NYC-American_Museum_of_Natural_History.JPG?width=300"
#                }
#             },
#             "http://dbpedia.org/property/imageUpright": "1.3",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/167627219"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1022740241",
#             "http://www.georss.org/georss/point": "40.78055555555556 -73.97472222222223",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-73.974723815918 40.780555725098)",
#             "http://dbpedia.org/ontology/president": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Ellen_V._Futter"
#                }
#             },
#             "http://dbpedia.org/property/website": "--06-24",
#             "http://dbpedia.org/property/caption": "Looking at the east entrance from Central Park West",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/American_Museum_of_Natural_History"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "40.78055572509766",
#             "http://dbpedia.org/property/president": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Ellen_V._Futter"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/USA-NYC-American_Museum_of_Natural_History.JPG"
#                }
#             },
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Museums"
#                }
#             },
#             "http://dbpedia.org/ontology/numberOfVisitors": "5000000",
#             "http://dbpedia.org/ontology/foundingDate": "1869-04-06",
#             "http://www.w3.org/2004/02/skos/core#closeMatch": {
#                "__deferred": {
#                   "uri": "http://www.grid.ac/institutes/grid.241963.b"
#                }
#             },
#             "http://dbpedia.org/property/established": "1869-04-06",
#             "http://dbpedia.org/ontology/wikiPageID": "399990",
#             "http://dbpedia.org/property/location": "United States",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/American_Museum_of_Natural_History?oldid=1022740241&ns=0"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
