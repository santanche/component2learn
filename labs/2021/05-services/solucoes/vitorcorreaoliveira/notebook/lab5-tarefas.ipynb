# %% [markdown]
# # Laboratório 5 -  Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_tenda = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"
data_tenda = requests.get(url_tenda)
json_tenda = data_tenda.json()

# %%
print(json.dumps(json_tenda, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = json_tenda["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles: " + grass)
# Out:
# Autor de Tent of Miracles: http://dbpedia.org/resource/Jorge_Amado

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageDisambiguates": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(album)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "154",
#             "http://dbpedia.org/ontology/wikiPageID": "37750149",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles?oldid=933203748&ns=0"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://www.wikidata.org/entity/Q7700759"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Disambiguation"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "933203748",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles"
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Notre-Dame de Paris"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 138639708,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 201611261,
#       "boundingbox": [
#          "48.8524229",
#          "48.8534514",
#          "2.3489587",
#          "2.3507815"
#       ],
#       "lat": "48.85293705",
#       "lon": "2.3500501225000026",
#       "display_name": "Cath\u00e9drale Notre-Dame, 6, Parvis Notre-Dame - Place Jean-Paul II, Quartier Les \u00celes, Paris 4e Arrondissement, Paris, \u00cele-de-France, France m\u00e9tropolitaine, 75004, France",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.9661417276635078,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 64292701,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 5716143594,
#       "boundingbox": [
#          "48.7766467",
#          "48.7767467",
#          "1.9620744",
#          "1.9621744"
#       ],
#       "lat": "48.7766967",
#       "lon": "1.9621244",
#       "display_name": "Notre-Dame de Paris, Boulevard Andr\u00e9 Malraux, \u00c9lancourt, Rambouillet, Yvelines, \u00cele-de-France, France m\u00e9tropolitaine, 78990, France",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.401,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 41818634,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3184358218,
#       "boundingbox": [
#          "39.8087309",
#          "39.8088309",
#          "116.2802193",
#          "116.2803193"
#       ],
#       "lat": "39.8087809",
#       "lon": "116.2802693",
#       "display_name": "Notre Dame de Paris, \u90ed\u516c\u5e84\u5357\u8857, \u82b1\u4e61\u8857\u9053, \u4e30\u53f0\u533a, \u5317\u4eac\u5e02, 100070, \u4e2d\u56fd",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.401,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    }
# ]

# %% [markdown]
# ### Extraindo o Identificador OSM

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 201611261

# %% [markdown]
# ### REST API do OpenStreetMap para Elementos (Node, Way e Relation)

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1712131 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 201611261,
#          "timestamp": "2019-09-02T15:41:18Z",
#          "version": 54,
#          "changeset": 74005875,
#          "user": "gendy54",
#          "uid": 713836,
#          "nodes": [
#             2117881277,
#             626890422,
#             626890405,
#             626890404,
#             626890407,
#             626890409,
#             626890410,
#             626890412,
#             626890414,
#             626890382,
#             626890384,
#             626890386,
#             626890387,
#             626890389,
#             626890390,
#             626890394,
#             626890392,
#             5652214587,
#             626890492,
#             626890494,
#             626890495,
#             626890497,
#             6417251770,
#             626890499,
#             626890500,
#             626890502,
#             626890504,
#             6417251769,
#             626890512,
#             626890514,
#             626890505,
#             626890507,
#             626890509,
#             626890511,
#             626890517,
#             626890691,
#             626890693,
#             2116468309,
#             2116468310,
#             2117663310,
#             626890677,
#             626890678,
#             626890680,
#             626890682,
#             626890870,
#             626890859,
#             626890860,
#             626890862,
#             626890864,
#             626890865,
#             626890867,
#             626890869,
#             626890475,
#             626890477,
#             626890479,
#             626890480,
#             2117881273,
#             2117881269,
#             2117881271,
#             2117881275,
#             626890489,
#             626890490,
#             2116400132,
#             2116400129,
#             2116400133,
#             2116400136,
#             626890460,
#             626890463,
#             626890466,
#             626890468,
#             626890471,
#             626890474,
#             626890395,
#             626890397,
#             626890424,
#             626890425,
#             626890427,
#             626890429,
#             626890430,
#             626890432,
#             626890434,
#             626890435,
#             626890443,
#             626890447,
#             2117663364,
#             626890415,
#             626890399,
#             626890417,
#             626890400,
#             5836025385,
#             626890402,
#             626890419,
#             2117881277
#          ],
#          "tags": {
#             "access": "no",
#             "addr:city": "Paris",
#             "addr:housenumber": "6",
#             "addr:postcode": "75004",
#             "addr:street": "Parvis Notre-Dame - Place Jean-Paul II",
#             "alt_name": "Notre-Dame de Paris",
#             "alt_name:fr": "Notre-Dame de Paris",
#             "alt_name:ru": "\u041d\u043e\u0442\u0440-\u0414\u0430\u043c-\u0434\u0435-\u041f\u0430\u0440\u0438",
#             "amenity": "place_of_worship",
#             "basilica": "minor",
#             "building": "cathedral",
#             "building:architecture": "gothic",
#             "denomination": "catholic",
#             "height": "10.5",
#             "heritage": "2",
#             "heritage:operator": "mhs",
#             "historic": "church",
#             "importance": "international",
#             "mhs:inscription_date": "1862",
#             "name": "Cath\u00e9drale Notre-Dame",
#             "name:ar": "\u0643\u0627\u062a\u062f\u0631\u0627\u0626\u064a\u0629 \u0646\u0648\u062a\u0631\u062f\u0627\u0645",
#             "name:de": "Kathedrale Notre-Dame",
#             "name:en": "Cathedral of Notre Dame",
#             "name:es": "Catedral de Notre Dame",
#             "name:fr": "Cath\u00e9drale Notre-Dame",
#             "name:it": "Cattedrale di Notre-Dame",
#             "name:ja": "\u30ce\u30fc\u30c8\u30eb\u30c0\u30e0\u5bfa\u9662",
#             "name:ko": "\ub178\ud2b8\ub974\ub2f4 \ub300\uc131\ub2f9",
#             "name:ru": "\u0421\u043e\u0431\u043e\u0440 \u041f\u0430\u0440\u0438\u0436\u0441\u043a\u043e\u0439 \u0411\u043e\u0433\u043e\u043c\u0430\u0442\u0435\u0440\u0438",
#             "name:sr": "\u041d\u043e\u0442\u0440 \u0434\u0430\u043c",
#             "name:zh": "\u5df4\u9ece\u8056\u6bcd\u9662",
#             "operational_status": "no",
#             "organ:listed_status": "yes",
#             "phone": "+33 1 42 34 56 10",
#             "ref:FR:CEF": "75104_01",
#             "ref:mhs": "PA00086250",
#             "ref:structurae": "20000272",
#             "religion": "christian",
#             "roof:colour": "#d0d0d0",
#             "ruins": "yes",
#             "short_name": "Notre-Dame",
#             "start_date": "1345",
#             "start_date:construction": "1163",
#             "tourism": "attraction",
#             "tourism:visitors": "14000000",
#             "website": "http://www.notredamedeparis.fr",
#             "website:en": "http://www.notredamedeparis.fr/en/",
#             "wheelchair": "yes",
#             "wikidata": "Q2981",
#             "wikipedia": "fr:Cath\u00e9drale Notre-Dame de Paris"
#          }
#       }
#    ]
# }

# %% [markdown]
# ### Extraindo o Identificador DBPedia

# %%
print(museum_way["elements"][0]["tags"]["wikipedia"])
# Out:
# fr:Cathédrale Notre-Dame de Paris
