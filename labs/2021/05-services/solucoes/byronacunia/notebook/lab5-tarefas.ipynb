# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json
url_drum = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_drum = requests.get(url_drum)
json_drum = data_drum.json()

print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles (novel): " + grass)
# Out:
# Autor de Tent of Miracles (novel): http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))

uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])

url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Smithsonian Institution"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 107528703,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 66418787,
#       "boundingbox": [
#          "38.8907587",
#          "38.8917448",
#          "-77.0275532",
#          "-77.02439"
#       ],
#       "lat": "38.891245",
#       "lon": "-77.02597012430643",
#       "display_name": "National Museum of Natural History, Smithsonian Pollinator Garden Path, Penn Quarter, Washington, District of Columbia, 20560, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.5927699307272315,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 106698268,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 66418797,
#       "boundingbox": [
#          "38.887818",
#          "38.8884633",
#          "-77.0210446",
#          "-77.0179971"
#       ],
#       "lat": "38.88813505",
#       "lon": "-77.0194987456374",
#       "display_name": "National Air and Space Museum, 655, Jefferson Drive Southwest, Washington, District of Columbia, 20560, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.4428993157246233,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 305526097,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 3374667,
#       "boundingbox": [
#          "38.88786",
#          "38.8884945",
#          "-77.0233611",
#          "-77.0225478"
#       ],
#       "lat": "38.8881647",
#       "lon": "-77.02325699334995",
#       "display_name": "Hirshhorn Museum, Hirshhorn Museum Tunnel, Washington, District of Columbia, 20560, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.43885007126885206,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 259518960,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 11313259,
#       "boundingbox": [
#          "38.8639362",
#          "38.9056576",
#          "-78.1809124",
#          "-78.1124823"
#       ],
#       "lat": "38.8847957",
#       "lon": "-78.14619675708981",
#       "display_name": "Smithsonian Conservation Biology Institute, Bridle Path Road, High Knob, Warren County, Virginia, 22630, United States",
#       "class": "tourism",
#       "type": "zoo",
#       "importance": 0.4340805778876783,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_zoo.p.20.png"
#    },
#    {
#       "place_id": 107528629,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 66418605,
#       "boundingbox": [
#          "38.8878653",
#          "38.8885039",
#          "-77.0172224",
#          "-77.0158994"
#       ],
#       "lat": "38.88818305",
#       "lon": "-77.01663726740057",
#       "display_name": "National Museum of the American Indian, Maryland Avenue Southwest, Washington, District of Columbia, 20024, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.42354574368059655,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 175051171,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 362488767,
#       "boundingbox": [
#          "36.1138328",
#          "36.1142062",
#          "-115.1487707",
#          "-115.147956"
#       ],
#       "lat": "36.1139519",
#       "lon": "-115.1483834831469",
#       "display_name": "National Atomic Testing Museum, 755, East Flamingo Road, Hughes Center, Paradise, Clark County, Nevada, 89119, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.34458594246920515,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 100258517,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 42341486,
#       "boundingbox": [
#          "38.8877282",
#          "38.8886385",
#          "-77.0250599",
#          "-77.0238972"
#       ],
#       "lat": "38.888189",
#       "lon": "-77.02447959701192",
#       "display_name": "Arts and Industries Building, 9th Street Expressway, Southwest Employment Area, Washington, District of Columbia, 20560, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.32273448234397095,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    }
# ]

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 66418787

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1376562 spike-08.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 66418787,
#          "timestamp": "2021-06-12T16:26:05Z",
#          "version": 23,
#          "changeset": 106258801,
#          "user": "Imar de Coninck",
#          "uid": 13546511,
#          "nodes": [
#             4502666382,
#             804641975,
#             8457264371,
#             804640302,
#             804643071,
#             804642757,
#             804641275,
#             8457264335,
#             8457264282,
#             8457264338,
#             804641563,
#             8457264311,
#             804640839,
#             804637966,
#             804639264,
#             8457264292,
#             804639480,
#             8457379398,
#             804640464,
#             804642286,
#             804641889,
#             804642200,
#             804641856,
#             804641620,
#             8457379380,
#             8457264290,
#             8457379422,
#             804638104,
#             804642189,
#             804642251,
#             8457264370,
#             804641705,
#             804639318,
#             804641359,
#             8457379423,
#             8457264287,
#             8457379446,
#             804641236,
#             804639088,
#             8457379438,
#             804642620,
#             8457379439,
#             8457379442,
#             8457419222,
#             8457379443,
#             804642296,
#             8457264327,
#             8457264284,
#             8457264330,
#             8457264369,
#             8457264368,
#             8457264349,
#             804639331,
#             804642857,
#             8457264363,
#             804639828,
#             4502666383,
#             2995259838,
#             4502666382
#          ],
#          "tags": {
#             "addr:city": "Washington",
#             "addr:postcode": "20560",
#             "addr:state": "DC",
#             "building": "yes",
#             "building:level": "6",
#             "email": "naturalexperience@si.edu",
#             "internet_access": "wlan",
#             "name": "National Museum of Natural History",
#             "name:de": "Nationalmuseum f\u00fcr Naturgeschichte",
#             "name:en": "National Museum of Natural History",
#             "name:fr": "Mus\u00e9e National d'Histoire Naturelle",
#             "name:nl": "Nationaal Museum voor Natuurlijke Historie",
#             "name:pl": "Narodowe Muzeum Historii Naturalnej",
#             "name:ru": "\u041d\u0430\u0446\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u043c\u0443\u0437\u0435\u0439 \u0435\u0441\u0442\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439 \u0438\u0441\u0442\u043e\u0440\u0438\u0438",
#             "name:uk": "\u041d\u0430\u0446\u0456\u043e\u043d\u0430\u043b\u044c\u043d\u0438\u0439 \u043c\u0443\u0437\u0435\u0439 \u043f\u0440\u0438\u0440\u043e\u0434\u043e\u0437\u043d\u0430\u0432\u0441\u0442\u0432\u0430",
#             "name:zh": "\u56fd\u5bb6\u81ea\u7136\u5386\u53f2\u535a\u7269\u9986",
#             "opening_hours": "Mo-Su 10:00-17:30",
#             "operator": "Smithsonian Institution",
#             "phone": "+12026331000",
#             "start_date": "1910",
#             "tourism": "museum",
#             "website": "https://naturalhistory.si.edu",
#             "wikidata": "Q148554",
#             "wikipedia": "en:National Museum of Natural History"
#          }
#       }
#    ]
# }

# %%
print(museum_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:National Museum of Natural History

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/National_Museum_of_Natural_History"
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Facility103315023"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Asian_art_museums_in_the_United_States"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://zh.dbpedia.org/resource/\u7f8e\u56fd\u56fd\u7acb\u81ea\u7136\u5386\u53f2\u535a\u7269\u9986"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Rint"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "\u041d\u0430\u0446\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u043c\u0443\u0437\u0435\u0439 \u0435\u0441\u0442\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439 \u0438\u0441\u0442\u043e\u0440\u0438\u0438 (\u0430\u043d\u0433\u043b. National Museum of Natural History) \u2014 \u043c\u0443\u0437\u0435\u0439, \u043e\u0441\u043d\u043e\u0432\u0430\u043d\u043d\u044b\u0439 \u0432 1910 \u0433\u043e\u0434\u0443 \u0438 \u0443\u043f\u0440\u0430\u0432\u043b\u044f\u0435\u043c\u044b\u0439 \u0421\u043c\u0438\u0442\u0441\u043e\u043d\u043e\u0432\u0441\u043a\u0438\u043c \u0438\u043d\u0441\u0442\u0438\u0442\u0443\u0442\u043e\u043c. \u041c\u0443\u0437\u0435\u0439 \u0440\u0430\u0441\u043f\u043e\u043b\u043e\u0436\u0435\u043d \u043d\u0430 \u0442\u0435\u0440\u0440\u0438\u0442\u043e\u0440\u0438\u0438 \u041d\u0430\u0446\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u043e\u0439 \u0430\u043b\u043b\u0435\u0438 (\u0430\u043d\u0433\u043b. National Mall) \u0432 \u0441\u0442\u043e\u043b\u0438\u0446\u0435 \u0421\u043e\u0435\u0434\u0438\u043d\u0451\u043d\u043d\u044b\u0445 \u0428\u0442\u0430\u0442\u043e\u0432 \u0410\u043c\u0435\u0440\u0438\u043a\u0438 \u0433\u043e\u0440\u043e\u0434\u0435 \u0412\u0430\u0448\u0438\u043d\u0433\u0442\u043e\u043d\u0435. \u0412\u0445\u043e\u0434 \u0432 \u043c\u0443\u0437\u0435\u0439 \u0431\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u044b\u0439. \u041c\u0443\u0437\u0435\u0439 \u043e\u0442\u043a\u0440\u044b\u0442 364 \u0434\u043d\u044f \u0432 \u0433\u043e\u0434\u0443, \u043a\u0440\u043e\u043c\u0435 \u0420\u043e\u0436\u0434\u0435\u0441\u0442\u0432\u0430. \u041a\u043e\u043b\u043b\u0435\u043a\u0446\u0438\u044f \u043c\u0443\u0437\u0435\u044f \u0432\u043a\u043b\u044e\u0447\u0430\u0435\u0442 \u0441\u0432\u044b\u0448\u0435 126 \u043c\u0438\u043b\u043b\u0438\u043e\u043d\u043e\u0432 \u043e\u0431\u0440\u0430\u0437\u0446\u043e\u0432 \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0439, \u0436\u0438\u0432\u043e\u0442\u043d\u044b\u0445, \u0438\u0441\u043a\u043e\u043f\u0430\u0435\u043c\u044b\u0445, \u043c\u0438\u043d\u0435\u0440\u0430\u043b\u043e\u0432, \u043f\u043e\u0440\u043e\u0434, \u043c\u0435\u0442\u0435\u043e\u0440\u0438\u0442\u043e\u0432, \u0430 \u0442\u0430\u043a\u0436\u0435 \u0430\u0440\u0445\u0435\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0438 \u043a\u0443\u043b\u044c\u0442\u0443\u0440\u043d\u044b\u0445 \u0430\u0440\u0442\u0435\u0444\u0430\u043a\u0442\u043e\u0432. \u0417\u0434\u0435\u0441\u044c \u0440\u0430\u0431\u043e\u0442\u0430\u044e\u0442 185 \u043f\u0440\u043e\u0444\u0435\u0441\u0441\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0445 \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u0438\u0441\u0442\u043e\u0432 \u043f\u043e \u0435\u0441\u0442\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439 \u0438\u0441\u0442\u043e\u0440\u0438\u0438.",
#             "http://dbpedia.org/ontology/abstract": "\u041d\u0430\u0446\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u043c\u0443\u0437\u0435\u0439 \u0435\u0441\u0442\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439 \u0438\u0441\u0442\u043e\u0440\u0438\u0438 (\u0430\u043d\u0433\u043b. National Museum of Natural History) \u2014 \u043c\u0443\u0437\u0435\u0439, \u043e\u0441\u043d\u043e\u0432\u0430\u043d\u043d\u044b\u0439 \u0432 1910 \u0433\u043e\u0434\u0443 \u0438 \u0443\u043f\u0440\u0430\u0432\u043b\u044f\u0435\u043c\u044b\u0439 \u0421\u043c\u0438\u0442\u0441\u043e\u043d\u043e\u0432\u0441\u043a\u0438\u043c \u0438\u043d\u0441\u0442\u0438\u0442\u0443\u0442\u043e\u043c. \u041c\u0443\u0437\u0435\u0439 \u0440\u0430\u0441\u043f\u043e\u043b\u043e\u0436\u0435\u043d \u043d\u0430 \u0442\u0435\u0440\u0440\u0438\u0442\u043e\u0440\u0438\u0438 \u041d\u0430\u0446\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u043e\u0439 \u0430\u043b\u043b\u0435\u0438 (\u0430\u043d\u0433\u043b. National Mall) \u0432 \u0441\u0442\u043e\u043b\u0438\u0446\u0435 \u0421\u043e\u0435\u0434\u0438\u043d\u0451\u043d\u043d\u044b\u0445 \u0428\u0442\u0430\u0442\u043e\u0432 \u0410\u043c\u0435\u0440\u0438\u043a\u0438 \u0433\u043e\u0440\u043e\u0434\u0435 \u0412\u0430\u0448\u0438\u043d\u0433\u0442\u043e\u043d\u0435. \u0412\u0445\u043e\u0434 \u0432 \u043c\u0443\u0437\u0435\u0439 \u0431\u0435\u0441\u043f\u043b\u0430\u0442\u043d\u044b\u0439. \u041c\u0443\u0437\u0435\u0439 \u043e\u0442\u043a\u0440\u044b\u0442 364 \u0434\u043d\u044f \u0432 \u0433\u043e\u0434\u0443, \u043a\u0440\u043e\u043c\u0435 \u0420\u043e\u0436\u0434\u0435\u0441\u0442\u0432\u0430. \u041a\u043e\u043b\u043b\u0435\u043a\u0446\u0438\u044f \u043c\u0443\u0437\u0435\u044f \u0432\u043a\u043b\u044e\u0447\u0430\u0435\u0442 \u0441\u0432\u044b\u0448\u0435 126 \u043c\u0438\u043b\u043b\u0438\u043e\u043d\u043e\u0432 \u043e\u0431\u0440\u0430\u0437\u0446\u043e\u0432 \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0439, \u0436\u0438\u0432\u043e\u0442\u043d\u044b\u0445, \u0438\u0441\u043a\u043e\u043f\u0430\u0435\u043c\u044b\u0445, \u043c\u0438\u043d\u0435\u0440\u0430\u043b\u043e\u0432, \u043f\u043e\u0440\u043e\u0434, \u043c\u0435\u0442\u0435\u043e\u0440\u0438\u0442\u043e\u0432, \u0430 \u0442\u0430\u043a\u0436\u0435 \u0430\u0440\u0445\u0435\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0445 \u0438 \u043a\u0443\u043b\u044c\u0442\u0443\u0440\u043d\u044b\u0445 \u0430\u0440\u0442\u0435\u0444\u0430\u043a\u0442\u043e\u0432. \u0417\u0434\u0435\u0441\u044c \u0440\u0430\u0431\u043e\u0442\u0430\u044e\u0442 185 \u043f\u0440\u043e\u0444\u0435\u0441\u0441\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0445 \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u0438\u0441\u0442\u043e\u0432 \u043f\u043e \u0435\u0441\u0442\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439 \u0438\u0441\u0442\u043e\u0440\u0438\u0438.",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/National_Museum_of_Natural_History,_Washington.jpg?width=300"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Dinosaur_museums_in_the_United_States"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Narodowe Muzeum Historii Naturalnej",
#             "http://www.w3.org/2004/02/skos/core#closeMatch": {
#                "__deferred": {
#                   "uri": "http://www.grid.ac/institutes/grid.453560.1"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/National_Museum_of_Natural_History"
#                }
#             },
#             "http://dbpedia.org/property/mapCaption": "Location within Washington, D.C.",
#             "http://dbpedia.org/ontology/director": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Kirk_Johnson_(scientist)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://www.minerals.si.edu/collections.htm"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "700610",
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "https://naturalhistory.si.edu/"
#                }
#             },
#             "http://dbpedia.org/property/visitors": "6000000",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/National_Mall"
#                }
#             },
#             "http://dbpedia.org/property/director": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Kirk_Johnson_(scientist)"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "38.89130020141602",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/National_Museum_of_Natural_History,_Washington.jpg"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "National Museum of Natural History",
#             "http://dbpedia.org/ontology/wikiPageLength": "50665",
#             "http://dbpedia.org/property/caption": "Main facade",
#             "http://dbpedia.org/property/mapframeZoom": "13",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1014614138",
#             "http://dbpedia.org/property/publictransit": "at Federal Triangle",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Museum"
#                }
#             },
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Natural_history"
#                }
#             },
#             "http://dbpedia.org/property/name": "National Museum of Natural History",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/134356831"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/National_Museum_of_Natural_History?oldid=1014614138&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Natural_history"
#                }
#             },
#             "http://dbpedia.org/property/imagesize": "250",
#             "http://dbpedia.org/property/website": {
#                "__deferred": {
#                   "uri": "https://naturalhistory.si.edu/"
#                }
#             },
#             "http://www.georss.org/georss/point": "38.8913 -77.0259",
#             "http://dbpedia.org/ontology/numberOfVisitors": "6000000",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-77.025901794434 38.891300201416)",
#             "http://dbpedia.org/property/location": "National Mall in Washington, D.C., United States",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-77.02590179443359"
#          }
#       ],
#       "__count": "1"
#    }
# }
