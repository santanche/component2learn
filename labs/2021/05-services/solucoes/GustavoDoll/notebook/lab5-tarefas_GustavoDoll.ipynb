# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles (novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = js["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor Tenda dos Milagres: " + grass)
# Out:
# Autor Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}"

concept = "Aspirin"
match = "exact"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Central Park"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
observatory_ref = data.json()
print(json.dumps(observatory_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 186345758,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 427818536,
#       "boundingbox": [
#          "40.7647452",
#          "40.8003135",
#          "-73.9814075",
#          "-73.9496061"
#       ],
#       "lat": "40.7827725",
#       "lon": "-73.9653627406542",
#       "display_name": "Central Park, New York County, New York, United States",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.7651715105441765
#    },
#    {
#       "place_id": 2589176,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 357719603,
#       "boundingbox": [
#          "40.5233147",
#          "40.5234147",
#          "-74.2685346",
#          "-74.2684346"
#       ],
#       "lat": "40.5233647",
#       "lon": "-74.2684846",
#       "display_name": "Central Park, Perth Amboy, Middlesex County, New Jersey, 08861, United States",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.7651715105441765
#    },
#    {
#       "place_id": 136142772,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 193186459,
#       "boundingbox": [
#          "56.1081779",
#          "56.1096228",
#          "-3.3485435",
#          "-3.3456937"
#       ],
#       "lat": "56.108888199999996",
#       "lon": "-3.3471341958577003",
#       "display_name": "Central Park, Cowdenbeath Racewall, Cowdenbeath, Fife, Scotland, KY4 9QQ, United Kingdom",
#       "class": "leisure",
#       "type": "stadium",
#       "importance": 0.6093119917908739
#    },
#    {
#       "place_id": 94534366,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 26379414,
#       "boundingbox": [
#          "22.314655",
#          "22.3176768",
#          "114.1610456",
#          "114.1633507"
#       ],
#       "lat": "22.3161667",
#       "lon": "114.1617575069302",
#       "display_name": "\u5e1d\u67cf\u6d77\u7063 Central Park, \u5927\u89d2\u5480 Tai Kok Tsui, \u6cb9\u5c16\u65fa\u5340 Yau Tsim Mong District, \u4e5d\u9f8d Kowloon, \u9999\u6e2f Hong Kong, \u4e2d\u56fd",
#       "class": "landuse",
#       "type": "residential",
#       "importance": 0.5450441780326737
#    },
#    {
#       "place_id": 25124452,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 2525014059,
#       "boundingbox": [
#          "-33.884653",
#          "-33.884553",
#          "151.2007053",
#          "151.2008053"
#       ],
#       "lat": "-33.884603",
#       "lon": "151.2007553",
#       "display_name": "Central Park, 80, Broadway, Chippendale, Sydney, Council of the City of Sydney, New South Wales, 2000, Australia",
#       "class": "shop",
#       "type": "mall",
#       "importance": 0.5417625908494562
#    },
#    {
#       "place_id": 257918677,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 237577,
#       "boundingbox": [
#          "46.958791",
#          "46.980959",
#          "-123.744762",
#          "-123.666649"
#       ],
#       "lat": "46.969922999999994",
#       "lon": "-123.71012378873237",
#       "display_name": "Central Park, Grays Harbor County, Washington, United States",
#       "class": "place",
#       "type": "locality",
#       "importance": 0.531859350128987,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 90024002,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 14868338,
#       "boundingbox": [
#          "49.894283",
#          "49.8972686",
#          "-97.1497101",
#          "-97.1476287"
#       ],
#       "lat": "49.89629415",
#       "lon": "-97.1486181604383",
#       "display_name": "Central Park, West End, Winnipeg, Manitoba, Canada",
#       "class": "leisure",
#       "type": "park",
#       "importance": 0.4759490106750474
#    },
#    {
#       "place_id": 320087314,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 8796400111,
#       "boundingbox": [
#          "45.6141945",
#          "45.6541945",
#          "-122.673315",
#          "-122.633315"
#       ],
#       "lat": "45.6341945",
#       "lon": "-122.653315",
#       "display_name": "Central Park, Vancouver, Clark County, Washington, 98663, United States",
#       "class": "place",
#       "type": "suburb",
#       "importance": 0.47500000000000003,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 83841184,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 8147648936,
#       "boundingbox": [
#          "-23.44231",
#          "-23.40231",
#          "-51.9796911",
#          "-51.9396911"
#       ],
#       "lat": "-23.42231",
#       "lon": "-51.9596911",
#       "display_name": "Central Park, Maring\u00e1, Regi\u00e3o Geogr\u00e1fica Imediata de Maring\u00e1, Regi\u00e3o Geogr\u00e1fica Intermedi\u00e1ria de Maring\u00e1, Paran\u00e1, Regi\u00e3o Sul, 87015-320, Brasil",
#       "class": "place",
#       "type": "suburb",
#       "importance": 0.47500000000000003,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 17615891,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 1824455113,
#       "boundingbox": [
#          "-22.0969033",
#          "-22.0569033",
#          "-51.48609",
#          "-51.44609"
#       ],
#       "lat": "-22.0769033",
#       "lon": "-51.46609",
#       "display_name": "Central Park, \u00c1lvares Machado, Regi\u00e3o Imediata de Presidente Prudente, Regi\u00e3o Geogr\u00e1fica Intermedi\u00e1ria de Presidente Prudente, S\u00e3o Paulo, Regi\u00e3o Sudeste, 19160000, Brasil",
#       "class": "place",
#       "type": "suburb",
#       "importance": 0.47500000000000003,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    }
# ]

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way"
id = str(observatory_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
observatory_way = data.json()
print(json.dumps(observatory_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1284775 spike-08.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 427818536,
#          "timestamp": "2021-05-01T22:14:29Z",
#          "version": 54,
#          "changeset": 103975471,
#          "user": "C R",
#          "uid": 13021963,
#          "nodes": [
#             6991136395,
#             6991136391,
#             6991124651,
#             6991136407,
#             6991136419,
#             6991124639,
#             6991124627,
#             6991136417,
#             6991136393,
#             6991136389,
#             6991136400,
#             6991124681,
#             6991124669,
#             6991124635,
#             6991136436,
#             6991136425,
#             6991136413,
#             6991124665,
#             6991124654,
#             6991124641,
#             6991124630,
#             6991124676,
#             6991124646,
#             6991124658,
#             6991400337,
#             6991400366,
#             6991414897,
#             6991400329,
#             6991400360,
#             6991414890,
#             6991400322,
#             6991400355,
#             6991400384,
#             6991400316,
#             6991400383,
#             6991400315,
#             6991400348,
#             6991400378,
#             6991400312,
#             6991400309,
#             6991400323,
#             6991400317,
#             6991400350,
#             6991400339,
#             6991400380,
#             6991400313,
#             6991400368,
#             6991400345,
#             6991400374,
#             6991414898,
#             6991400367,
#             6991400308,
#             6991400379,
#             7093980567,
#             6991400344,
#             6991414892,
#             6991400324,
#             7093980560,
#             8032579495,
#             3392519827,
#             8039596500,
#             8039596494,
#             8039596496,
#             8039596490,
#             8039596492,
#             8039941085,
#             7785624629,
#             7785624644,
#             7785624681,
#             7785624660,
#             7785624616,
#             6991414900,
#             6991400375,
#             7785624620,
#             6991400370,
#             6991400307,
#             6991414894,
#             6991400319,
#             6991414887,
#             6991400326,
#             6991400346,
#             6991400314,
#             6991400342,
#             3602661071,
#             6991400371,
#             6991414901,
#             3602661070,
#             6991400334,
#             7830757207,
#             42453674,
#             42453676,
#             2902437013,
#             42433870,
#             1283225217,
#             4347535694,
#             7830685364,
#             2553978278,
#             4347550072,
#             7830757189,
#             1659429013,
#             6991124653,
#             6838446021,
#             1659429064,
#             6838446017,
#             6991124664,
#             1659429078,
#             1825841723,
#             1659429162,
#             6838446016,
#             1659429202,
#             6991124629,
#             1659429228,
#             4347550058,
#             1659429258,
#             4347550067,
#             4997760450,
#             2710141721,
#             2710141733,
#             6991124650,
#             6991136385,
#             6991136397,
#             6991136409,
#             6991136421,
#             6991124631,
#             6991136432,
#             6991136410,
#             6991136433,
#             6991136422,
#             6991124677,
#             6991124666,
#             6991124632,
#             6991124643,
#             6794406110,
#             6991136390,
#             6991136426,
#             6991136437,
#             6991124636,
#             7104620799,
#             6991124659,
#             6991124682,
#             6991136394,
#             7146903295,
#             6991136418,
#             6991136430,
#             6991124640,
#             6991124628,
#             6991124652,
#             6991124663,
#             6991124674,
#             7146903298,
#             6991136387,
#             7120586338,
#             6794406099,
#             6991136398,
#             6991136386,
#             6991136424,
#             6991124673,
#             6991136411,
#             6991136423,
#             6991124633,
#             6991124644,
#             6991124656,
#             6991124667,
#             6991124679,
#             6991136403,
#             6991136416,
#             6991136428,
#             6991136439,
#             6991136435,
#             6991124638,
#             6991124649,
#             6991124634,
#             6991124661,
#             6991124645,
#             6991124672,
#             6991124684,
#             6991124657,
#             6991124678,
#             6991124668,
#             6991124680,
#             6991136392,
#             6991124662,
#             6991136404,
#             6991136438,
#             6991136427,
#             6991124637,
#             6991136415,
#             6991124648,
#             6991124660,
#             6991124671,
#             6991136408,
#             6991124683,
#             6991136402,
#             6991136395
#          ],
#          "tags": {
#             "architect": "Frederick Law Olmstead;Calvert Vaux",
#             "check_date:opening_hours": "2021-05-01",
#             "heritage": "2",
#             "heritage:operator": "nrhp",
#             "heritage:website": "https://www.nps.gov/subjects/nationalregister/index.htm",
#             "leisure": "park",
#             "name": "Central Park",
#             "name:el": "\u039a\u03b5\u03bd\u03c4\u03c1\u03b9\u03ba\u03cc \u03c0\u03ac\u03c1\u03ba\u03bf",
#             "name:fa": "\u067e\u0627\u0631\u06a9 \u0645\u0631\u06a9\u0632\u06cc",
#             "name:hi": "\u0938\u0947\u0902\u091f\u094d\u0930\u0932 \u092a\u093e\u0930\u094d\u0915",
#             "name:ja": "\u4e2d\u592e\u516c\u5712",
#             "name:kn": "\u0cb8\u0cc6\u0c82\u0c9f\u0ccd\u0cb0\u0cb2\u0ccd \u0caa\u0cbe\u0cb0\u0ccd\u0c95\u0ccd",
#             "name:ko": "\uc13c\ud2b8\ub7f4 \ud30c\ud06c",
#             "name:ru": "\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u043f\u0430\u0440\u043a",
#             "name:tr": "Central Park",
#             "name:zh": "\u4e2d\u592e\u516c\u56ed",
#             "nrhp:inscription_date": "1966-10-15",
#             "nrhp:nhl": "yes",
#             "nrhp:nhl:inscription_date": "1963-05-23",
#             "opening_hours": "06:00-01:00",
#             "operator": "Central Park Conservancy",
#             "owner": "NYC Parks",
#             "ref:nrhp": "66000538",
#             "smoking": "no",
#             "website": "https://www.centralparknyc.org",
#             "wikidata": "Q160409",
#             "wikipedia": "en:Central Park"
#          }
#       }
#    ]
# }

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = observatory_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
observatory_dbpedia = data.json()
print(json.dumps(observatory_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Central_Park"
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "https://global.dbpedia.org/id/aobi"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Central Park is een groot stadspark op het eiland Manhattan in de stad New York. Het is het bekendste park van New York en wellicht zelfs van de Verenigde Staten. Central Park komt veelvuldig voor in films en televisieprogramma&#39;s. Met zo\u2019n 25 miljoen bezoekers per jaar is het park het meest bezochte park in de Verenigde Staten.",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/File:SS_Venue_and_Crowd.JPG"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/WikicatHistoricPublicGardens"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://books.google.com/books%3Fid=56yTCwAAQBAJ&pg=PT80"
#                }
#             },
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/315146053"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Authority_control"
#                }
#             },
#             "http://dbpedia.org/property/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Urban_park"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "Central Park \u00e8 il pi\u00f9 grande parco nel distretto di Manhattan, a New York. Si trova nella Uptown. al centro tra i due quartieri residenziali, l&#39;Upper West Side e l&#39;Upper East Side, i quali prendono il nome dalla loro posizione rispetto al parco. Anche le strade che lo circondano prendono il suo nome. \u00c8 uno dei parchi cittadini pi\u00f9 conosciuti del mondo, grazie anche alle sue comparse in numerosi film e telefilm. \u00c8 chiamato il polmone verde di New York.",
#             "http://www.w3.org/2004/02/skos/core#exactMatch": {
#                "__deferred": {
#                   "uri": "http://globalwordnet.org/ili/i84560"
#                }
#             },
#             "http://dbpedia.org/property/image": "Great-Lawn.jpg",
#             "http://www.w3.org/2000/01/rdf-schema#label": "\u0633\u0646\u062a\u0631\u0627\u0644 \u0628\u0627\u0631\u0643",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Upper_East_Side"
#                }
#             },
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Manhattan"
#                }
#             },
#             "http://dbpedia.org/property/altCaption": "Great Lawn before renovations showing large areas of dead grass",
#             "http://dbpedia.org/property/name": "Central Park",
#             "http://dbpedia.org/ontology/wikiPageLength": "256053",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-73.965278625488 40.782222747803)",
#             "http://dbpedia.org/property/photoWidth": "300",
#             "http://dbpedia.org/property/caption": "The Loch",
#             "http://dbpedia.org/property/width": "220",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1026300702",
#             "http://dbpedia.org/property/visitationNum": "about 42 million annually",
#             "http://dbpedia.org/property/mapCaption": "Interactive map showing location of Central Park",
#             "http://dbpedia.org/property/embedded": "--05-23",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Special:FilePath/Southwest_corner_of_Central_Park,_looking_east,_NYC.jpg?width=300"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-73.96527862548828",
#             "http://dbpedia.org/property/align": "right",
#             "http://www.georss.org/georss/point": "40.782222222222224 -73.96527777777777",
#             "http://dbpedia.org/property/open": "6",
#             "http://dbpedia.org/property/owner": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/New_York_City_Department_of_Parks_and_Recreation"
#                }
#             },
#             "http://dbpedia.org/property/publictransit": "[[#Public transport",
#             "http://dbpedia.org/property/direction": "vertical",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Park"
#                }
#             },
#             "http://dbpedia.org/property/operator": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Central_Park_Conservancy"
#                }
#             },
#             "http://dbpedia.org/property/photoCaption": "The Pond and Midtown Manhattan from the Gapstow Bridge",
#             "http://dbpedia.org/property/location": "Manhattan, New York City, United States",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Special:FilePath/Southwest_corner_of_Central_Park,_looking_east,_NYC.jpg"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Central_Park"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "40.78222274780273",
#             "http://dbpedia.org/property/created": "1857",
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Urban_park"
#                }
#             },
#             "http://dbpedia.org/property/photo": "Central Park - The Pond .jpg",
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-location-noun-1"
#                }
#             },
#             "http://dbpedia.org/property/title": "Articles related to Central Park",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Central_Park?oldid=1026300702&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "37536"
#          }
#       ],
#       "__count": "1"
#    }
# }
