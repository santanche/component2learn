# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_drum = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_drum = requests.get(url_drum)
json_drum = data_drum.json()

print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
amado = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tenda dos milagres: " + amado)
# Out:
# Autor de Tenda dos milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "aspirin"
match = "exact"
limit = "10"

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Casa Loma"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 137501591,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 198471666,
#       "boundingbox": [
#          "43.67783",
#          "43.67838",
#          "-79.409834",
#          "-79.40892"
#       ],
#       "lat": "43.6781015",
#       "lon": "-79.409415775",
#       "display_name": "Casa Loma, 1, Austin Terrace, Tarragon Village, Toronto\u2014St. Paul's, Old Toronto, Toronto, Golden Horseshoe, Ontario, M5R 1X9, Canada",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.574579673985169,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 313924,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 141047757,
#       "boundingbox": [
#          "39.1804548",
#          "39.2204548",
#          "-120.7966028",
#          "-120.7566028"
#       ],
#       "lat": "39.2004548",
#       "lon": "-120.7766028",
#       "display_name": "Casa Loma, Placer County, California, United States",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.531859350128987,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 49436790,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 4058989185,
#       "boundingbox": [
#          "31.9609256",
#          "31.9809256",
#          "-102.1421982",
#          "-102.1221982"
#       ],
#       "lat": "31.9709256",
#       "lon": "-102.1321982",
#       "display_name": "Casa Loma, Midland, Midland County, Texas, 79703, United States",
#       "class": "place",
#       "type": "neighbourhood",
#       "importance": 0.45
#    },
#    {
#       "place_id": 333387,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 150951956,
#       "boundingbox": [
#          "33.806963",
#          "33.846963",
#          "-117.0519716",
#          "-117.0119716"
#       ],
#       "lat": "33.826963",
#       "lon": "-117.0319716",
#       "display_name": "Casa Loma, Riverside County, California, 92582, United States",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.45,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 221019199,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 645312130,
#       "boundingbox": [
#          "27.4477982",
#          "27.4532391",
#          "-82.5630371",
#          "-82.5598528"
#       ],
#       "lat": "27.45050845",
#       "lon": "-82.56142774260016",
#       "display_name": "Casa Loma, Manatee County, Florida, United States",
#       "class": "place",
#       "type": "neighbourhood",
#       "importance": 0.45
#    },
#    {
#       "place_id": 361104,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 151423256,
#       "boundingbox": [
#          "35.0908792",
#          "35.1308792",
#          "-106.4058574",
#          "-106.3658574"
#       ],
#       "lat": "35.1108792",
#       "lon": "-106.3858574",
#       "display_name": "Casa Loma, Cedar Crest, Bernalillo County, New Mexico, 87008, United States",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.45,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 46994900,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3792951101,
#       "boundingbox": [
#          "49.8506027",
#          "49.8706027",
#          "-119.545692",
#          "-119.525692"
#       ],
#       "lat": "49.8606027",
#       "lon": "-119.535692",
#       "display_name": "Casa Loma, West Kelowna, Westbank First Nation #9, Regional District of Central Okanagan, British Columbia, V1Z 2E5, Canada",
#       "class": "place",
#       "type": "neighbourhood",
#       "importance": 0.45
#    },
#    {
#       "place_id": 15719412,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 1497314364,
#       "boundingbox": [
#          "-1.7284234",
#          "-1.6884234",
#          "-78.735072",
#          "-78.695072"
#       ],
#       "lat": "-1.7084234",
#       "lon": "-78.715072",
#       "display_name": "Casa Loma, Cacha, Riobamba, Chimborazo, 060112, Ecuador",
#       "class": "place",
#       "type": "hamlet",
#       "importance": 0.45,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 70786155,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 6369689195,
#       "boundingbox": [
#          "40.3622903",
#          "40.3822903",
#          "-4.7749127",
#          "-4.7549127"
#       ],
#       "lat": "40.3722903",
#       "lon": "-4.7649127",
#       "display_name": "Casa Loma, Burgohondo, \u00c1vila, Castilla y Le\u00f3n, 05113, Espa\u00f1a",
#       "class": "place",
#       "type": "locality",
#       "importance": 0.325,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    },
#    {
#       "place_id": 351856,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 150971591,
#       "boundingbox": [
#          "40.9230004",
#          "40.9430004",
#          "-111.8863271",
#          "-111.8663271"
#       ],
#       "lat": "40.9330004",
#       "lon": "-111.8763271",
#       "display_name": "Casa Loma, Centerville, Davis County, Utah, 84014, United States",
#       "class": "place",
#       "type": "locality",
#       "importance": 0.325,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_village.p.20.png"
#    }
# ]

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 198471666

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (3327536 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 198471666,
#          "timestamp": "2020-02-23T17:43:54Z",
#          "version": 14,
#          "changeset": 81372313,
#          "user": "Nate Wessel",
#          "uid": 1108251,
#          "nodes": [
#             6213787832,
#             6213787831,
#             2085988448,
#             6213787830,
#             6213787829,
#             6213787828,
#             6213787827,
#             6213787826,
#             6213787825,
#             6213787824,
#             2085988355,
#             2085988338,
#             2085988243,
#             6213787823,
#             2085988218,
#             6213787822,
#             6213787821,
#             2085988273,
#             6213787820,
#             6213787819,
#             6213787818,
#             2085988225,
#             6213787817,
#             6213787816,
#             6213787815,
#             2085988233,
#             6213787814,
#             2085988229,
#             2085988222,
#             6213787813,
#             2085988203,
#             6213787812,
#             6213787811,
#             2085988149,
#             2085988127,
#             6213787810,
#             2085988104,
#             6213787809,
#             6213787808,
#             2085988095,
#             6213787807,
#             6213787806,
#             2085988082,
#             6213787805,
#             6213787804,
#             2085988068,
#             2085987986,
#             6213787803,
#             6213787802,
#             6213787801,
#             6213787800,
#             6213787799,
#             6213787798,
#             6213787797,
#             6213787796,
#             6213787795,
#             6213787794,
#             6213787793,
#             6213787792,
#             6213787791,
#             6213787790,
#             6213787789,
#             6213787788,
#             6213787787,
#             6213787786,
#             6213787785,
#             6213787784,
#             6213787783,
#             6213787782,
#             6213787781,
#             6213787780,
#             6213787779,
#             6213787778,
#             6213787777,
#             6213787776,
#             6213787775,
#             6213787774,
#             6213787773,
#             6213787772,
#             2085987688,
#             2085987673,
#             2085987665,
#             2085987660,
#             6213787771,
#             2085987655,
#             2085987652,
#             2085987658,
#             2085987662,
#             2085987670,
#             6213787770,
#             6213787769,
#             6213787768,
#             6213787767,
#             6213787766,
#             6213787765,
#             6213787764,
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Castles_in_Canada"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Building102913152"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "\u5361\u8428\u7f57\u9a6c\u57ce\u5821",
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://archive.org/details/casalomamanwhobu0000deni"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "43.6781005859375",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:City_of_Toronto_Heritage_Properties"
#                }
#             },
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Historic_house_museum"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "\u5361\u8428\u7f57\u9a6c\u57ce\u5821\u662f\u4f4d\u4e8e\u52a0\u62ff\u5927\u5b89\u5927\u7565\u7701\u591a\u4f26\u591a\u7684\u4e00\u5904\u540d\u80dc\u3002\u5979\u662f\u4e00\u5ea7\u4eff\u4e2d\u4e16\u7eaa\u7684\u57ce\u5821\uff0c\u7531\u52a0\u62ff\u5927\u5bcc\u7fc1\u4e8e20\u4e16\u7eaa\u521d\u5efa\u9020\u3002",
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "https://global.dbpedia.org/id/8q7q"
#                }
#             },
#             "http://dbpedia.org/property/currentTenants": "Liberty Entertainment Group",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-79.40950012207 43.678100585938)",
#             "http://dbpedia.org/property/owner": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Municipal_government_of_Toronto"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1020884762",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Casa_Loma?oldid=1020884762&ns=0"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Casa_Loma.JPG"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Casa Loma",
#             "http://dbpedia.org/property/startDate": "1911",
#             "http://dbpedia.org/property/architecturalStyle": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Gothic_Revival_architecture_in_Canada"
#                }
#             },
#             "http://dbpedia.org/property/caption": "Exterior of Casa Loma in 2012",
#             "http://dbpedia.org/ontology/buildingStartDate": "1911",
#             "http://dbpedia.org/ontology/buildingEndDate": "1914",
#             "http://dbpedia.org/property/cost": "5.4",
#             "http://dbpedia.org/property/name": "Casa Loma",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/House"
#                }
#             },
#             "http://dbpedia.org/ontology/architecturalStyle": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Gothic_Revival_architecture_in_Canada"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "24019",
#             "http://dbpedia.org/property/title": "Casa Loma Corporation fonds",
#             "http://dbpedia.org/ontology/owner": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Municipal_government_of_Toronto"
#                }
#             },
#             "http://dbpedia.org/property/otherDimensions": "Grounds: 343,253 sqft",
#             "http://dbpedia.org/ontology/cost": "5.4",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-79.40950012207031",
#             "http://dbpedia.org/ontology/wikiPageID": "21969495",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Casa_Loma"
#                }
#             },
#             "http://dbpedia.org/property/inventoryNumber": "Fonds 471",
#             "http://dbpedia.org/property/architect": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/E._J._Lennox"
#                }
#             },
#             "http://dbpedia.org/ontology/floorCount": "7",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Casa_Loma.JPG?width=300"
#                }
#             },
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Ontario"
#                }
#             },
#             "http://dbpedia.org/property/floorArea": "64700",
#             "http://dbpedia.org/property/descriptionUrl": {
#                "__deferred": {
#                   "uri": "http://gencat.eloquent-systems.com/torontodetail.html%3Fkey=579267%7Cdates=%7Caccess_conditions="
#                }
#             },
#             "http://dbpedia.org/property/client": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Henry_Pellatt"
#                }
#             },
#             "http://dbpedia.org/property/completionDate": "1914",
#             "http://dbpedia.org/property/floorCount": "7"
#          }
#       ],
#       "__count": "1"
#    }
# }
