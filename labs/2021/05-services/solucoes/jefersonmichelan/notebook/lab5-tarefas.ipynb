# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles (novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
author = js["d"]["results"][0]["http://dbpedia.org/property/author"]["__deferred"]["uri"]
print("Autor de Tenda dos Milagres: " + author)
# Out:
# Autor de Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Metropolitan Museum of Art"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 258536518,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 3698894,
#       "boundingbox": [
#          "40.7778736",
#          "40.78092",
#          "-73.9651438",
#          "-73.9616917"
#       ],
#       "lat": "40.7794396",
#       "lon": "-73.96338248033601",
#       "display_name": "The Metropolitan Museum of Art, 1000, 5th Avenue, Manhattan Community Board 8, Manhattan, New York County, New York, 10035, United States",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 1.019706212260086,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    }
# ]

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 3698894

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "relation" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1576820 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "relation",
#          "id": 3698894,
#          "timestamp": "2021-07-02T15:36:07Z",
#          "version": 10,
#          "changeset": 107319122,
#          "user": "Natbu2384",
#          "uid": 13362183,
#          "members": [
#             {
#                "type": "way",
#                "ref": 278363061,
#                "role": "outer"
#             }
#          ],
#          "tags": {
#             "addr:city": "New York",
#             "addr:housenumber": "1000",
#             "addr:state": "NY",
#             "addr:street": "5th Avenue",
#             "alt_name:es": "Museo Metropolitan de Arte",
#             "building": "museum",
#             "ele": "28",
#             "fee": "yes",
#             "gnis:feature_id": "957042",
#             "height": "26.8",
#             "museum": "art",
#             "name": "The Metropolitan Museum of Art",
#             "name:en": "The Metropolitan Museum of Art",
#             "name:he": "\u05de\u05d5\u05d6\u05d9\u05d0\u05d5\u05df \u05d4\u05de\u05d8\u05e8\u05d5\u05e4\u05d5\u05dc\u05d9\u05d8\u05df \u05dc\u05d0\u05de\u05e0\u05d5\u05ea",
#             "name:hi": "\u0915\u0932\u093e \u0915\u093e \u092e\u0939\u093e\u0928\u0917\u0930\u0940\u092f \u0938\u0902\u0917\u094d\u0930\u0939\u093e\u0932\u092f",
#             "name:ru": "\u041c\u0443\u0437\u0435\u0439 \u0438\u0441\u043a\u0443\u0441\u0441\u0442\u0432\u0430 \u041c\u0435\u0442\u0440\u043e\u043f\u043e\u043b\u0438\u0442\u0435\u043d",
#             "nycdoitt:bin": "1083810",
#             "opening_hours": "Mo-Th 10:00-17:30; Fr-Sa 10:00-21:00; Su 10:00-17:30",
#             "phone": "+1 212-535-7710",
#             "ref:nrhp": "86003556",
#             "short_name": "The Met",
#             "source": "bing",
#             "tourism": "museum",
#             "type": "multipolygon",
#             "website": "http://www.metmuseum.org/",
#             "wheelchair": "yes",
#             "wikidata": "Q160236",
#             "wikipedia": "en:Metropolitan Museum of Art"
#          }
#       }
#    ]
# }

# %%
print(museum_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:Metropolitan Museum of Art

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Metropolitan_Museum_of_Art"
#             },
#             "http://www.georss.org/georss/point": "40.7795457 -73.962916",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/The_Burghers_of_Calais"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://d-nb.info/gnd/108578200X"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Historic_districts_in_Manhattan"
#                }
#             },
#             "http://dbpedia.org/property/alt": "--04-13",
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Le Metropolitan Museum of Art de New York (aussi connu sous le nom abr\u00e9g\u00e9 de the Met) est l&#39;un des plus grands mus\u00e9es d&#39;art au monde. Ouvert au public depuis le 20 f\u00e9vrier 1872, il est situ\u00e9 dans l&#39;arrondissement de Manhattan, du c\u00f4t\u00e9 de Central Park sur la Cinqui\u00e8me Avenue et \u00e0 la hauteur de la 82e rue. Le mus\u00e9e comprend \u00e9galement un autre b\u00e2timent, The Cloisters (les clo\u00eetres), \u00e0 l&#39;extr\u00e9mit\u00e9 nord de l&#39;\u00eele, dans Fort Tryon Park (quartier de Washington Heights). Cette annexe pr\u00e9sente des \u0153uvres d&#39;art m\u00e9di\u00e9val et des reconstitutions de clo\u00eetres europ\u00e9ens.",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Metropolitan Museum of Art",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Metropolitan_Museum_of_Art_entrance_NYC.JPG?width=300"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://libmma.contentdm.oclc.org/cdm/"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "37535",
#             "http://dbpedia.org/ontology/abstract": "El Metropolitan Museum of Art, o simplement Met, \u00e9s un museu d&#39;art de la ciutat de Nova York, i un dels museus d&#39;art m\u00e9s destacats i visitats del m\u00f3n. Situat a la ciutat de Nova York, al centre de l&#39;illa de Manhattan al costat est de Central Park, a la cinquena avinguda, a l&#39;altura del carrer 82. Va obrir les seves portes el 20 de febrer de 1872. La col\u00b7lecci\u00f3 del museu cont\u00e9 de m\u00e9s de dos milions d&#39;obres d&#39;art de tot el m\u00f3n. Les col\u00b7leccions abasten des de tresors de l&#39;antiguitat cl\u00e0ssica, representada a les seves galeries de Gr\u00e8cia i Xipre, fins a pintures i escultures de quasi tots els mestres d&#39;Europa i, tamb\u00e9, una gran col\u00b7lecci\u00f3 d&#39;obres dels Estats Units. S&#39;hi exposen obres mestres de Rafael, Tiziano, el Greco, Rembrandt, Vel\u00e1zquez, Picasso, Pollock, Braque, Joan Mir\u00f3, Salvador Dal\u00ed i molts m\u00e9s. A m\u00e9s a m\u00e9s, el museu conserva un vast patrimoni d&#39;art egipci, afric\u00e0, asi\u00e0tic, d&#39;Oceania, l&#39;Orient Pr\u00f2xim, rom\u00e0 d&#39;Orient i isl\u00e0mic. Les galeries inclouen grans obres d&#39;art europeu del segle xix, amb un \u00e8mfasi particular en els pintors impressionistes i postimpressionistes, aix\u00ed com una gran col\u00b7lecci\u00f3 d&#39;escultures de Rodin. Cal mencionar que aquestes col\u00b7leccions s&#39;exposen a la seva seu principal, situada de la cinquena avinguda. No obstant aix\u00f2, el museu t\u00e9 sengles seccions en altres llocs de Nova York\u02d0 The Met Cloisters, museu refernt a nivell mundial d&#39;art medieval, i The Met Breuer, dedicat a l&#39;art contemporani.",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Start_date_and_age"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/WikicatMuseumsInNewYork"
#                }
#             },
#             "http://dbpedia.org/property/caption": "Entrance facade",
#             "http://dbpedia.org/property/publictransit": "at 77th Street",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1025515081",
#             "http://dbpedia.org/ontology/numberOfVisitors": "1124759",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Fifth_Avenue"
#                }
#             },
#             "http://dbpedia.org/property/visitors": "1124759",
#             "http://xmlns.com/foaf/0.1/name": "The Metropolitan Museum of Art",
#             "http://dbpedia.org/property/imageSize": "250",
#             "http://dbpedia.org/ontology/wikiPageLength": "142265",
#             "http://dbpedia.org/ontology/director": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Max_Hollein"
#                }
#             },
#             "http://dbpedia.org/property/director": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Max_Hollein"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Metropolitan_Museum_of_Art_entrance_NYC.JPG"
#                }
#             },
#             "http://dbpedia.org/property/mapframeHeight": "180",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Museum"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-73.962913513184 40.779544830322)",
#             "http://dbpedia.org/property/logoUpright": "0.25",
#             "http://dbpedia.org/property/website": "--06-24",
#             "http://dbpedia.org/property/location": "1000",
#             "http://dbpedia.org/property/width": "500",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/126238294"
#                }
#             },
#             "http://dbpedia.org/property/logo": "The Metropolitan Museum of Art Logo.svg",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "40.77954483032227",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-73.96291351318359",
#             "http://dbpedia.org/property/height": "250",
#             "http://dbpedia.org/property/mapframeWidth": "250",
#             "http://dbpedia.org/property/established": "1870-04-13",
#             "http://www.w3.org/2002/07/owl#differentFrom": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Museum_of_Modern_Art"
#                }
#             },
#             "http://dbpedia.org/property/collectionSize": "2000000",
#             "http://dbpedia.org/ontology/foundingDate": "1870-04-13",
#             "http://www.w3.org/2004/02/skos/core#closeMatch": {
#                "__deferred": {
#                   "uri": "http://www.grid.ac/institutes/grid.421319.c"
#                }
#             },
#             "http://dbpedia.org/property/name": "The Metropolitan Museum of Art",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Metropolitan_Museum_of_Art"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#seeAlso": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Looted_art"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Metropolitan_Museum_of_Art?oldid=1025515081&ns=0"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
