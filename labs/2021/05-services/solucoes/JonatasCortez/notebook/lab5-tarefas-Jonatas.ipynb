# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_drum = "https://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_drum = requests.get(url_drum)
json_drum = data_drum.json()

print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles: " + grass)
# Out:
# Autor de Tent of Miracles: http://dbpedia.org/resource/Jorge_Amado

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageDisambiguates": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(album)"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "154",
#             "http://dbpedia.org/ontology/wikiPageID": "37750149",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles?oldid=933203748&ns=0"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://www.wikidata.org/entity/Q7700759"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Disambiguation"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "933203748",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles"
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
uri_mesh = json_mi[0]["resource"]
print("uri do recurso: " + uri_mesh)
bar = str.rindex(uri_mesh, "/")
print("código do recurso: " + uri_mesh[bar+1:])
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso: D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "National Gallery"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()
print(json.dumps(museum_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 83130490,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 4372002,
#       "boundingbox": [
#          "51.5082611",
#          "51.5095106",
#          "-0.1301357",
#          "-0.1273245"
#       ],
#       "lat": "51.50888405",
#       "lon": "-0.1283741501862351",
#       "display_name": "National Gallery, Charing Cross Road, Covent Garden, City of Westminster, London, Greater London, England, WC2N 5DN, United Kingdom",
#       "class": "tourism",
#       "type": "gallery",
#       "importance": 0.7636382548891893
#    },
#    {
#       "place_id": 258436322,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 2983284,
#       "boundingbox": [
#          "40.1782751",
#          "40.1793115",
#          "44.5134389",
#          "44.514851"
#       ],
#       "lat": "40.178763950000004",
#       "lon": "44.513897970771346",
#       "display_name": "\u0531\u0566\u0563\u0561\u0575\u056b\u0576 \u057a\u0561\u057f\u056f\u0565\u0580\u0561\u057d\u0580\u0561\u0570, 1, \u0531\u0580\u0561\u0574\u056b \u0583\u0578\u0572\u0578\u0581, \u053f\u0565\u0576\u057f\u0580\u0578\u0576, \u0535\u0580\u0587\u0561\u0576, 0010, \u0540\u0561\u0575\u0561\u057d\u057f\u0561\u0576",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.43082628035454323,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 95900934,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 24785631,
#       "boundingbox": [
#          "46.0533926",
#          "46.054568",
#          "14.4997951",
#          "14.5007093"
#       ],
#       "lat": "46.0540237",
#       "lon": "14.500261279718178",
#       "display_name": "Narodna galerija, 9, Puharjeva ulica, Vrta\u010da, Trnovo, Ljubljana, Upravna Enota Ljubljana, 1000, Slovenija",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.41470152591076137,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 98777507,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 31106819,
#       "boundingbox": [
#          "59.915817",
#          "59.9165902",
#          "10.7369473",
#          "10.7381348"
#       ],
#       "lat": "59.916203550000006",
#       "lon": "10.737540454152805",
#       "display_name": "Nasjonalgalleriet, Universitetsgata, Vika, Sentrum, Oslo, 0164, Norge",
#       "class": "building",
#       "type": "yes",
#       "importance": 0.34248064634289366
#    },
#    {
#       "place_id": 59338202,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 5274840822,
#       "boundingbox": [
#          "25.1411803",
#          "25.1412803",
#          "55.2258243",
#          "55.2259243"
#       ],
#       "lat": "25.1412303",
#       "lon": "55.2258743",
#       "display_name": "The National Gallery, \u0634\u0627\u0631\u0639 \u0627\u0644\u0633\u0631\u0643\u0627\u0644, \u0627\u0644\u0642\u0648\u0632 \u0627\u0644\u0635\u0646\u0627\u0639\u064a\u0629 1, \u0627\u0644\u0642\u0648\u0632 \u0627\u0644\u0635\u0646\u0627\u0639\u064a\u0629, \u062f\u0628\u064a, 57566, \u0627\u0644\u0625\u0645\u0627\u0631\u0627\u062a \u0627\u0644\u0639\u0631\u0628\u064a\u0629 \u0627\u0644\u0645\u062a\u062d\u062f\u0629",
#       "class": "tourism",
#       "type": "museum",
#       "importance": 0.201,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_museum.p.20.png"
#    },
#    {
#       "place_id": 69070649,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 6210502973,
#       "boundingbox": [
#          "52.1449187",
#          "52.1450187",
#          "5.4043163",
#          "5.4044163"
#       ],
#       "lat": "52.1449687",
#       "lon": "5.4043663",
#       "display_name": "National Gallery, 171, Heiligenbergerweg, Randenbroek, Amersfoort, Utrecht, Nederland, 3816AJ, Nederland",
#       "class": "tourism",
#       "type": "gallery",
#       "importance": 0.201
#    },
#    {
#       "place_id": 16524058,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 1639411830,
#       "boundingbox": [
#          "39.5242807",
#          "39.5243807",
#          "46.0229185",
#          "46.0230185"
#       ],
#       "lat": "39.5243307",
#       "lon": "46.0229685",
#       "display_name": "National Gallery, \u054d\u056b\u057d\u0561\u056f\u0561\u0576 \u0583\u0578\u0572\u0578\u0581, \u054d\u056b\u057d\u056b\u0561\u0576, \u054d\u056b\u057d\u056b\u0561\u0576\u056b \u057f\u0561\u0580\u0561\u056e\u0561\u0577\u0580\u057b\u0561\u0576, \u054d\u0575\u0578\u0582\u0576\u056b\u0584\u056b \u0574\u0561\u0580\u0566, 3501, \u0540\u0561\u0575\u0561\u057d\u057f\u0561\u0576",
#       "class": "amenity",
#       "type": "arts_centre",
#       "importance": 0.201,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_art_gallery2.p.20.png"
#    },
#    {
#       "place_id": 792918,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 279920371,
#       "boundingbox": [
#          "53.3407314",
#          "53.3408314",
#          "-6.2509381",
#          "-6.2508381"
#       ],
#       "lat": "53.3407814",
#       "lon": "-6.2508881",
#       "display_name": "National Gallery, Merrion Square West, Dublin, County Dublin, Leinster, DUBLIN 2, \u00c9ire / Ireland",
#       "class": "highway",
#       "type": "bus_stop",
#       "importance": 0.201,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//transport_bus_stop2.p.20.png"
#    },
#    {
#       "place_id": 177910738,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 372530751,
#       "boundingbox": [
#          "19.3157403",
#          "19.316142",
#          "-81.3789226",
#          "-81.3786306"
#       ],
#       "lat": "19.31593905",
#       "lon": "-81.37878148463807",
#       "display_name": "The National Gallery, Esterley Tibbetts Highway, Dog City, The Rock, George Town, KY1-9006, Cayman Islands",
#       "class": "tourism",
#       "type": "gallery",
#       "importance": 0.201
#    },
#    {
#       "place_id": 45759306,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3609864448,
#       "boundingbox": [
#          "51.5088702",
#          "51.5089702",
#          "-0.1275319",
#          "-0.1274319"
#       ],
#       "lat": "51.5089202",
#       "lon": "-0.1274819",
#       "display_name": "National Caf\u00e9, Saint Martin's Place, Covent Garden, City of Westminster, London, Greater London, England, WC2N 5DN, United Kingdom",
#       "class": "amenity",
#       "type": "cafe",
#       "importance": 0.101,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//food_cafe.p.20.png"
#    }
# ]

# %%
print(museum_ref[0]["osm_id"])
# Out:
# 4372002

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()
print(json.dumps(museum_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (2661565 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 4372002,
#          "timestamp": "2020-09-10T17:02:59Z",
#          "version": 38,
#          "changeset": 90714492,
#          "user": "Cebderby",
#          "uid": 705850,
#          "nodes": [
#             1835289528,
#             1835289527,
#             6173728483,
#             1637789597,
#             1637789594,
#             1637789595,
#             1637789593,
#             1637789596,
#             1637789592,
#             26631003,
#             26631004,
#             1637789582,
#             1637789585,
#             1637789581,
#             1637789580,
#             1637789574,
#             1637789575,
#             1637789573,
#             6173732718,
#             6173732714,
#             1637789571,
#             1637789576,
#             1637789569,
#             1637789518,
#             1637789486,
#             1637789499,
#             1637789502,
#             1637789525,
#             1637789528,
#             1637789557,
#             6173732721,
#             6173728480,
#             1637789562,
#             1637789551,
#             1637789549,
#             1637789529,
#             1637789534,
#             1637789526,
#             1637789530,
#             1637789532,
#             1637789539,
#             1637789531,
#             1637789533,
#             1637789536,
#             1637789540,
#             1637789541,
#             1637789544,
#             1637789546,
#             1637789542,
#             345859447,
#             345859448,
#             345859449,
#             345859450,
#             1637789550,
#             1637789552,
#             1637789555,
#             1637789559,
#             1637789554,
#             1637789556,
#             6173728482,
#             1637789558,
#             1637789561,
#             1637789563,
#             1637789566,
#             1637789565,
#             1637789567,
#             733691174,
#             6173732715,
#             7894448057,
#             1637789578,
#             6173732692,
#             1835289528
#          ],
#          "tags": {
#             "addr:city": "London",
#             "building": "yes",
#             "building:levels": "2",
#             "fee": "no",
#             "name": "National Gallery",
#             "name:de": "Nationalgalerie",
#             "name:en": "National Gallery",
#             "name:es": "Galer\u00eda Nacional.",
#             "name:gl": "Galer\u00eda Nacional",
#             "name:ru": "\u041d\u0430\u0446\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u0430\u044f \u0433\u0430\u043b\u0435\u0440\u0435\u044f",
#             "name:uk": "\u041d\u0430\u0446\u0456\u043e\u043d\u0430\u043b\u044c\u043d\u0430 \u0433\u0430\u043b\u0435\u0440\u0435\u044f",
#             "name:zh": "\u570b\u5bb6\u7f8e\u8853\u9928",
#             "opening_hours": "Sa-Th 10:00-18:00; Fr 10:00-21:00",
#             "postal_code": "WC2N 5DN",
#             "source": "Bing",
#             "toilets:wheelchair": "yes",
#             "tourism": "gallery",
#             "website": "https://www.nationalgallery.org.uk/",
#             "wheelchair": "yes",
#             "wikidata": "Q180788",
#             "wikipedia": "en:National Gallery"
#          }
#       }
#    ]
# }
