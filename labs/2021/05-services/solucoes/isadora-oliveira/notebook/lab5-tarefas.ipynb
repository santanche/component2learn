# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_drum = "http://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"
data_drum = requests.get(url_drum)
json_drum = data_drum.json()
print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
grass = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor da Tenda dos Milagres: " + grass)
# Out:
# Autor da Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "St Paul's Cathedral"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
cathedral_ref = data.json()
print(json.dumps(cathedral_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 177039372,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 369161987,
#       "boundingbox": [
#          "51.5133982",
#          "51.5141715",
#          "-0.0995735",
#          "-0.0972996"
#       ],
#       "lat": "51.51378715",
#       "lon": "-0.09845055141832956",
#       "display_name": "St Paul's Cathedral, Saint Paul's Church Yard, Blackfriars, City of London, Greater London, England, EC4M 8AD, United Kingdom",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.947082738787663,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 87934724,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 13127644,
#       "boundingbox": [
#          "-37.8171982",
#          "-37.816401",
#          "144.9673061",
#          "144.9678814"
#       ],
#       "lat": "-37.816872149999995",
#       "lon": "144.96760952877617",
#       "display_name": "Saint Paul's Cathedral, 202, Flinders Street, Melbourne, Southbank, Melbourne, City of Melbourne, Victoria, 3000, Australia",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.7882193556092346,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 102241793,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 45403864,
#       "boundingbox": [
#          "56.4608374",
#          "56.4611955",
#          "-2.9684648",
#          "-2.9677901"
#       ],
#       "lat": "56.46102325",
#       "lon": "-2.968099283110078",
#       "display_name": "St Paul's Cathedral, Exchange Court, City Centre, Dundee, Dundee City, Scotland, DD1 3DE, United Kingdom",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.7420028734125638,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 95709101,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 27044968,
#       "boundingbox": [
#          "35.8862135",
#          "35.8865697",
#          "14.4037713",
#          "14.4044924"
#       ],
#       "lat": "35.88639955",
#       "lon": "14.404131409721227",
#       "display_name": "St Paul's Cathedral, Misra\u0127 l-Ar\u010bisqof, Mdina, L-Imdina, Tramuntana, MDN 1191, Malta",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.7310053078346157,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 117283483,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 119789042,
#       "boundingbox": [
#          "42.9855847",
#          "42.9862395",
#          "-81.2499792",
#          "-81.2492015"
#       ],
#       "lat": "42.985912049999996",
#       "lon": "-81.24944027069385",
#       "display_name": "St. Paul's Cathedral, 472, Richmond Street, London, Southwestern Ontario, Ontario, N6A 3E6, Canada",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.6879976529248165,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 209713687,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 556912651,
#       "boundingbox": [
#          "-15.9569626",
#          "-15.9567465",
#          "-5.7204056",
#          "-5.7201106"
#       ],
#       "lat": "-15.95685455",
#       "lon": "-5.720258104021277",
#       "display_name": "St. Paul\u2019s Cathedral, Casons, Kunji Field, St Paul's, Saint Helena, STHL 1ZZ, Saint Helena, Ascension and Tristan da Cunha",
#       "class": "building",
#       "type": "church",
#       "importance": 0.6813117306116221
#    },
#    {
#       "place_id": 116897085,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 119506012,
#       "boundingbox": [
#          "42.882719",
#          "42.8830875",
#          "-78.8764186",
#          "-78.8757986"
#       ],
#       "lat": "42.8829076",
#       "lon": "-78.87612946683214",
#       "display_name": "St. Paul's Cathedral, 128, Pearl Street, Downtown, Buffalo, Erie County, New York, 14202, United States",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.6288763567136217,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 188292838,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 427924203,
#       "boundingbox": [
#          "50.448921",
#          "50.4494255",
#          "-104.6163821",
#          "-104.6159019"
#       ],
#       "lat": "50.449174299999996",
#       "lon": "-104.61602912508118",
#       "display_name": "St. Paul's Cathedral, 12th Avenue, Regina, Regina (city), Saskatchewan, S4P 3X1, Canada",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.6075345213990273,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 167473837,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 317840309,
#       "boundingbox": [
#          "43.0483359",
#          "43.0485822",
#          "-76.1499468",
#          "-76.149447"
#       ],
#       "lat": "43.04843535",
#       "lon": "-76.14969987861556",
#       "display_name": "Saint Paul's Cathedral, 310, Montgomery Street, Downtown, Syracuse, Onondaga County, New York, 13202, United States",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.581472839091896,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    },
#    {
#       "place_id": 117692842,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 116893811,
#       "boundingbox": [
#          "-45.8737248",
#          "-45.8734036",
#          "170.50217",
#          "170.5027602"
#       ],
#       "lat": "-45.873564650000006",
#       "lon": "170.50251070802148",
#       "display_name": "St Paul's Cathedral, 228, Stuart Street, Dunedin Central, Dunedin, Dunedin City, Otago, 9016, New Zealand / Aotearoa",
#       "class": "amenity",
#       "type": "place_of_worship",
#       "importance": 0.553150759043076,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//place_of_worship_unknown3.p.20.png"
#    }
# ]

# %%
print(cathedral_ref[0]["osm_id"])
# Out:
# 369161987

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"
element_type = "way" # types: node, way, or relation
id = str(cathedral_ref[0]["osm_id"])
format = "json"
url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)
data = requests.get(url)
cathedral_way = data.json()
print(json.dumps(cathedral_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (2805130 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 369161987,
#          "timestamp": "2019-12-20T08:29:50Z",
#          "version": 29,
#          "changeset": 78673395,
#          "user": "\u53f6\u4ef2\u9f99",
#          "uid": 5420416,
#          "nodes": [
#             3729757300,
#             3729757291,
#             3729757290,
#             3729757289,
#             3729757276,
#             3729757270,
#             3729757281,
#             6221019999,
#             3729757271,
#             3729757267,
#             3729757266,
#             3729757292,
#             3729757293,
#             5947865293,
#             3729757309,
#             3729757311,
#             3729757310,
#             6221209598,
#             6221408612,
#             6221408614,
#             6221408613,
#             6221209599,
#             3729757674,
#             6221064531,
#             6221064569,
#             6221064499,
#             6221064582,
#             6221064532,
#             6221064574,
#             6221064566,
#             6221064559,
#             6221064571,
#             6221064504,
#             3729757731,
#             3729757728,
#             3729757729,
#             3729757708,
#             3729757707,
#             3729757688,
#             3729757689,
#             3729757682,
#             3729757684,
#             3729757691,
#             3729757692,
#             3729757690,
#             3729757693,
#             3729757698,
#             3729757701,
#             3729757697,
#             3729757702,
#             3729757703,
#             3729757704,
#             3729757712,
#             3729757711,
#             3729757735,
#             3729757736,
#             3729757741,
#             3729757744,
#             3729757739,
#             3729757740,
#             3729757746,
#             3729757747,
#             3729757772,
#             3729757771,
#             3729757773,
#             3729757775,
#             3729757777,
#             3729757778,
#             3729757780,
#             3729757782,
#             3729757779,
#             3729757781,
#             3729757783,
#             3729757786,
#             3729757795,
#             3729757801,
#             3729757803,
#             3729757805,
#             3729757807,
#             3729757809,
#             3729757808,
#             3729757806,
#             3729757804,
#             3729757802,
#             3729757794,
#             3729757792,
#             3729757788,
#             3729757793,
#             3729757799,
#             3729757800,
#             3729757797,
#             3729757798,
#             3729757789,
#             3729757790,
#             3729757776,
#             3729757774,
#             3729757765,
#             3729757767,
#             3729757763,
#             3729757764,
#             3729757769,
#             3729757770,
#             3729757766,
#             3729757768,
#             3729757750,
#             3729757749,
#             3729757732,
#             3729757733,
#             3729757730,
#             3729757734,
#             3729757738,
#             3729757742,
#             3729757737,
#             3729757743,
#             3729757748,
#             3729757751,
#             3729757745,
#             3729757754,
#             3729757757,
#             3729757758,
#             3729757755,
#             3729757756,
#             3729757761,
#             3729757762,
#             3729757759,
#             3729757760,
#             3729757752,
#             3729757753,
#             3729757727,
#             3729757726,
#             3729757705,
#             3729757706,
#             3729757699,
#             3729757696,
#             3729757687,
#             3729757681,
#             3729757683,
#             3729757680,
#             3729757679,
#             3729757678,
#             3729757673,
#             3729757672,
#             3729757671,
#             3729757670,
#             3729757668,
#             3729757669,
#             3729757667,
#             3729757666,
#             3729757664,
#             3729757665,
#             3729757663,
#             3729757662,
#             3729757660,
#             3729757661,
#             3729757659,
#             3729757658,
#             3729757657,
#             3729757656,
#             3729757654,
#             3729757652,
#             3729757655,
#             3729757653,
#             3729757650,
#             3729757649,
#             3729757651,
#             3729757648,
#             3729757646,
#             3729757645,
#             3729757647,
#             3729757644,
#             3729757642,
#             3729757641,
#             3729757643,
#             3729757640,
#             3729757639,
#             3729757638,
#             3729757636,
#             3729757637,
#             3729757631,
#             3729757630,
#             3729757626,
#             3729757322,
#             3729757627,
#             3729757625,
#             3729757321,
#             3729757319,
#             3729757296,
#             3729757297,
#             3729757288,
#             3729757287,
#             3729757275,
#             3729757274,
#             3729757268,
#             3729757264,
#             3729757269,
#             3729757265,
#             3729757262,
#             3729757260,
#             3729757249,
#             3729757244,
#             3729757242,
#             3729757240,
#             3729757238,
#             3729757236,
#             3729757235,
#             3729757237,
#             3729757239,
#             3729757241,
#             3729757243,
#             3729757245,
#             3729757250,
#             3729757254,
#             3729757257,
#             3729757255,
#             3729757247,
#             3729757246,
#             3729757252,
#             3729757251,
#             3729757259,
#             3729757258,
#             3729757285,
#             3729757286,
#             3729757303,
#             3729757302,
#             3729757307,
#             3729757306,
#             3729757301,
#             3729757299,
#             3729757305,
#             3729757304,
#             3729757314,
#             3729757315,
#             3729757634,
#             3729757633,
#             3729757635,
#             3729757632,
#             3729757628,
#             3729757324,
#             3729757629,
#             3729757323,
#             3729757318,
#             3729757317,
#             3729757320,
#             3729757316,
#             3729757313,
#             3729757312,
#             3729757298,
#             3729757300
#          ],
#          "tags": {
#             "addr:city": "London",
#             "addr:housename": "Saint Paul's Cathedral",
#             "addr:postcode": "EC4M 8AD",
#             "addr:street": "St Paul's Church Yard",
#             "amenity": "place_of_worship",
#             "architect": "Christopher Wren",
#             "architect:wikidata": "Q170373",
#             "building": "cathedral",
#             "building:part": "no",
#             "dedication:wikidata": "Q9200",
#             "denomination": "anglican",
#             "height": "35",
#             "historic": "building",
#             "name": "St Paul's Cathedral",
#             "name:af": "St. Paulus se katedraal",
#             "name:en": "St Paul's Cathedral",
#             "name:es": "Catedral de San Pablo",
#             "name:fr": "Cath\u00e9drale Saint-Paul",
#             "name:he": "\u05e7\u05ea\u05d3\u05e8\u05dc\u05ea \u05e1\u05e0\u05d8 \u05e4\u05d5\u05dc",
#             "name:ja": "\u30bb\u30f3\u30c8\u30dd\u30fc\u30eb\u5927\u8056\u5802",
#             "name:ko": "\uc138\uc778\ud2b8 \ud3f4 \ub300\uc131\ub2f9",
#             "name:lt": "\u0160v. Pauliaus katedra",
#             "name:pl": "Katedra \u015bw. Paw\u0142a w Londynie",
#             "name:uk": "\u0421\u043e\u0431\u043e\u0440 \u0441\u0432\u044f\u0442\u043e\u0433\u043e \u041f\u0430\u0432\u043b\u0430",
#             "name:zh": "\u8056\u4fdd\u7f85\u5927\u6559\u5802",
#             "opening_hours": "Mo-Sa 08:30-16:00",
#             "payment:cash": "yes",
#             "payment:mastercard": "yes",
#             "payment:visa": "yes",
#             "religion": "christian",
#             "short_name": "Saint Paul's",
#             "start_date": "1711",
#             "tourism": "attraction",
#             "website": "http://www.stpauls.co.uk/",
#             "wheelchair": "limited",
#             "wheelchair:description": "Accessible entrance on south side signposted from main west front entrance.",
#             "wikidata": "Q173882",
#             "wikipedia": "en:St Paul's Cathedral"
#          }
#       }
#    ]
# }

# %%
print(cathedral_way["elements"][0]["tags"]["wikipedia"])
# Out:
# en:St Paul's Cathedral
