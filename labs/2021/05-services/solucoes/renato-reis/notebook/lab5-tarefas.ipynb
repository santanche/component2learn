# %% [markdown]
# # Laboratório 5 - Bloco 2
#
# Nas tarefas a seguir o número de células de resposta pode ser aumentado conforme a necessidade.

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Alice's Adventures in Wonderland"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Alice's_Adventures_in_Wonderland"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/'Tis_the_Voice_of_the_Lobster"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://kk.dbpedia.org/resource/\u0410\u043b\u0438\u0441\u0430_\u0493\u0430\u0436\u0430\u0439\u044b\u043f\u0442\u0430\u0440_\u0435\u043b\u0456\u043d\u0434\u0435"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "\u0645\u063a\u0627\u0645\u0631\u0627\u062a \u0623\u0644\u064a\u0633 \u0641\u064a \u0628\u0644\u0627\u062f \u0627\u0644\u0639\u062c\u0627\u0626\u0628 (\u0628\u0627\u0644\u0625\u0646\u062c\u0644\u064a\u0632\u064a\u0629: Alice&#39;s Adventures in Wonderland)\u200f\u060c \u062a\u062e\u062a\u0635\u0631 \u0639\u0627\u062f\u0629 \u0625\u0644\u0649 \u0623\u0644\u064a\u0633 \u0641\u064a \u0628\u0644\u0627\u062f \u0627\u0644\u0639\u062c\u0627\u0626\u0628 (\u0628\u0627\u0644\u0625\u0646\u062c\u0644\u064a\u0632\u064a\u0629: Alice in Wonderland)\u200f \u0647\u064a \u0631\u0648\u0627\u064a\u0629 \u0644\u0644\u0623\u0637\u0641\u0627\u0644 \u0645\u0643\u062a\u0648\u0628\u0629 \u0633\u0646\u0629 1865 \u0645\u0646 \u0642\u0628\u0644 \u0639\u0627\u0644\u0645 \u0627\u0644\u0631\u064a\u0627\u0636\u064a\u0627\u062a \u0627\u0644\u0625\u0646\u062c\u0644\u064a\u0632\u064a \u062a\u0634\u0627\u0631\u0644\u0632 \u0644\u0648\u062a\u0648\u064a\u062f\u062c \u062f\u0648\u062f\u0633\u0648\u0646 \u062a\u062d\u062a \u0627\u0633\u0645\u0647 \u0627\u0644\u0645\u0633\u062a\u0639\u0627\u0631 \u0644\u0648\u064a\u0633 \u0643\u0627\u0631\u0648\u0644. \u0648\u0647\u064a \u062a\u062d\u0643\u064a \u0639\u0646 \u0641\u062a\u0627\u0629 \u062a\u062f\u0639\u0649 \u0623\u0644\u064a\u0633 \u0648\u0627\u0644\u062a\u064a \u062a\u0633\u0642\u0637 \u0645\u0646 \u062e\u0644\u0627\u0644 \u062c\u062d\u0631 \u0623\u0631\u0646\u0628 \u0625\u0644\u0649 \u0639\u0627\u0644\u0645 \u062e\u064a\u0627\u0644\u064a \u062a\u0633\u0643\u0646\u0647\u0627 \u0645\u062e\u0644\u0648\u0642\u0627\u062a \u063a\u0631\u064a\u0628\u0629. \u062a\u062a\u0644\u0627\u0639\u0628 \u0627\u0644\u062d\u0643\u0627\u064a\u0629 \u0628\u0627\u0644\u0645\u0646\u0637\u0642 \u0645\u0645\u0627 \u0623\u0639\u0637\u0627\u0647\u0627 \u0634\u0639\u0628\u064a\u0629 \u062f\u0627\u0626\u0645\u0629 \u0639\u0646\u062f \u0627\u0644\u0623\u0637\u0641\u0627\u0644 \u0648\u0627\u0644\u0628\u0627\u0644\u063a\u064a\u0646 \u0639\u0644\u0649 \u062d\u062f \u0633\u0648\u0627\u0621. \u0648\u0647\u064a \u062a\u0639\u062a\u0628\u0631 \u0648\u0627\u062d\u062f\u0629 \u0645\u0646 \u0623\u0641\u0636\u0644 \u0627\u0644\u0623\u0645\u062b\u0644\u0629 \u0639\u0644\u0649 \u0646\u0648\u0639 . \u0633\u0631\u062f \u0627\u0644\u0642\u0635\u0629 \u0648\u0647\u064a\u0643\u0644\u062a\u0647\u0627 \u0648\u0634\u062e\u0635\u064a\u0627\u062a\u0647\u0627 \u0643\u0627\u0646\u062a \u062c\u062f \u0645\u0624\u062b\u0631\u0629 \u0641\u064a \u0643\u0644 \u0645\u0646 \u0627\u0644\u062b\u0642\u0627\u0641\u0629 \u0627\u0644\u0634\u0639\u0628\u064a\u0629 \u0648\u0627\u0644\u0623\u062f\u0628\u060c \u0648\u062e\u0635\u0648\u0635\u0627 \u0641\u064a \u0645\u062c\u0627\u0644 \u0627\u0644\u062e\u064a\u0627\u0644.",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:Spaced_ndash"
#                }
#             },
#             "http://dbpedia.org/property/quote": "facsimile of original manuscript pages, and illustrations by Carroll",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Eachtra\u00ed Eil\u00edse i dT\u00edr na nIontas",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Works_by_Lewis_Carroll"
#                }
#             },
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Alice's_Adventures_Under_Ground_-_Lewis_Carroll_-_British_Library_Add_MS_46700_f45v.jpg?width=300"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Fiction106367107"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "Alice&#39;s Adventures in Wonderland (vaak afgekort tot Alice in Wonderland, wat ook de titel is in Nederlandse vertalingen) is een kinderboek uit 1865 van Lewis Carroll, pseudoniem van de Engelse wiskundige Charles Lutwidge Dodgson. Het verhaal wordt gezien als modern sprookje.",
#             "http://dbpedia.org/property/wikt": "Alice in Wonderland",
#             "http://dbpedia.org/property/language": "English",
#             "http://dbpedia.org/ontology/releaseDate": "1865-11-26",
#             "http://dbpedia.org/ontology/literaryGenre": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Fantasy"
#                }
#             },
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Macmillan_Publishers"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "77508",
#             "http://dbpedia.org/property/v": "no",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Alice's_Adventures_in_Wonderland"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Alice's_Adventures_in_Wonderland?oldid=1025920007&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/genre": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Literary_nonsense"
#                }
#             },
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://www.gasl.org/refbib/Carroll__Works.pdf"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "52853",
#             "http://dbpedia.org/property/illustrator": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/John_Tenniel"
#                }
#             },
#             "http://dbpedia.org/property/no": "19002",
#             "http://xmlns.com/foaf/0.1/name": "Alice&#39;s Adventures in Wonderland",
#             "http://dbpedia.org/property/n": "no",
#             "http://dbpedia.org/property/followedBy": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Through_the_Looking-Glass"
#                }
#             },
#             "http://dbpedia.org/property/commons": "Category:Alice in Wonderland",
#             "http://dbpedia.org/property/s": "Alice&#39;s Adventures in Wonderland",
#             "http://dbpedia.org/property/b": "Lewis Carroll/Alice in Wonderland",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1025920007",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Lewis_Carroll"
#                }
#             },
#             "http://dbpedia.org/property/year": "1916",
#             "http://dbpedia.org/property/country": "United Kingdom",
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Lewis_Carroll"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Alice's_Adventures_Under_Ground_-_Lewis_Carroll_-_British_Library_Add_MS_46700_f45v.jpg"
#                }
#             },
#             "http://dbpedia.org/property/title": "Alice&#39;s Adventures Underground",
#             "http://dbpedia.org/ontology/subsequentWork": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Through_the_Looking-Glass"
#                }
#             },
#             "http://dbpedia.org/property/q": "Alice&#39;s Adventures in Wonderland",
#             "http://dbpedia.org/property/name": "Alice&#39;s Adventures in Wonderland,",
#             "http://dbpedia.org/property/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Macmillan_Publishers"
#                }
#             },
#             "http://dbpedia.org/property/releaseDate": "1865-11-26",
#             "http://dbpedia.org/ontology/illustrator": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/John_Tenniel"
#                }
#             },
#             "http://dbpedia.org/property/caption": "Cover of the original edition",
#             "http://dbpedia.org/property/bullet": "none",
#             "http://purl.org/dc/elements/1.1/publisher": "Macmillan"
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
author = js["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Alice's Adventures in Wonderland: " + author)
# Out:
# Autor de Alice's Adventures in Wonderland: http://dbpedia.org/resource/Lewis_Carroll

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
uri_mesh = json_mi[0]["resource"]

# %%
code = uri_mesh.split("/")[-1]

# %%
print("uri do recurso: " + uri_mesh)
print("código do recurso: ", code)
# Out:
# uri do recurso: http://id.nlm.nih.gov/mesh/D001241
# código do recurso:  D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"
url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %%
for term in json_mid['terms']:
    print("Termo :: ", term['label'])
    print("Resource :: ", term['resource'])
    print("-------------------------------------")
# Out:
# Termo ::  Aspirin
# Resource ::  http://id.nlm.nih.gov/mesh/T003713
# -------------------------------------
# Termo ::  2-(Acetyloxy)benzoic Acid
# Resource ::  http://id.nlm.nih.gov/mesh/T003714
# -------------------------------------
# Termo ::  Acetylsalicylic Acid
# Resource ::  http://id.nlm.nih.gov/mesh/T003712
# -------------------------------------
# Termo ::  Acetysal
# Resource ::  http://id.nlm.nih.gov/mesh/T003721
# -------------------------------------
# Termo ::  Acylpyrin
# Resource ::  http://id.nlm.nih.gov/mesh/T003722
# -------------------------------------
# Termo ::  Aloxiprimum
# Resource ::  http://id.nlm.nih.gov/mesh/T003711
# -------------------------------------
# Termo ::  Colfarit
# Resource ::  http://id.nlm.nih.gov/mesh/T003723
# -------------------------------------
# Termo ::  Dispril
# Resource ::  http://id.nlm.nih.gov/mesh/T003715
# -------------------------------------
# Termo ::  Easprin
# Resource ::  http://id.nlm.nih.gov/mesh/T003719
# -------------------------------------
# Termo ::  Ecotrin
# Resource ::  http://id.nlm.nih.gov/mesh/T003724
# -------------------------------------
# Termo ::  Endosprin
# Resource ::  http://id.nlm.nih.gov/mesh/T003725
# -------------------------------------
# Termo ::  Magnecyl
# Resource ::  http://id.nlm.nih.gov/mesh/T003726
# -------------------------------------
# Termo ::  Micristin
# Resource ::  http://id.nlm.nih.gov/mesh/T003727
# -------------------------------------
# Termo ::  Polopirin
# Resource ::  http://id.nlm.nih.gov/mesh/T003717
# -------------------------------------
# Termo ::  Polopiryna
# Resource ::  http://id.nlm.nih.gov/mesh/T003728
# -------------------------------------
# Termo ::  Solprin
# Resource ::  http://id.nlm.nih.gov/mesh/T003716
# -------------------------------------
# Termo ::  Solupsan
# Resource ::  http://id.nlm.nih.gov/mesh/T003718
# -------------------------------------
# Termo ::  Zorprin
# Resource ::  http://id.nlm.nih.gov/mesh/T003720
# -------------------------------------

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Eiffel Tower"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
json_data = data.json()
print(json.dumps(json_data, indent=3))
# Out:
# [
#    {
#       "place_id": 84512907,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 5013364,
#       "boundingbox": [
#          "48.8574753",
#          "48.8590453",
#          "2.2933084",
#          "2.2956897"
#       ],
#       "lat": "48.858260200000004",
#       "lon": "2.2944990543196795",
#       "display_name": "Tour Eiffel, 5, Avenue Anatole France, Quartier du Gros-Caillou, Paris 7e Arrondissement, Paris, \u00cele-de-France, France m\u00e9tropolitaine, 75007, France",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.6868325701744196,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 26942747,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 2689315641,
#       "boundingbox": [
#          "51.33355",
#          "51.33365",
#          "-116.23505",
#          "-116.23495"
#       ],
#       "lat": "51.3336",
#       "lon": "-116.235",
#       "display_name": "Eiffel Tower, Improvement District No. 9, Alberta, Canada",
#       "class": "natural",
#       "type": "peak",
#       "importance": 0.5,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_peak.p.20.png"
#    },
#    {
#       "place_id": 43676635,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3422228091,
#       "boundingbox": [
#          "48.8586807",
#          "48.8587807",
#          "2.2944394",
#          "2.2945394"
#       ],
#       "lat": "48.8587307",
#       "lon": "2.2944894",
#       "display_name": "Gustave Eiffel, Esplanade des Ouvriers de la Tour Eiffel, Quartier du Gros-Caillou, Paris 7e Arrondissement, Paris, \u00cele-de-France, France m\u00e9tropolitaine, 75007, France",
#       "class": "historic",
#       "type": "memorial",
#       "importance": 0.28764122278025944,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_monument.p.20.png"
#    },
#    {
#       "place_id": 48133458,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3880146677,
#       "boundingbox": [
#          "33.6398152",
#          "33.6399152",
#          "-95.5239198",
#          "-95.5238198"
#       ],
#       "lat": "33.6398652",
#       "lon": "-95.5238698",
#       "display_name": "Eiffel Tower, 2025, South Collegiate Drive, Paris, Lamar County, Texas, 75460, United States",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.28544064771236405,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 203841332,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 528467728,
#       "boundingbox": [
#          "-6.1031636",
#          "-6.1027488",
#          "106.7399174",
#          "106.7403743"
#       ],
#       "lat": "-6.1029492",
#       "lon": "106.74014672697001",
#       "display_name": "Eiffel Tower, Jalan Pantai Indah Kapuk, RW 03, Kamal Muara, Penjaringan, Jakarta Utara, Daerah Khusus Ibukota Jakarta, 14470, Indonesia",
#       "class": "man_made",
#       "type": "pumping_station",
#       "importance": 0.201
#    },
#    {
#       "place_id": 25145835,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 2552255779,
#       "boundingbox": [
#          "35.1699468",
#          "35.1700468",
#          "33.3565982",
#          "33.3566982"
#       ],
#       "lat": "35.1699968",
#       "lon": "33.3566482",
#       "display_name": "EIFFEL TOWER BUILDING, 2, Christodoulou Sozou, \u0394\u03ae\u03bc\u03bf\u03c2 \u039b\u03b5\u03c5\u03ba\u03c9\u03c3\u03af\u03b1\u03c2, \u039b\u03b5\u03c5\u03ba\u03c9\u03c3\u03af\u03b1 - Lefko\u015fa, \u039b\u03b5\u03c5\u03ba\u03c9\u03c3\u03af\u03b1, \u039d\u03cc\u03c4\u03b9\u03b1 \u039a\u03cd\u03c0\u03c1\u03bf\u03c2, 1096, \u039a\u03cd\u03c0\u03c1\u03bf\u03c2 - K\u0131br\u0131s",
#       "class": "place",
#       "type": "house",
#       "importance": 0.201
#    },
#    {
#       "place_id": 18653291,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 1822526019,
#       "boundingbox": [
#          "30.7489407",
#          "30.7490407",
#          "76.7852786",
#          "76.7853786"
#       ],
#       "lat": "30.7489907",
#       "lon": "76.7853286",
#       "display_name": "Eiffel Tower, Madhya Marg, Sector 10, Ward 1, Chandigarh, 160016, India",
#       "class": "tourism",
#       "type": "viewpoint",
#       "importance": 0.201,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//tourist_view_point.p.20.png"
#    },
#    {
#       "place_id": 305206882,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 27831699,
#       "boundingbox": [
#          "36.1121663",
#          "36.1127597",
#          "-115.1726095",
#          "-115.1717273"
#       ],
#       "lat": "36.11244535",
#       "lon": "-115.17216806080182",
#       "display_name": "Eiffel Tower, South Las Vegas Boulevard, Hughes Center, Paradise, Clark County, Nevada, 89158, United States",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.201,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 41257364,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 3184358208,
#       "boundingbox": [
#          "39.8091898",
#          "39.8092898",
#          "116.280389",
#          "116.280489"
#       ],
#       "lat": "39.8092398",
#       "lon": "116.280439",
#       "display_name": "Eiffel Tower, \u90ed\u516c\u5e84\u5357\u8857, \u82b1\u4e61\u8857\u9053, \u4e30\u53f0\u533a, \u5317\u4eac\u5e02, 100070, \u4e2d\u56fd",
#       "class": "tourism",
#       "type": "attraction",
#       "importance": 0.201,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_point_of_interest.p.20.png"
#    },
#    {
#       "place_id": 222867882,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 661318737,
#       "boundingbox": [
#          "39.3430824",
#          "39.3435738",
#          "-84.2672867",
#          "-84.2666744"
#       ],
#       "lat": "39.3433267",
#       "lon": "-84.26698190499772",
#       "display_name": "Eiffel Tower, Mason, Warren County, Ohio, United States",
#       "class": "man_made",
#       "type": "tower",
#       "importance": 0.201
#    }
# ]

# %%
print(place_ref[0]["osm_id"])
# Out:
# 6390214561

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
place_way = data.json()
print(json.dumps(place_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (3728580 spike-06.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 5013364,
#          "timestamp": "2021-05-18T08:12:31Z",
#          "version": 138,
#          "changeset": 104872415,
#          "user": "PanierAvide",
#          "uid": 214436,
#          "nodes": [
#             33388356,
#             639613234,
#             639613207,
#             33388327,
#             639613243,
#             828530561,
#             33388329,
#             3139588816,
#             3422228276,
#             3139781236,
#             3422228277,
#             828533301,
#             3139588819,
#             3139564403,
#             3139564405,
#             3139624571,
#             33388330,
#             3139564410,
#             33388332,
#             3139564415,
#             3139564417,
#             335600369,
#             3139564421,
#             33388333,
#             3139564425,
#             3139564426,
#             33388334,
#             828532883,
#             3422228396,
#             3139564427,
#             3422228292,
#             828530751,
#             33388335,
#             828532365,
#             639613322,
#             33388336,
#             4468710855,
#             4468710856,
#             639613336,
#             828530379,
#             33388337,
#             828530646,
#             3422228403,
#             3139781279,
#             3139781276,
#             3139564531,
#             33388338,
#             3139564534,
#             33388339,
#             335600372,
#             3139564541,
#             33388340,
#             641972287,
#             3139564546,
#             335600368,
#             3139564549,
#             3139564551,
#             3139781284,
#             3422228439,
#             828532672,
#             828531786,
#             828533113,
#             828530539,
#             828531926,
#             828530955,
#             639613303,
#             33388343,
#             3422228470,
#             639613276,
#             828529970,
#             828533385,
#             828530987,
#             828533459,
#             828530580,
#             828532951,
#             3422228448,
#             3422228197,
#             3422228443,
#             33388345,
#             3139564552,
#             3139564550,
#             3139624572,
#             3139564547,
#             3139564545,
#             3422228407,
#             33388346,
#             3139564540,
#             3139564538,
#             3139564536,
#             3139564535,
#             335600371,
#             33388347,
#             33388348,
#             639613263,
#             828530524,
#             828530083,
#             828532753,
#             828530713,
#             639613264,
#             33388350,
#             639613214,
#             828530347,
#             33388351,
#             828532987,
#             3423751744,
#             3139781246,
#             33388352,
#             33388353,
#             3139781254,
#             3139781253,
#             3139564423,
#             3139564420,
#             335600370,
#             3139564416,
#             3139564414,
#             3139564412,
#             33388354,
#             3139564409,
#             3139564407,
#             641972277,
#             3139564404,
#             3139564402,
#             3139781237,
#             33388355,
#             3423751743,
#             828532221,
#             828530849,
#             828530005,
#             33388356
#          ],
#          "tags": {
#             "3dmr": "4",
#             "addr:city": "Paris",
#             "addr:housenumber": "5",
#             "addr:postcode": "75007",
#             "addr:street": "Avenue Anatole France",
#             "alt_name:sr": "\u0410\u0458\u0444\u0435\u043b\u043e\u0432 \u0442\u043e\u0440\u0430\u045a",
#             "alt_name:zh-Hans": "\u5df4\u9ece\u94c1\u5854",
#             "alt_name:zh-Hant": "\u5df4\u9ece\u9435\u5854",
#             "architect": "Stephen Sauvestre;Gustave Eiffel;Maurice Koechlin;\u00c9mile Nouguier",
#             "building": "attraction",
#             "building:colour": "#706550",
#             "building:material": "iron",
#             "building:shape": "pyramidal",
#             "communication:radio": "fm",
#             "communication:television": "dvb-t",
#             "engineer": "Maurice Koechlin;\u00c9mile Nouguier",
#             "fee": "10-25\u20ac",
#             "height": "324",
#             "heritage": "3",
#             "heritage:operator": "mhs",
#             "historic": "yes",
#             "image": "https://fr.wikipedia.org/wiki/Fichier:Tour_Eiffel_Wikimedia_Commons.jpg",
#             "importance": "international",
#             "layer": "2",
#             "man_made": "tower",
#             "mhs:inscription_date": "1964-06-24",
#             "min_height": "0",
#             "name": "Tour Eiffel",
#             "name:af": "Eiffel-toring",
#             "name:ar": "\u0628\u0631\u062c \u0625\u064a\u0641\u0644",
#             "name:ast": "Torrne Eiffel",
#             "name:ba": "\u042d\u0439\u0444\u0435\u043b\u044c \u0431\u0430\u0448\u043d\u044f\u04bb\u044b",
#             "name:be": "\u0412\u0435\u0436\u0430 \u042d\u0439\u0444\u0435\u043b\u044f",
#             "name:cs": "Eiffelova v\u011b\u017e",
#             "name:da": "Eiffelt\u00e5rnet",
#             "name:de": "Eiffelturm",
#             "name:el": "\u03a0\u03cd\u03c1\u03b3\u03bf\u03c2 \u03c4\u03bf\u03c5 \u0386\u03b9\u03c6\u03b5\u03bb",
#             "name:en": "Eiffel Tower",
#             "name:eo": "Eiffel-Turo",
#             "name:es": "Torre Eiffel",
#             "name:et": "Eiffeli torn",
#             "name:fa": "\u0628\u0631\u062c \u0627\u06cc\u0641\u0644",
#             "name:fi": "Eiffel-torni",
#             "name:fr": "Tour Eiffel",
#             "name:hi": "\u090f\u092b\u093c\u093f\u0932 \u091f\u0949\u0935\u0930",
#             "name:hr": "Eiffelov toranj",
#             "name:hu": "Eiffel-torony",
#             "name:ia": "Turre Eiffel",
#             "name:id": "Menara Eiffel",
#             "name:io": "Turmo Eiffel",
#             "name:it": "Torre Eiffel",
#             "name:ja": "\u30a8\u30c3\u30d5\u30a7\u30eb\u5854",
#             "name:ko": "\uc5d0\ud3a0\ud0d1",
#             "name:ku": "Bar\u00fbya Eyfel\u00ea",
#             "name:la": "Turris Eiffelia",
#             "name:lb": "Eiffeltuerm",
#             "name:nl": "Eiffeltoren",
#             "name:pl": "Wie\u017ca Eiffla",
#             "name:pt": "Torre Eiffel",
#             "name:ru": "\u042d\u0439\u0444\u0435\u043b\u0435\u0432\u0430 \u0431\u0430\u0448\u043d\u044f",
#             "name:sk": "Eiffelova ve\u017ea",
#             "name:sl": "Eifflov stolp",
#             "name:sr": "\u0410\u0458\u0444\u0435\u043b\u043e\u0432\u0430 \u043a\u0443\u043b\u0430",
#             "name:sv": "Eiffeltornet",
#             "name:ta": "\u0b88\u0baa\u0bc6\u0bb2\u0bcd \u0b95\u0bcb\u0baa\u0bc1\u0bb0\u0bae\u0bcd",
#             "name:tr": "Eyfel Kulesi",
#             "name:tt": "\u042d\u0439\u0444\u0435\u043b\u044c \u043c\u0430\u043d\u0430\u0440\u0430\u0441\u044b",
#             "name:uk": "\u0415\u0439\u0444\u0435\u043b\u0435\u0432\u0430 \u0432\u0435\u0436\u0430",
#             "name:vi": "Th\u00e1p Eiffel",
#             "name:vo": "T\u00fcm di Eiffel",
#             "name:zh": "\u57c3\u83f2\u5c14\u94c1\u5854",
#             "name:zh-Hant": "\u827e\u83f2\u723e\u9435\u5854",
#             "opening_hours": "09:30-23:45; Jun 21-Sep 2: 09:00-00:45; Jul 14,Jul 15 off",
#             "operator": "Soci\u00e9t\u00e9 d\u2019Exploitation de la Tour Eiffel",
#             "ref:FR:ANFR": "548894",
#             "ref:FR:FANTOIR": "75107P320D",
#             "ref:mhs": "PA00088801",
#             "source:building": "http://fr.wikipedia.org/wiki/Donn%C3%A9es_techniques_de_la_tour_Eiffel",
#             "source:heritage": "data.gouv.fr, Minist\u00e8re de la Culture - 2016",
#             "start_date": "C19",
#             "tourism": "attraction",
#             "tourism:visitors": "7000000",
#             "tower:construction": "lattice",
#             "tower:type": "communication;observation",
#             "website": "https://www.toureiffel.paris/",
#             "wheelchair": "yes",
#             "wikidata": "Q243",
#             "wikimedia_commons": "Category:Eiffel Tower",
#             "wikipedia": "fr:Tour Eiffel"
#          }
#       }
#    ]
# }

# %%
print(place_way["elements"][0]["tags"]["wikipedia"])
# Out:
# fr:Tour Eiffel

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("fr:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
place_dbpedia = data.json()
print(json.dumps(place_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tour_Eiffel"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Eiffel_Tower"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tour_Eiffel?oldid=871963804&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "58",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tour_Eiffel"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "1098124",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "871963804",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tour Eiffel",
#             "http://dbpedia.org/ontology/wikiPageRedirects": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Eiffel_Tower"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:R_from_alternative_language"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
