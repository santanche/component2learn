# %% [markdown]
# # Componentização Passo a Passo
#
# ## Passo 1 - Módulo / Pacote

# %%
import iplantuml

# %%
# %%plantuml
#
# @startuml
#
# rectangle table
#
# @enduml
# Out:
# Writing output for /home/santanche/git/component2learn/notebooks/componentization/fa07383b-d7c0-491d-8a06-88fe7b778fc6.uml to fa07383b-d7c0-491d-8a06-88fe7b778fc6.svg

# %%
import pandas as pd

def table(file_path):
    return pd.read_csv(file_path)

# %%
# %%plantuml
#
# @startuml
#
# rectangle scatter_plot
#
# @enduml
# Out:
# Writing output for /home/santanche/git/component2learn/notebooks/componentization/340e0854-bf56-4d0d-9922-e7d510d16247.uml to 340e0854-bf56-4d0d-9922-e7d510d16247.svg

# %%
import matplotlib.pyplot as plt

def scatter_plot(data, xfield, yfield, title):
    plt.figure(figsize=(10, 6))
    scatter = plt.scatter(data[xfield], data[yfield], c=data[yfield], cmap='viridis')
    
    plt.xlabel(xfield)
    plt.ylabel(yfield)
    plt.title(title)
    
    plt.colorbar(scatter, label=yfield)
    
    plt.show()

# %%
# %%plantuml
#
# @startuml
#
# rectangle Table
# rectangle ScatterPlot
# rectangle df
#
# Table - df
# df - ScatterPlot
#
# @enduml
# Out:
# Writing output for /home/santanche/git/component2learn/notebooks/componentization/31eba19b-4ede-4990-a092-f00b0a2c12f4.uml to 31eba19b-4ede-4990-a092-f00b0a2c12f4.svg

# %%
# Read the data
df = table('intake-person-demo(potato-chips).csv')

# Create the scatter plot
scatter_plot(df, 'age', 'intake_bw', 'Age vs. Intake (body weight)')
